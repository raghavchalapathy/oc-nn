# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install picklable_itertools

# !pip install fuel
# !pip install foolbox

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
import numpy as np
PROJECT_DIR = "/content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/"
import sys,os
import numpy as np
sys.path.append(PROJECT_DIR)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: picklable_itertools in /usr/local/lib/python3.6/dist-packages (0.1.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from picklable_itertools) (1.11.0)
# Requirement already satisfied: fuel in /usr/local/lib/python3.6/dist-packages (0.2.0)
# Requirement already satisfied: tables in /usr/local/lib/python3.6/dist-packages (from fuel) (3.4.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from fuel) (2.18.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from fuel) (3.13)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from fuel) (4.0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from fuel) (1.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from fuel) (1.14.6)
# Requirement already satisfied: picklable-itertools in /usr/local/lib/python3.6/dist-packages (from fuel) (0.1.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from fuel) (1.11.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from fuel) (2.8.0)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.6/dist-packages (from fuel) (17.0.0)
# Requirement already satisfied: progressbar2 in /usr/local/lib/python3.6/dist-packages (from fuel) (3.38.0)
# Requirement already satisfied: numexpr>=2.5.2 in /usr/local/lib/python3.6/dist-packages (from tables->fuel) (2.6.8)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->fuel) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->fuel) (2018.10.15)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->fuel) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->fuel) (2.6)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from pillow->fuel) (0.46)
# Requirement already satisfied: python-utils>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from progressbar2->fuel) (2.3.0)
# Requirement already satisfied: foolbox in /usr/local/lib/python3.6/dist-packages (1.8.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from foolbox) (40.6.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from foolbox) (2.18.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from foolbox) (1.14.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from foolbox) (1.1.0)
# Requirement already satisfied: GitPython in /usr/local/lib/python3.6/dist-packages (from foolbox) (2.1.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->foolbox) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->foolbox) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->foolbox) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->foolbox) (2018.10.15)
# Requirement already satisfied: gitdb2>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from GitPython->foolbox) (2.0.5)
# Requirement already satisfied: smmap2>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from gitdb2>=2.0.0->GitPython->foolbox) (2.0.5)

# %% [markdown]
# ##** MNIST  0 Vs All

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

import numpy as np 
from src.config import Configuration as Cfg
from src.models.kde import KDE



DATASET = "mnist"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/mnist/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/mnist/ISO_FOREST/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.mnist_val_frac = 0.1
Cfg.mnist_normal = 0
Cfg.mnist_outlier = -1
# KDE parameters
Cfg.kde_GridSearchCV = 1


for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    # initialize KDE
    kde = KDE(dataset=DATASET, kernel="gaussian")

    # train KDE model
    kde.fit(bandwidth_GridSearchCV=Cfg.kde_GridSearchCV)

    # predict scores
   
    auc_roc = kde.predict(which_set='test')
   
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    print("========================================================================",)
    AUC.append(auc_roc)

    
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean*100 ,"+/-",auc_roc_std*100)
print("========================================================================")
# Out:
# Using TensorFlow backend.
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/utils/visualization/mosaic_plot.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-6569f4f7c1be>", line 10, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')  # or 'PS', 'PDF', 'SVG'
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6374, 28, 28, 1)
# The shape of POS data :  (6311, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Using GridSearchCV for bandwidth selection...
# Total elapsed time: 3656.52
# Starting prediction...
# Total elapsed time: 66.9389
# ========================================================================
# AUROC:  0.609510227795761
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   56
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6374, 28, 28, 1)
# The shape of POS data :  (6311, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Using GridSearchCV for bandwidth selection...
# Total elapsed time: 3669.43
# Starting prediction...
# Total elapsed time: 66.8014
# ========================================================================
# AUROC:  0.6271526410173218
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   81
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6374, 28, 28, 1)
# The shape of POS data :  (6311, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Using GridSearchCV for bandwidth selection...

# %% [markdown]
# ## ** MNIST 1 Vs all

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

import numpy as np 
from src.config import Configuration as Cfg
from src.models.kde import KDE



DATASET = "mnist"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/mnist/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/mnist/ISO_FOREST/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.mnist_val_frac = 0.1
Cfg.mnist_normal = 1
Cfg.mnist_outlier = -1
# KDE parameters
Cfg.kde_GridSearchCV = 1


for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    # initialize KDE
    kde = KDE(dataset=DATASET, kernel="gaussian")

    # train KDE model
    kde.fit(bandwidth_GridSearchCV=Cfg.kde_GridSearchCV)

    # predict scores
   
    auc_roc = kde.predict(which_set='test')
   
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    print("========================================================================",)
    AUC.append(auc_roc)

    
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean*100 ,"+/-",auc_roc_std*100)
print("========================================================================")
# Out:
# Using TensorFlow backend.
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/utils/visualization/mosaic_plot.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-6569f4f7c1be>", line 10, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')  # or 'PS', 'PDF', 'SVG'
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (7275, 28, 28, 1)
# The shape of POS data :  (7203, 28, 28, 1)
# The shape of NEG data :  (72, 28, 28, 1)
# Starting training...
# Using GridSearchCV for bandwidth selection...
# Total elapsed time: 6902.86
# Starting prediction...
# Total elapsed time: 91.563
# ========================================================================
# AUROC:  0.7143821247319789
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   56
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (7275, 28, 28, 1)
# The shape of POS data :  (7203, 28, 28, 1)
# The shape of NEG data :  (72, 28, 28, 1)
# Starting training...
# Using GridSearchCV for bandwidth selection...
# Total elapsed time: 6925.53
# Starting prediction...
# Total elapsed time: 94.2764
# ========================================================================
# AUROC:  0.7192093957764512
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   81
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (7275, 28, 28, 1)
# The shape of POS data :  (7203, 28, 28, 1)
# The shape of NEG data :  (72, 28, 28, 1)
# Starting training...
# Using GridSearchCV for bandwidth selection...
# Total elapsed time: 6926.35
# Starting prediction...
# Total elapsed time: 93.4185
# ========================================================================
# AUROC:  0.7094430175698396
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   67
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (7275, 28, 28, 1)
# The shape of POS data :  (7203, 28, 28, 1)
# The shape of NEG data :  (72, 28, 28, 1)
# Starting training...
# Using GridSearchCV for bandwidth selection...
# Total elapsed time: 6914.43
# Starting prediction...
# Total elapsed time: 99.2634
# ========================================================================
# AUROC:  0.663944999768615
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   33
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (7275, 28, 28, 1)
# The shape of POS data :  (7203, 28, 28, 1)
# The shape of NEG data :  (72, 28, 28, 1)
# Starting training...
# Using GridSearchCV for bandwidth selection...
# Total elapsed time: 6915.03
# Starting prediction...
# Total elapsed time: 95.1499
# ========================================================================
# AUROC:  0.7098199824147344
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   25
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (7275, 28, 28, 1)
# The shape of POS data :  (7203, 28, 28, 1)
# The shape of NEG data :  (72, 28, 28, 1)
# Starting training...
# Using GridSearchCV for bandwidth selection...

# %% [markdown]
# ## ** MNIST 2 Vs all

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

import numpy as np 
from src.config import Configuration as Cfg
from src.models.kde import KDE



DATASET = "mnist"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/mnist/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/mnist/ISO_FOREST/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.mnist_val_frac = 0.1
Cfg.mnist_normal = 2
Cfg.mnist_outlier = -1
# KDE parameters
Cfg.kde_GridSearchCV = 1


for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    # initialize KDE
    kde = KDE(dataset=DATASET, kernel="gaussian")

    # train KDE model
    kde.fit(bandwidth_GridSearchCV=Cfg.kde_GridSearchCV)

    # predict scores
   
    auc_roc = kde.predict(which_set='test')
   
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    print("========================================================================",)
    AUC.append(auc_roc)

    
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean*100 ,"+/-",auc_roc_std*100)
print("========================================================================")
# Out:
# Using TensorFlow backend.
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/utils/visualization/mosaic_plot.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-6569f4f7c1be>", line 10, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')  # or 'PS', 'PDF', 'SVG'
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  2
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6458, 28, 28, 1)
# The shape of POS data :  (6395, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Using GridSearchCV for bandwidth selection...
# Total elapsed time: 5021.88
# Starting prediction...
# Total elapsed time: 68.2714
# ========================================================================
# AUROC:  0.6298310932400065
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  2
# [INFO:] Random Seed used is   56
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6458, 28, 28, 1)
# The shape of POS data :  (6395, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Using GridSearchCV for bandwidth selection...
# Total elapsed time: 5017.79
# Starting prediction...
# Total elapsed time: 70.2936
# ========================================================================
# AUROC:  0.6229035580872955
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  2
# [INFO:] Random Seed used is   81
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6458, 28, 28, 1)
# The shape of POS data :  (6395, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Using GridSearchCV for bandwidth selection...
# Total elapsed time: 5028.6
# Starting prediction...
# Total elapsed time: 70.3034
# ========================================================================
# AUROC:  0.7051280141975999
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  2
# [INFO:] Random Seed used is   67
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6458, 28, 28, 1)
# The shape of POS data :  (6395, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Using GridSearchCV for bandwidth selection...

# %% [markdown]
# ## ** MNIST 3 Vs all

# %%
# !! python --version

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

import numpy as np 
from src.config import Configuration as Cfg
from src.models.kde import KDE



DATASET = "mnist"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/mnist/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/mnist/ISO_FOREST/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.mnist_val_frac = 0.1
Cfg.mnist_normal = 3
Cfg.mnist_outlier = -1
# KDE parameters
Cfg.kde_GridSearchCV = 1


for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    # initialize KDE
    kde = KDE(dataset=DATASET, kernel="gaussian")

    # train KDE model
    kde.fit(bandwidth_GridSearchCV=Cfg.kde_GridSearchCV)

    # predict scores
   
    auc_roc = kde.predict(which_set='test')
   
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    print("========================================================================",)
    AUC.append(auc_roc)

    
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean*100 ,"+/-",auc_roc_std*100)
print("========================================================================")
# Out:
# Using TensorFlow backend.
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/utils/visualization/mosaic_plot.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-6569f4f7c1be>", line 10, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')  # or 'PS', 'PDF', 'SVG'
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (6528, 28, 28, 1)
# The shape of NEG data :  (65, 28, 28, 1)
# Starting training...
# Using GridSearchCV for bandwidth selection...
# Total elapsed time: 5240.85
# Starting prediction...
# Total elapsed time: 70.3722
# ========================================================================
# AUROC:  0.702166996606335
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO:] Random Seed used is   56
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (6528, 28, 28, 1)
# The shape of NEG data :  (65, 28, 28, 1)
# Starting training...
# Using GridSearchCV for bandwidth selection...
# Total elapsed time: 5521.03
# Starting prediction...
# Total elapsed time: 75.0601
# ========================================================================
# AUROC:  0.6922499528657617
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO:] Random Seed used is   81
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (6528, 28, 28, 1)
# The shape of NEG data :  (65, 28, 28, 1)
# Starting training...
# Using GridSearchCV for bandwidth selection...
# Total elapsed time: 5551.34
# Starting prediction...
# Total elapsed time: 75.3563
# ========================================================================
# AUROC:  0.6447080033936652
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO:] Random Seed used is   67
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (6528, 28, 28, 1)
# The shape of NEG data :  (65, 28, 28, 1)
# Starting training...
# Using GridSearchCV for bandwidth selection...
# Total elapsed time: 5566.4
# Starting prediction...
# Total elapsed time: 75.4758
# ========================================================================
# AUROC:  0.6671592194570136
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO:] Random Seed used is   33
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (6528, 28, 28, 1)
# The shape of NEG data :  (65, 28, 28, 1)
# Starting training...
# Using GridSearchCV for bandwidth selection...
# Total elapsed time: 5545.43
# Starting prediction...
# Total elapsed time: 75.4696
# ========================================================================
# AUROC:  0.716025641025641
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO:] Random Seed used is   25
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (6528, 28, 28, 1)
# The shape of NEG data :  (65, 28, 28, 1)
# Starting training...
# Using GridSearchCV for bandwidth selection...
# Total elapsed time: 5594.86
# Starting prediction...
# Total elapsed time: 77.2475
# ========================================================================
# AUROC:  0.7012349170437406
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO:] Random Seed used is   90
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (6528, 28, 28, 1)
# The shape of NEG data :  (65, 28, 28, 1)
# Starting training...
# Using GridSearchCV for bandwidth selection...
# Total elapsed time: 5613.94
# Starting prediction...
# Total elapsed time: 77.6118
# ========================================================================
# AUROC:  0.6464696455505279
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO:] Random Seed used is   77
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (6528, 28, 28, 1)
# The shape of NEG data :  (65, 28, 28, 1)
# Starting training...
# Using GridSearchCV for bandwidth selection...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-9b6d9d08170e> in <module>()
#      46
#      47     # train KDE model
# ---> 48     kde.fit(bandwidth_GridSearchCV=Cfg.kde_GridSearchCV)
#      49
#      50     # predict scores
#
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/models/kde.py in fit(self, bandwidth_GridSearchCV)
#     251
#     252             hyper_kde = GridSearchCV(KernelDensity(kernel=self.kernel), params, n_jobs=-1, cv=5, verbose=0)
# --> 253             hyper_kde.fit(X_train)
#     254
#     255             self.bandwidth = hyper_kde.best_estimator_.bandwidth
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     638                                   error_score=self.error_score)
#     639           for parameters, (train, test) in product(candidate_params,
# --> 640                                                    cv.split(X, y, groups)))
#     641
#     642         # if one choose to see train score, "out" will contain train score info
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     787                 # consumption.
#     788                 self._iterating = False
# --> 789             self.retrieve()
#     790             # Make sure that we get a last message telling us we are done
#     791             elapsed_time = time.time() - self._start_time
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in retrieve(self)
#     697             try:
#     698                 if getattr(self._backend, 'supports_timeout', False):
# --> 699                     self._output.extend(job.get(timeout=self.timeout))
#     700                 else:
#     701                     self._output.extend(job.get())
#
# /usr/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     662
#     663     def get(self, timeout=None):
# --> 664         self.wait(timeout)
#     665         if not self.ready():
#     666             raise TimeoutError
#
# /usr/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     659
#     660     def wait(self, timeout=None):
# --> 661         self._event.wait(timeout)
#     662
#     663     def get(self, timeout=None):
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %% [markdown]
# ## ** MNIST 4 Vs all

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

import numpy as np 
from src.config import Configuration as Cfg
from src.models.kde import KDE



DATASET = "mnist"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/mnist/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/mnist/ISO_FOREST/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.mnist_val_frac = 0.1
Cfg.mnist_normal = 4
Cfg.mnist_outlier = -1
# KDE parameters
Cfg.kde_GridSearchCV = 1


for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    # initialize KDE
    kde = KDE(dataset=DATASET, kernel="gaussian")

    # train KDE model
    kde.fit(bandwidth_GridSearchCV=Cfg.kde_GridSearchCV)

    # predict scores
   
    auc_roc = kde.predict(which_set='test')
   
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    print("========================================================================",)
    AUC.append(auc_roc)

    
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean*100 ,"+/-",auc_roc_std*100)
print("========================================================================")
# Out:
# Using TensorFlow backend.
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/utils/visualization/mosaic_plot.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-6569f4f7c1be>", line 10, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')  # or 'PS', 'PDF', 'SVG'
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  4
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (6240, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Using GridSearchCV for bandwidth selection...
# Total elapsed time: 3701.28
# Starting prediction...
# Total elapsed time: 68.6871
# ========================================================================
# AUROC:  0.5891555521091811
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  4
# [INFO:] Random Seed used is   56
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (6240, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Using GridSearchCV for bandwidth selection...
# Total elapsed time: 3705.56
# Starting prediction...
# Total elapsed time: 68.4284
# ========================================================================
# AUROC:  0.5886489350703062
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  4
# [INFO:] Random Seed used is   81
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (6240, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Using GridSearchCV for bandwidth selection...
# Total elapsed time: 3710.82
# Starting prediction...
# Total elapsed time: 68.0864
# ========================================================================
# AUROC:  0.593058571133168
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  4
# [INFO:] Random Seed used is   67
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (6240, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Using GridSearchCV for bandwidth selection...
# Total elapsed time: 3735.01
# Starting prediction...
# Total elapsed time: 68.5603
# ========================================================================
# AUROC:  0.5497725392886683
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  4
# [INFO:] Random Seed used is   33
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (6240, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Using GridSearchCV for bandwidth selection...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-adf3eff49c84> in <module>()
#      46
#      47     # train KDE model
# ---> 48     kde.fit(bandwidth_GridSearchCV=Cfg.kde_GridSearchCV)
#      49
#      50     # predict scores
#
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/models/kde.py in fit(self, bandwidth_GridSearchCV)
#     251
#     252             hyper_kde = GridSearchCV(KernelDensity(kernel=self.kernel), params, n_jobs=-1, cv=5, verbose=0)
# --> 253             hyper_kde.fit(X_train)
#     254
#     255             self.bandwidth = hyper_kde.best_estimator_.bandwidth
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     638                                   error_score=self.error_score)
#     639           for parameters, (train, test) in product(candidate_params,
# --> 640                                                    cv.split(X, y, groups)))
#     641
#     642         # if one choose to see train score, "out" will contain train score info
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     787                 # consumption.
#     788                 self._iterating = False
# --> 789             self.retrieve()
#     790             # Make sure that we get a last message telling us we are done
#     791             elapsed_time = time.time() - self._start_time
#
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/parallel.py in retrieve(self)
#     697             try:
#     698                 if getattr(self._backend, 'supports_timeout', False):
# --> 699                     self._output.extend(job.get(timeout=self.timeout))
#     700                 else:
#     701                     self._output.extend(job.get())
#
# /usr/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     662
#     663     def get(self, timeout=None):
# --> 664         self.wait(timeout)
#     665         if not self.ready():
#     666             raise TimeoutError
#
# /usr/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     659
#     660     def wait(self, timeout=None):
# --> 661         self._event.wait(timeout)
#     662
#     663     def get(self, timeout=None):
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %% [markdown]
# ## ** MNIST 5 Vs all

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

import numpy as np 
from src.config import Configuration as Cfg
from src.models.kde import KDE



DATASET = "mnist"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/mnist/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/mnist/ISO_FOREST/"

PRETRAINED_WT_PATH = ""
# RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
RANDOM_SEED = [42]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.mnist_val_frac = 0.1
Cfg.mnist_normal = 5
Cfg.mnist_outlier = -1
# KDE parameters
Cfg.kde_GridSearchCV = 1


for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    # initialize KDE
    kde = KDE(dataset=DATASET, kernel="gaussian")

    # train KDE model
    kde.fit(bandwidth_GridSearchCV=Cfg.kde_GridSearchCV)

    # predict scores
   
    auc_roc = kde.predict(which_set='test')
   
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    print("========================================================================",)
    AUC.append(auc_roc)

    
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean*100 ,"+/-",auc_roc_std*100)
print("========================================================================")
# Out:
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  5
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (5828, 28, 28, 1)
# The shape of POS data :  (5771, 28, 28, 1)
# The shape of NEG data :  (57, 28, 28, 1)
# Starting training...
# Using GridSearchCV for bandwidth selection...
# Total elapsed time: 3335.62
# Starting prediction...
# Total elapsed time: 62.4879
# ========================================================================
# AUROC:  0.5542610207723433
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.5542610207723433]
# AUROC ===== 55.42610207723433 +/- 0.0
# ========================================================================

# %% [markdown]
# ## ** MNIST 6 Vs all

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

import numpy as np 
from src.config import Configuration as Cfg
from src.models.kde import KDE



DATASET = "mnist"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/mnist/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/mnist/ISO_FOREST/"

PRETRAINED_WT_PATH = ""
# RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
RANDOM_SEED = [42]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.mnist_val_frac = 0.1
Cfg.mnist_normal = 6
Cfg.mnist_outlier = -1
# KDE parameters
Cfg.kde_GridSearchCV = 1


for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    # initialize KDE
    kde = KDE(dataset=DATASET, kernel="gaussian")

    # train KDE model
    kde.fit(bandwidth_GridSearchCV=Cfg.kde_GridSearchCV)

    # predict scores
   
    auc_roc = kde.predict(which_set='test')
   
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    print("========================================================================",)
    AUC.append(auc_roc)

    
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean*100 ,"+/-",auc_roc_std*100)
print("========================================================================")
# Out:
# Using TensorFlow backend.
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/utils/visualization/mosaic_plot.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-6569f4f7c1be>", line 10, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')  # or 'PS', 'PDF', 'SVG'
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  6
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6347, 28, 28, 1)
# The shape of POS data :  (6285, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Using GridSearchCV for bandwidth selection...
# Total elapsed time: 3475.99
# Starting prediction...
# Total elapsed time: 56.0924
# ========================================================================
# AUROC:  0.57175815433572
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.57175815433572]
# AUROC ===== 57.175815433572 +/- 0.0
# ========================================================================

# %% [markdown]
# ## ** MNIST 7 Vs all

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

import numpy as np 
from src.config import Configuration as Cfg
from src.models.kde import KDE



DATASET = "mnist"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/mnist/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/mnist/ISO_FOREST/"

PRETRAINED_WT_PATH = ""
# RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
RANDOM_SEED = [42]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.mnist_val_frac = 0.1
Cfg.mnist_normal = 7
Cfg.mnist_outlier = -1
# KDE parameters
Cfg.kde_GridSearchCV = 1


for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    # initialize KDE
    kde = KDE(dataset=DATASET, kernel="gaussian")

    # train KDE model
    kde.fit(bandwidth_GridSearchCV=Cfg.kde_GridSearchCV)

    # predict scores
   
    auc_roc = kde.predict(which_set='test')
   
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    print("========================================================================",)
    AUC.append(auc_roc)

    
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean*100 ,"+/-",auc_roc_std*100)
print("========================================================================")
# Out:
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  7
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6733, 28, 28, 1)
# The shape of POS data :  (6667, 28, 28, 1)
# The shape of NEG data :  (66, 28, 28, 1)
# Starting training...
# Using GridSearchCV for bandwidth selection...
# Total elapsed time: 5046.69
# Starting prediction...
# Total elapsed time: 63.0465
# ========================================================================
# AUROC:  0.6259152951443337
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.6259152951443337]
# AUROC ===== 62.591529514433375 +/- 0.0
# ========================================================================

# %% [markdown]
# ## ** MNIST 8 Vs all

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

import numpy as np 
from src.config import Configuration as Cfg
from src.models.kde import KDE



DATASET = "mnist"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/mnist/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/mnist/ISO_FOREST/"

PRETRAINED_WT_PATH = ""
# RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
RANDOM_SEED = [42]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.mnist_val_frac = 0.1
Cfg.mnist_normal = 8
Cfg.mnist_outlier = -1
# KDE parameters
Cfg.kde_GridSearchCV = 1


for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    # initialize KDE
    kde = KDE(dataset=DATASET, kernel="gaussian")

    # train KDE model
    kde.fit(bandwidth_GridSearchCV=Cfg.kde_GridSearchCV)

    # predict scores
   
    auc_roc = kde.predict(which_set='test')
   
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    print("========================================================================",)
    AUC.append(auc_roc)

    
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean*100 ,"+/-",auc_roc_std*100)
print("========================================================================")
# Out:
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (6240, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Using GridSearchCV for bandwidth selection...
# Total elapsed time: 3838.71
# Starting prediction...
# Total elapsed time: 67.6859
# ========================================================================
# AUROC:  0.5492594602977667
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.5492594602977667]
# AUROC ===== 54.925946029776675 +/- 0.0
# ========================================================================

# %% [markdown]
# ## ** MNIST 9 Vs all

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

import numpy as np 
from src.config import Configuration as Cfg
from src.models.kde import KDE



DATASET = "mnist"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/mnist/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/mnist/ISO_FOREST/"

PRETRAINED_WT_PATH = ""
# RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
RANDOM_SEED = [42]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.mnist_val_frac = 0.1
Cfg.mnist_normal = 9
Cfg.mnist_outlier = -1
# KDE parameters
Cfg.kde_GridSearchCV = 1


for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    # initialize KDE
    kde = KDE(dataset=DATASET, kernel="gaussian")

    # train KDE model
    kde.fit(bandwidth_GridSearchCV=Cfg.kde_GridSearchCV)

    # predict scores
   
    auc_roc = kde.predict(which_set='test')
   
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    print("========================================================================",)
    AUC.append(auc_roc)

    
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean*100 ,"+/-",auc_roc_std*100)
print("========================================================================")
# Out:
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  9
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6427, 28, 28, 1)
# The shape of POS data :  (6364, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Using GridSearchCV for bandwidth selection...
# Total elapsed time: 5340.22
# Starting prediction...
# Total elapsed time: 68.9289
# ========================================================================
# AUROC:  0.5510385801083475
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.5510385801083475]
# AUROC ===== 55.10385801083475 +/- 0.0
# ========================================================================
