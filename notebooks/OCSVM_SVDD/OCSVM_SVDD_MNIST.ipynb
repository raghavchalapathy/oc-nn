# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install picklable_itertools

# !pip install fuel
# !pip install foolbox

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
import numpy as np
PROJECT_DIR = "/content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/"
import sys,os
import numpy as np
sys.path.append(PROJECT_DIR)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# Collecting picklable_itertools
#   Downloading https://files.pythonhosted.org/packages/75/bc/cda9191f0c92960ede6aa95e364443965246385faf62775cc30749931c2c/picklable-itertools-0.1.1.tar.gz
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from picklable_itertools) (1.11.0)
# Building wheels for collected packages: picklable-itertools
# done
#   Stored in directory: /root/.cache/pip/wheels/36/dd/e2/ec30ef7c475e1d9fb966735984ba05f8710c67d7de5358c326
# Successfully built picklable-itertools
# Installing collected packages: picklable-itertools
# Successfully installed picklable-itertools-0.1.1
# Collecting fuel
#   Downloading https://files.pythonhosted.org/packages/16/c2/b5fb651c90e908f79769b7dd3643982b6a9b1bac9449b8ab16f72612d4f5/fuel-0.2.0.tar.gz (184kB)
#     100% |████████████████████████████████| 194kB 12.9MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from fuel) (1.14.6)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from fuel) (1.11.0)
# Requirement already satisfied: picklable_itertools in /usr/local/lib/python3.6/dist-packages (from fuel) (0.1.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from fuel) (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from fuel) (2.8.0)
# Collecting tables (from fuel)
#   Downloading https://files.pythonhosted.org/packages/d7/1b/21f4c7f296b718575c17ef25e61c05742a283c45077b4c8d5a190b3e0b59/tables-3.4.4-cp36-cp36m-manylinux1_x86_64.whl (3.8MB)
#     100% |████████████████████████████████| 3.8MB 9.9MB/s
# Collecting progressbar2 (from fuel)
#   Downloading https://files.pythonhosted.org/packages/4f/6f/acb2dd76f2c77527584bd3a4c2509782bb35c481c610521fc3656de5a9e0/progressbar2-3.38.0-py2.py3-none-any.whl
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.6/dist-packages (from fuel) (17.0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from fuel) (1.1.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from fuel) (4.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from fuel) (2.18.4)
# Collecting numexpr>=2.5.2 (from tables->fuel)
#   Downloading https://files.pythonhosted.org/packages/db/ea/efd9e16283637eb5b6c0042b6cc3521f1b9a5b47767ac463c88bbd37670c/numexpr-2.6.8-cp36-cp36m-manylinux1_x86_64.whl (162kB)
#     100% |████████████████████████████████| 163kB 15.7MB/s
# Collecting python-utils>=2.3.0 (from progressbar2->fuel)
#   Downloading https://files.pythonhosted.org/packages/eb/a0/19119d8b7c05be49baf6c593f11c432d571b70d805f2fe94c0585e55e4c8/python_utils-2.3.0-py2.py3-none-any.whl
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from pillow->fuel) (0.46)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->fuel) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->fuel) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->fuel) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->fuel) (2018.10.15)
# Building wheels for collected packages: fuel
# done
#   Stored in directory: /root/.cache/pip/wheels/96/ff/1b/f3708731cf77a6d759cd12e68c0a27700c299fbe2bffd34fa3
# Successfully built fuel
# Installing collected packages: numexpr, tables, python-utils, progressbar2, fuel
# Successfully installed fuel-0.2.0 numexpr-2.6.8 progressbar2-3.38.0 python-utils-2.3.0 tables-3.4.4
# Collecting foolbox
#   Downloading https://files.pythonhosted.org/packages/d5/6d/31f6bbd461f3276288b9bd9c0cf6d93e01231e5da2133b250e23f7df6566/foolbox-1.8.0.tar.gz (239kB)
#     100% |████████████████████████████████| 245kB 15.1MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from foolbox) (1.14.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from foolbox) (1.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from foolbox) (40.6.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from foolbox) (2.18.4)
# Collecting GitPython (from foolbox)
#   Downloading https://files.pythonhosted.org/packages/fe/e5/fafe827507644c32d6dc553a1c435cdf882e0c28918a5bab29f7fbebfb70/GitPython-2.1.11-py2.py3-none-any.whl (448kB)
#     100% |████████████████████████████████| 450kB 24.4MB/s
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->foolbox) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->foolbox) (2018.10.15)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->foolbox) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->foolbox) (1.22)
# Collecting gitdb2>=2.0.0 (from GitPython->foolbox)
#   Downloading https://files.pythonhosted.org/packages/da/30/a407568aa8d8f25db817cf50121a958722f3fc5f87e3a6fba1f40c0633e3/gitdb2-2.0.5-py2.py3-none-any.whl (62kB)
#     100% |████████████████████████████████| 71kB 24.4MB/s
# Collecting smmap2>=2.0.0 (from gitdb2>=2.0.0->GitPython->foolbox)
#   Downloading https://files.pythonhosted.org/packages/55/d2/866d45e3a121ee15a1dc013824d58072fd5c7799c9c34d01378eb262ca8f/smmap2-2.0.5-py2.py3-none-any.whl
# Building wheels for collected packages: foolbox
# done
#   Stored in directory: /root/.cache/pip/wheels/d7/e7/c8/153284a6e5e5c3fd4da42a8453175b45e2e185e8b5a09ced06
# Successfully built foolbox
# Installing collected packages: smmap2, gitdb2, GitPython, foolbox
# Successfully installed GitPython-2.1.11 foolbox-1.8.0 gitdb2-2.0.5 smmap2-2.0.5

# %% [markdown]
# ##** MNIST 0 Vs All  **##

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

import numpy as np 
from src.config import Configuration as Cfg
from src.models.svm import SVM


DATASET = "mnist"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/mnist/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/mnist/ISO_FOREST/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.mnist_val_frac = 0.1
Cfg.mnist_normal = 0
Cfg.mnist_outlier = -1


 # SVM parameters
Cfg.svm_nu = 0.1
Cfg.svm_GridSearchCV = 1

for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    
    # initialize OC-SVM
    ocsvm = SVM(loss="OneClassSVM", dataset=DATASET, kernel="rbf")

    # train OC-SVM model
    ocsvm.fit(GridSearch=Cfg.svm_GridSearchCV)

    # predict scores
    auc_roc = ocsvm.predict(which_set='test')
   
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    print("========================================================================",)
    AUC.append(auc_roc)

    
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean*100 ,"+/-",auc_roc_std*100)
print("========================================================================")
# Out:
# Using TensorFlow backend.
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/utils/visualization/mosaic_plot.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-6569f4f7c1be>", line 10, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')  # or 'PS', 'PDF', 'SVG'
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6374, 28, 28, 1)
# The shape of POS data :  (63, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.78006
# Starting prediction...
# Total elapsed time: 0.77609
# Starting prediction...
# Total elapsed time: 0.780618
# Starting prediction...
# Total elapsed time: 0.782565
# Starting prediction...
# Total elapsed time: 0.800366
# Starting prediction...
# Total elapsed time: 0.919966
# Starting prediction...
# Total elapsed time: 2.16792
# Starting prediction...
# Total elapsed time: 6.65066
# Starting prediction...
# Total elapsed time: 8.55329
# Starting prediction...
# Total elapsed time: 8.70956
# Total elapsed time: 8.71016
# Starting prediction...
# Total elapsed time: 6.99687
# ========================================================================
# AUROC:  0.9669418578605483
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   56
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6374, 28, 28, 1)
# The shape of POS data :  (63, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.77827
# Starting prediction...
# Total elapsed time: 0.772313
# Starting prediction...
# Total elapsed time: 0.786532
# Starting prediction...
# Total elapsed time: 0.802843
# Starting prediction...
# Total elapsed time: 0.822423
# Starting prediction...
# Total elapsed time: 0.918804
# Starting prediction...
# Total elapsed time: 2.18301
# Starting prediction...
# Total elapsed time: 6.59708
# Starting prediction...
# Total elapsed time: 8.33536
# Starting prediction...
# Total elapsed time: 8.59538
# Total elapsed time: 8.59597
# Starting prediction...
# Total elapsed time: 7.00746
# ========================================================================
# AUROC:  0.9736022314765936
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   81
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6374, 28, 28, 1)
# The shape of POS data :  (63, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.782445
# Starting prediction...
# Total elapsed time: 0.780404
# Starting prediction...
# Total elapsed time: 0.78507
# Starting prediction...
# Total elapsed time: 0.777317
# Starting prediction...
# Total elapsed time: 0.803817
# Starting prediction...
# Total elapsed time: 0.919281
# Starting prediction...
# Total elapsed time: 2.18937
# Starting prediction...
# Total elapsed time: 6.81782
# Starting prediction...
# Total elapsed time: 8.3569
# Starting prediction...
# Total elapsed time: 8.39779
# Total elapsed time: 8.39848
# Starting prediction...
# Total elapsed time: 6.99622
# ========================================================================
# AUROC:  0.9674916329047032
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   67
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6374, 28, 28, 1)
# The shape of POS data :  (63, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.787271
# Starting prediction...
# Total elapsed time: 0.773828
# Starting prediction...
# Total elapsed time: 0.787144
# Starting prediction...
# Total elapsed time: 0.787983
# Starting prediction...
# Total elapsed time: 0.82145
# Starting prediction...
# Total elapsed time: 0.918617
# Starting prediction...
# Total elapsed time: 2.17801
# Starting prediction...
# Total elapsed time: 6.61061
# Starting prediction...
# Total elapsed time: 8.44586
# Starting prediction...
# Total elapsed time: 8.32205
# Total elapsed time: 8.32264
# Starting prediction...
# Total elapsed time: 7.03276
# ========================================================================
# AUROC:  0.9693529446303798
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   33
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6374, 28, 28, 1)
# The shape of POS data :  (63, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.772785
# Starting prediction...
# Total elapsed time: 0.780397
# Starting prediction...
# Total elapsed time: 0.789429
# Starting prediction...
# Total elapsed time: 0.790208
# Starting prediction...
# Total elapsed time: 0.808419
# Starting prediction...
# Total elapsed time: 0.914559
# Starting prediction...
# Total elapsed time: 2.18063
# Starting prediction...
# Total elapsed time: 6.528
# Starting prediction...
# Total elapsed time: 8.4694
# Starting prediction...
# Total elapsed time: 8.42826
# Total elapsed time: 8.42853
# Starting prediction...
# Total elapsed time: 6.97825
# ========================================================================
# AUROC:  0.9654047325672039
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   25
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6374, 28, 28, 1)
# The shape of POS data :  (63, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.775095
# Starting prediction...
# Total elapsed time: 0.781517
# Starting prediction...
# Total elapsed time: 0.780323
# Starting prediction...
# Total elapsed time: 0.801115
# Starting prediction...
# Total elapsed time: 0.803326
# Starting prediction...
# Total elapsed time: 0.916925
# Starting prediction...
# Total elapsed time: 2.18701
# Starting prediction...
# Total elapsed time: 6.61932
# Starting prediction...
# Total elapsed time: 8.60165
# Starting prediction...
# Total elapsed time: 8.43085
# Total elapsed time: 8.43153
# Starting prediction...
# Total elapsed time: 6.98883
# ========================================================================
# AUROC:  0.9571773806704678
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   90
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6374, 28, 28, 1)
# The shape of POS data :  (63, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.786266
# Starting prediction...
# Total elapsed time: 0.782109
# Starting prediction...
# Total elapsed time: 0.79192
# Starting prediction...
# Total elapsed time: 0.7806
# Starting prediction...
# Total elapsed time: 0.821604
# Starting prediction...
# Total elapsed time: 0.922174
# Starting prediction...
# Total elapsed time: 2.19181
# Starting prediction...
# Total elapsed time: 6.65973
# Starting prediction...
# Total elapsed time: 8.56795
# Starting prediction...
# Total elapsed time: 8.44802
# Total elapsed time: 8.44862
# Starting prediction...
# Total elapsed time: 7.00724
# ========================================================================
# AUROC:  0.9678879472929816
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   77
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6374, 28, 28, 1)
# The shape of POS data :  (63, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.787129
# Starting prediction...
# Total elapsed time: 0.782104
# Starting prediction...
# Total elapsed time: 0.783461
# Starting prediction...
# Total elapsed time: 0.795175
# Starting prediction...
# Total elapsed time: 0.807491
# Starting prediction...
# Total elapsed time: 0.905577
# Starting prediction...
# Total elapsed time: 2.17447
# Starting prediction...
# Total elapsed time: 6.55785
# Starting prediction...
# Total elapsed time: 8.42577
# Starting prediction...
# Total elapsed time: 8.40999
# Total elapsed time: 8.41056
# Starting prediction...
# Total elapsed time: 7.06577
# ========================================================================
# AUROC:  0.9749101013403073
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   15
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6374, 28, 28, 1)
# The shape of POS data :  (63, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.783017
# Starting prediction...
# Total elapsed time: 0.786099
# Starting prediction...
# Total elapsed time: 0.790746
# Starting prediction...
# Total elapsed time: 0.798004
# Starting prediction...
# Total elapsed time: 0.810882
# Starting prediction...
# Total elapsed time: 0.905593
# Starting prediction...
# Total elapsed time: 2.1882
# Starting prediction...
# Total elapsed time: 6.65317
# Starting prediction...
# Total elapsed time: 8.26048
# Starting prediction...
# Total elapsed time: 8.51727
# Total elapsed time: 8.51798
# Starting prediction...
# Total elapsed time: 6.98764
# ========================================================================
# AUROC:  0.9732634607480477
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   11
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6374, 28, 28, 1)
# The shape of POS data :  (63, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.77442
# Starting prediction...
# Total elapsed time: 0.7845
# Starting prediction...
# Total elapsed time: 0.787032
# Starting prediction...
# Total elapsed time: 0.795756
# Starting prediction...
# Total elapsed time: 0.80672
# Starting prediction...
# Total elapsed time: 0.912234
# Starting prediction...
# Total elapsed time: 2.18459
# Starting prediction...
# Total elapsed time: 6.79928
# Starting prediction...
# Total elapsed time: 8.54897
# Starting prediction...
# Total elapsed time: 8.59804
# Total elapsed time: 8.59874
# Starting prediction...
# Total elapsed time: 6.98628
# ========================================================================
# AUROC:  0.9592579558266696
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.9669418578605483, 0.9736022314765936, 0.9674916329047032, 0.9693529446303798, 0.9654047325672039, 0.9571773806704678, 0.9678879472929816, 0.9749101013403073, 0.9732634607480477, 0.9592579558266696]
# AUROC ===== 96.75290245317903 +/- 0.5550939502294929
# ========================================================================

# %% [markdown]
# ##** MNIST 1 Vs All  **##

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

import numpy as np 
from src.config import Configuration as Cfg
from src.models.svm import SVM


DATASET = "mnist"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/mnist/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/mnist/ISO_FOREST/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.mnist_val_frac = 0.1
Cfg.mnist_normal = 1
Cfg.mnist_outlier = -1


 # SVM parameters
Cfg.svm_nu = 0.1
Cfg.svm_GridSearchCV = 1

for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    
    # initialize OC-SVM
    ocsvm = SVM(loss="OneClassSVM", dataset=DATASET, kernel="rbf")

    # train OC-SVM model
    ocsvm.fit(GridSearch=Cfg.svm_GridSearchCV)

    # predict scores
    auc_roc = ocsvm.predict(which_set='test')
   
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    print("========================================================================",)
    AUC.append(auc_roc)

    
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean*100 ,"+/-",auc_roc_std*100)
print("========================================================================")
# Out:
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (7275, 28, 28, 1)
# The shape of POS data :  (72, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 1.01505
# Starting prediction...
# Total elapsed time: 0.997761
# Starting prediction...
# Total elapsed time: 1.01082
# Starting prediction...
# Total elapsed time: 1.01727
# Starting prediction...
# Total elapsed time: 1.0293
# Starting prediction...
# Total elapsed time: 1.03399
# Starting prediction...
# Total elapsed time: 1.09319
# Starting prediction...
# Total elapsed time: 1.36213
# Starting prediction...
# Total elapsed time: 3.0816
# Starting prediction...
# Total elapsed time: 7.05528
# Total elapsed time: 7.0559
# Starting prediction...
# Total elapsed time: 9.05326
# ========================================================================
# AUROC:  0.9930706344403707
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   56
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (7275, 28, 28, 1)
# The shape of POS data :  (72, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 1.00262
# Starting prediction...
# Total elapsed time: 0.989482
# Starting prediction...
# Total elapsed time: 1.0325
# Starting prediction...
# Total elapsed time: 1.0107
# Starting prediction...
# Total elapsed time: 1.02141
# Starting prediction...
# Total elapsed time: 1.03996
# Starting prediction...
# Total elapsed time: 1.07465
# Starting prediction...
# Total elapsed time: 1.35352
# Starting prediction...
# Total elapsed time: 3.06657
# Starting prediction...
# Total elapsed time: 7.02405
# Total elapsed time: 7.02468
# Starting prediction...
# Total elapsed time: 9.01866
# ========================================================================
# AUROC:  0.9814182024984577
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   81
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (7275, 28, 28, 1)
# The shape of POS data :  (72, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 1.00356
# Starting prediction...
# Total elapsed time: 1.00609
# Starting prediction...
# Total elapsed time: 1.02026
# Starting prediction...
# Total elapsed time: 1.00958
# Starting prediction...
# Total elapsed time: 1.01283
# Starting prediction...
# Total elapsed time: 1.04545
# Starting prediction...
# Total elapsed time: 1.07393
# Starting prediction...
# Total elapsed time: 1.35504
# Starting prediction...
# Total elapsed time: 3.01963
# Starting prediction...
# Total elapsed time: 6.79253
# Total elapsed time: 6.79274
# Starting prediction...
# Total elapsed time: 9.03173
# ========================================================================
# AUROC:  0.9874522863972857
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   67
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (7275, 28, 28, 1)
# The shape of POS data :  (72, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 1.01156
# Starting prediction...
# Total elapsed time: 1.0034
# Starting prediction...
# Total elapsed time: 1.01665
# Starting prediction...
# Total elapsed time: 1.01204
# Starting prediction...
# Total elapsed time: 1.00109
# Starting prediction...
# Total elapsed time: 1.03357
# Starting prediction...
# Total elapsed time: 1.06233
# Starting prediction...
# Total elapsed time: 1.35025
# Starting prediction...
# Total elapsed time: 3.01289
# Starting prediction...
# Total elapsed time: 6.94828
# Total elapsed time: 6.94851
# Starting prediction...
# Total elapsed time: 9.03744
# ========================================================================
# AUROC:  0.9926538671023966
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   33
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (7275, 28, 28, 1)
# The shape of POS data :  (72, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 1.00603
# Starting prediction...
# Total elapsed time: 1.01219
# Starting prediction...
# Total elapsed time: 1.00378
# Starting prediction...
# Total elapsed time: 1.01108
# Starting prediction...
# Total elapsed time: 1.01623
# Starting prediction...
# Total elapsed time: 1.01616
# Starting prediction...
# Total elapsed time: 1.08147
# Starting prediction...
# Total elapsed time: 1.35876
# Starting prediction...
# Total elapsed time: 3.05168
# Starting prediction...
# Total elapsed time: 7.02967
# Total elapsed time: 7.03036
# Starting prediction...
# Total elapsed time: 9.08245
# ========================================================================
# AUROC:  0.9948692416295009
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   25
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (7275, 28, 28, 1)
# The shape of POS data :  (72, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 1.00214
# Starting prediction...
# Total elapsed time: 1.00886
# Starting prediction...
# Total elapsed time: 1.00925
# Starting prediction...
# Total elapsed time: 1.01461
# Starting prediction...
# Total elapsed time: 1.0239
# Starting prediction...
# Total elapsed time: 1.02938
# Starting prediction...
# Total elapsed time: 1.06563
# Starting prediction...
# Total elapsed time: 1.36079
# Starting prediction...
# Total elapsed time: 3.0625
# Starting prediction...
# Total elapsed time: 7.00429
# Total elapsed time: 7.00488
# Starting prediction...
# Total elapsed time: 8.98743
# ========================================================================
# AUROC:  0.9936133708224335
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   90
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (7275, 28, 28, 1)
# The shape of POS data :  (72, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 1.00531
# Starting prediction...
# Total elapsed time: 1.01559
# Starting prediction...
# Total elapsed time: 1.01392
# Starting prediction...
# Total elapsed time: 1.00784
# Starting prediction...
# Total elapsed time: 1.01798
# Starting prediction...
# Total elapsed time: 1.03126
# Starting prediction...
# Total elapsed time: 1.06875
# Starting prediction...
# Total elapsed time: 1.35591
# Starting prediction...
# Total elapsed time: 3.0327
# Starting prediction...
# Total elapsed time: 6.84006
# Total elapsed time: 6.8403
# Starting prediction...
# Total elapsed time: 9.04847
# ========================================================================
# AUROC:  0.9897081480423834
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   77
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (7275, 28, 28, 1)
# The shape of POS data :  (72, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 1.00599
# Starting prediction...
# Total elapsed time: 1.01414
# Starting prediction...
# Total elapsed time: 1.00523
# Starting prediction...
# Total elapsed time: 1.01467
# Starting prediction...
# Total elapsed time: 1.01572
# Starting prediction...
# Total elapsed time: 1.03385
# Starting prediction...
# Total elapsed time: 1.07405
# Starting prediction...
# Total elapsed time: 1.38386
# Starting prediction...
# Total elapsed time: 2.95761
# Starting prediction...
# Total elapsed time: 6.91628
# Total elapsed time: 6.91691
# Starting prediction...
# Total elapsed time: 9.04707
# ========================================================================
# AUROC:  0.9938314025787027
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   15
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (7275, 28, 28, 1)
# The shape of POS data :  (72, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 1.00844
# Starting prediction...
# Total elapsed time: 0.990945
# Starting prediction...
# Total elapsed time: 1.01085
# Starting prediction...
# Total elapsed time: 1.0174
# Starting prediction...
# Total elapsed time: 1.00815
# Starting prediction...
# Total elapsed time: 1.03439
# Starting prediction...
# Total elapsed time: 1.08332
# Starting prediction...
# Total elapsed time: 1.35995
# Starting prediction...
# Total elapsed time: 3.04686
# Starting prediction...
# Total elapsed time: 6.97087
# Total elapsed time: 6.97112
# Starting prediction...
# Total elapsed time: 9.06213
# ========================================================================
# AUROC:  0.9961562469200697
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   11
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (7275, 28, 28, 1)
# The shape of POS data :  (72, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 1.00785
# Starting prediction...
# Total elapsed time: 1.0078
# Starting prediction...
# Total elapsed time: 1.01434
# Starting prediction...
# Total elapsed time: 0.993494
# Starting prediction...
# Total elapsed time: 1.01501
# Starting prediction...
# Total elapsed time: 1.03507
# Starting prediction...
# Total elapsed time: 1.07357
# Starting prediction...
# Total elapsed time: 1.34616
# Starting prediction...
# Total elapsed time: 3.0393
# Starting prediction...
# Total elapsed time: 7.03805
# Total elapsed time: 7.03868
# Starting prediction...
# Total elapsed time: 9.0714
# ========================================================================
# AUROC:  0.9932020165021591
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.9930706344403707, 0.9814182024984577, 0.9874522863972857, 0.9926538671023966, 0.9948692416295009, 0.9936133708224335, 0.9897081480423834, 0.9938314025787027, 0.9961562469200697, 0.9932020165021591]
# AUROC ===== 99.1597541693376 +/- 0.4132451774127072
# ========================================================================

# %% [markdown]
# ##** MNIST 2 Vs All  **##

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

import numpy as np 
from src.config import Configuration as Cfg
from src.models.svm import SVM


DATASET = "mnist"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/mnist/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/mnist/ISO_FOREST/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.mnist_val_frac = 0.1
Cfg.mnist_normal = 2
Cfg.mnist_outlier = -1


 # SVM parameters
Cfg.svm_nu = 0.1
Cfg.svm_GridSearchCV = 1

for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    
    # initialize OC-SVM
    ocsvm = SVM(loss="OneClassSVM", dataset=DATASET, kernel="rbf")

    # train OC-SVM model
    ocsvm.fit(GridSearch=Cfg.svm_GridSearchCV)

    # predict scores
    auc_roc = ocsvm.predict(which_set='test')
   
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    print("========================================================================",)
    AUC.append(auc_roc)

    
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean*100 ,"+/-",auc_roc_std*100)
print("========================================================================")
# Out:
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  2
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6458, 28, 28, 1)
# The shape of POS data :  (63, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.800789
# Starting prediction...
# Total elapsed time: 0.797592
# Starting prediction...
# Total elapsed time: 0.807726
# Starting prediction...
# Total elapsed time: 0.813784
# Starting prediction...
# Total elapsed time: 0.838103
# Starting prediction...
# Total elapsed time: 0.981088
# Starting prediction...
# Total elapsed time: 2.90245
# Starting prediction...
# Total elapsed time: 8.26874
# Starting prediction...
# Total elapsed time: 8.42366
# Starting prediction...
# Total elapsed time: 8.55487
# Total elapsed time: 8.55547
# Starting prediction...
# Total elapsed time: 7.18617
# ========================================================================
# AUROC:  0.7920488930165673
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  2
# [INFO:] Random Seed used is   56
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6458, 28, 28, 1)
# The shape of POS data :  (63, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.804155
# Starting prediction...
# Total elapsed time: 0.801523
# Starting prediction...
# Total elapsed time: 0.817767
# Starting prediction...
# Total elapsed time: 0.810171
# Starting prediction...
# Total elapsed time: 0.838017
# Starting prediction...
# Total elapsed time: 0.974651
# Starting prediction...
# Total elapsed time: 2.90567
# Starting prediction...
# Total elapsed time: 8.58692
# Starting prediction...
# Total elapsed time: 8.84224
# Starting prediction...
# Total elapsed time: 8.79975
# Total elapsed time: 8.80052
# Starting prediction...
# Total elapsed time: 7.183
# ========================================================================
# AUROC:  0.8132621806814235
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  2
# [INFO:] Random Seed used is   81
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6458, 28, 28, 1)
# The shape of POS data :  (63, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.800347
# Starting prediction...
# Total elapsed time: 0.795251
# Starting prediction...
# Total elapsed time: 0.807364
# Starting prediction...
# Total elapsed time: 0.808483
# Starting prediction...
# Total elapsed time: 0.836861
# Starting prediction...
# Total elapsed time: 0.978577
# Starting prediction...
# Total elapsed time: 2.89752
# Starting prediction...
# Total elapsed time: 8.39349
# Starting prediction...
# Total elapsed time: 8.74787
# Starting prediction...
# Total elapsed time: 8.72847
# Total elapsed time: 8.72867
# Starting prediction...
# Total elapsed time: 7.18506
# ========================================================================
# AUROC:  0.8434075316815962
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  2
# [INFO:] Random Seed used is   67
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6458, 28, 28, 1)
# The shape of POS data :  (63, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.800869
# Starting prediction...
# Total elapsed time: 0.812488
# Starting prediction...
# Total elapsed time: 0.804687
# Starting prediction...
# Total elapsed time: 0.821919
# Starting prediction...
# Total elapsed time: 0.822244
# Starting prediction...
# Total elapsed time: 0.976191
# Starting prediction...
# Total elapsed time: 2.90875
# Starting prediction...
# Total elapsed time: 8.49701
# Starting prediction...
# Total elapsed time: 8.66875
# Starting prediction...
# Total elapsed time: 8.65553
# Total elapsed time: 8.65616
# Starting prediction...
# Total elapsed time: 7.18836
# ========================================================================
# AUROC:  0.7954642140267832
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  2
# [INFO:] Random Seed used is   33
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6458, 28, 28, 1)
# The shape of POS data :  (63, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.799191
# Starting prediction...
# Total elapsed time: 0.805138
# Starting prediction...
# Total elapsed time: 0.808864
# Starting prediction...
# Total elapsed time: 0.815621
# Starting prediction...
# Total elapsed time: 0.842098
# Starting prediction...
# Total elapsed time: 0.986975
# Starting prediction...
# Total elapsed time: 2.91172
# Starting prediction...
# Total elapsed time: 8.28028
# Starting prediction...
# Total elapsed time: 8.66689
# Starting prediction...
# Total elapsed time: 8.72945
# Total elapsed time: 8.72967
# Starting prediction...
# Total elapsed time: 7.18405
# ========================================================================
# AUROC:  0.7529086273828148
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  2
# [INFO:] Random Seed used is   25
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6458, 28, 28, 1)
# The shape of POS data :  (63, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.802658
# Starting prediction...
# Total elapsed time: 0.79557
# Starting prediction...
# Total elapsed time: 0.807251
# Starting prediction...
# Total elapsed time: 0.807555
# Starting prediction...
# Total elapsed time: 0.849209
# Starting prediction...
# Total elapsed time: 0.973077
# Starting prediction...
# Total elapsed time: 2.90279
# Starting prediction...
# Total elapsed time: 8.69985
# Starting prediction...
# Total elapsed time: 8.77817
# Starting prediction...
# Total elapsed time: 8.96093
# Total elapsed time: 8.9612
# Starting prediction...
# Total elapsed time: 7.18303
# ========================================================================
# AUROC:  0.7766269853800246
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  2
# [INFO:] Random Seed used is   90
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6458, 28, 28, 1)
# The shape of POS data :  (63, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.810229
# Starting prediction...
# Total elapsed time: 0.805852
# Starting prediction...
# Total elapsed time: 0.811487
# Starting prediction...
# Total elapsed time: 0.815985
# Starting prediction...
# Total elapsed time: 0.826089
# Starting prediction...
# Total elapsed time: 0.990858
# Starting prediction...
# Total elapsed time: 2.91251
# Starting prediction...
# Total elapsed time: 8.38452
# Starting prediction...
# Total elapsed time: 8.70104
# Starting prediction...
# Total elapsed time: 8.81251
# Total elapsed time: 8.81275
# Starting prediction...
# Total elapsed time: 7.02531
# ========================================================================
# AUROC:  0.7843239485575252
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  2
# [INFO:] Random Seed used is   77
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6458, 28, 28, 1)
# The shape of POS data :  (63, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.804398
# Starting prediction...
# Total elapsed time: 0.78172
# Starting prediction...
# Total elapsed time: 0.807469
# Starting prediction...
# Total elapsed time: 0.803419
# Starting prediction...
# Total elapsed time: 0.828198
# Starting prediction...
# Total elapsed time: 0.973428
# Starting prediction...
# Total elapsed time: 2.91729
# Starting prediction...
# Total elapsed time: 8.43463
# Starting prediction...
# Total elapsed time: 8.75393
# Starting prediction...
# Total elapsed time: 8.74066
# Total elapsed time: 8.7409
# Starting prediction...
# Total elapsed time: 7.16961
# ========================================================================
# AUROC:  0.8003046383647798
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  2
# [INFO:] Random Seed used is   15
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6458, 28, 28, 1)
# The shape of POS data :  (63, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.804353
# Starting prediction...
# Total elapsed time: 0.814461
# Starting prediction...
# Total elapsed time: 0.808207
# Starting prediction...
# Total elapsed time: 0.80738
# Starting prediction...
# Total elapsed time: 0.845507
# Starting prediction...
# Total elapsed time: 0.960301
# Starting prediction...
# Total elapsed time: 2.87534
# Starting prediction...
# Total elapsed time: 8.62674
# Starting prediction...
# Total elapsed time: 8.91
# Starting prediction...
# Total elapsed time: 8.81049
# Total elapsed time: 8.81117
# Starting prediction...
# Total elapsed time: 7.21869
# ========================================================================
# AUROC:  0.7952608799109927
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  2
# [INFO:] Random Seed used is   11
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6458, 28, 28, 1)
# The shape of POS data :  (63, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.801964
# Starting prediction...
# Total elapsed time: 0.799084
# Starting prediction...
# Total elapsed time: 0.812928
# Starting prediction...
# Total elapsed time: 0.809121
# Starting prediction...
# Total elapsed time: 0.842094
# Starting prediction...
# Total elapsed time: 0.974857
# Starting prediction...
# Total elapsed time: 2.90103
# Starting prediction...
# Total elapsed time: 8.53894
# Starting prediction...
# Total elapsed time: 9.02569
# Starting prediction...
# Total elapsed time: 8.92955
# Total elapsed time: 8.93026
# Starting prediction...
# Total elapsed time: 7.20525
# ========================================================================
# AUROC:  0.7804942348919404
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.7920488930165673, 0.8132621806814235, 0.8434075316815962, 0.7954642140267832, 0.7529086273828148, 0.7766269853800246, 0.7843239485575252, 0.8003046383647798, 0.7952608799109927, 0.7804942348919404]
# AUROC ===== 79.34102133894447 +/- 2.2632499942496844
# ========================================================================

# %% [markdown]
# ##** MNIST 3 Vs All  **##

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

import numpy as np 
from src.config import Configuration as Cfg
from src.models.svm import SVM


DATASET = "mnist"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/mnist/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/mnist/ISO_FOREST/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.mnist_val_frac = 0.1
Cfg.mnist_normal = 3
Cfg.mnist_outlier = -1


 # SVM parameters
Cfg.svm_nu = 0.1
Cfg.svm_GridSearchCV = 1

for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    
    # initialize OC-SVM
    ocsvm = SVM(loss="OneClassSVM", dataset=DATASET, kernel="rbf")

    # train OC-SVM model
    ocsvm.fit(GridSearch=Cfg.svm_GridSearchCV)

    # predict scores
    auc_roc = ocsvm.predict(which_set='test')
   
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    print("========================================================================",)
    AUC.append(auc_roc)

    
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean*100 ,"+/-",auc_roc_std*100)
print("========================================================================")
# Out:
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (65, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.836681
# Starting prediction...
# Total elapsed time: 0.837619
# Starting prediction...
# Total elapsed time: 0.836501
# Starting prediction...
# Total elapsed time: 0.841615
# Starting prediction...
# Total elapsed time: 0.866907
# Starting prediction...
# Total elapsed time: 0.965334
# Starting prediction...
# Total elapsed time: 2.2697
# Starting prediction...
# Total elapsed time: 7.6108
# Starting prediction...
# Total elapsed time: 9.34147
# Starting prediction...
# Total elapsed time: 9.33473
# Total elapsed time: 9.33543
# Starting prediction...
# Total elapsed time: 7.46553
# ========================================================================
# AUROC:  0.8759063730450851
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO:] Random Seed used is   56
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (65, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.825801
# Starting prediction...
# Total elapsed time: 0.84417
# Starting prediction...
# Total elapsed time: 0.842536
# Starting prediction...
# Total elapsed time: 0.852888
# Starting prediction...
# Total elapsed time: 0.865398
# Starting prediction...
# Total elapsed time: 0.958613
# Starting prediction...
# Total elapsed time: 2.26335
# Starting prediction...
# Total elapsed time: 7.35387
# Starting prediction...
# Total elapsed time: 9.3939
# Starting prediction...
# Total elapsed time: 9.14778
# Total elapsed time: 9.14858
# Starting prediction...
# Total elapsed time: 7.56534
# ========================================================================
# AUROC:  0.834281918085822
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO:] Random Seed used is   81
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (65, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.840214
# Starting prediction...
# Total elapsed time: 0.835099
# Starting prediction...
# Total elapsed time: 0.840785
# Starting prediction...
# Total elapsed time: 0.844939
# Starting prediction...
# Total elapsed time: 0.86684
# Starting prediction...
# Total elapsed time: 0.949061
# Starting prediction...
# Total elapsed time: 2.25251
# Starting prediction...
# Total elapsed time: 7.39778
# Starting prediction...
# Total elapsed time: 9.12846
# Starting prediction...
# Total elapsed time: 9.10404
# Total elapsed time: 9.1043
# Starting prediction...
# Total elapsed time: 7.51181
# ========================================================================
# AUROC:  0.8639090251861116
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO:] Random Seed used is   67
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (65, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.836621
# Starting prediction...
# Total elapsed time: 0.842809
# Starting prediction...
# Total elapsed time: 0.837934
# Starting prediction...
# Total elapsed time: 0.835947
# Starting prediction...
# Total elapsed time: 0.845954
# Starting prediction...
# Total elapsed time: 0.970183
# Starting prediction...
# Total elapsed time: 2.24136
# Starting prediction...
# Total elapsed time: 7.42207
# Starting prediction...
# Total elapsed time: 9.28239
# Starting prediction...
# Total elapsed time: 9.35776
# Total elapsed time: 9.35844
# Starting prediction...
# Total elapsed time: 7.49583
# ========================================================================
# AUROC:  0.8749092044035864
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO:] Random Seed used is   33
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (65, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.830521
# Starting prediction...
# Total elapsed time: 0.836597
# Starting prediction...
# Total elapsed time: 0.85016
# Starting prediction...
# Total elapsed time: 0.854691
# Starting prediction...
# Total elapsed time: 0.855974
# Starting prediction...
# Total elapsed time: 0.950184
# Starting prediction...
# Total elapsed time: 2.28492
# Starting prediction...
# Total elapsed time: 7.44071
# Starting prediction...
# Total elapsed time: 9.14371
# Starting prediction...
# Total elapsed time: 9.1662
# Total elapsed time: 9.16694
# Starting prediction...
# Total elapsed time: 7.49895
# ========================================================================
# AUROC:  0.8639600447188062
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO:] Random Seed used is   25
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (65, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.836851
# Starting prediction...
# Total elapsed time: 0.831062
# Starting prediction...
# Total elapsed time: 0.839334
# Starting prediction...
# Total elapsed time: 0.844149
# Starting prediction...
# Total elapsed time: 0.859331
# Starting prediction...
# Total elapsed time: 0.963179
# Starting prediction...
# Total elapsed time: 2.25116
# Starting prediction...
# Total elapsed time: 7.36265
# Starting prediction...
# Total elapsed time: 9.32704
# Starting prediction...
# Total elapsed time: 9.13085
# Total elapsed time: 9.13109
# Starting prediction...
# Total elapsed time: 7.50923
# ========================================================================
# AUROC:  0.8510699703494872
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO:] Random Seed used is   90
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (65, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.83537
# Starting prediction...
# Total elapsed time: 0.832885
# Starting prediction...
# Total elapsed time: 0.841635
# Starting prediction...
# Total elapsed time: 0.847421
# Starting prediction...
# Total elapsed time: 0.856319
# Starting prediction...
# Total elapsed time: 0.958781
# Starting prediction...
# Total elapsed time: 2.24305
# Starting prediction...
# Total elapsed time: 7.44886
# Starting prediction...
# Total elapsed time: 9.17875
# Starting prediction...
# Total elapsed time: 9.05866
# Total elapsed time: 9.05892
# Starting prediction...
# Total elapsed time: 7.45746
# ========================================================================
# AUROC:  0.8355436386335263
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO:] Random Seed used is   77
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (65, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.82902
# Starting prediction...
# Total elapsed time: 0.837203
# Starting prediction...
# Total elapsed time: 0.829781
# Starting prediction...
# Total elapsed time: 0.852188
# Starting prediction...
# Total elapsed time: 0.858286
# Starting prediction...
# Total elapsed time: 0.956798
# Starting prediction...
# Total elapsed time: 2.24625
# Starting prediction...
# Total elapsed time: 7.40203
# Starting prediction...
# Total elapsed time: 9.05627
# Starting prediction...
# Total elapsed time: 9.13622
# Total elapsed time: 9.13689
# Starting prediction...
# Total elapsed time: 7.43359
# ========================================================================
# AUROC:  0.8627673059317857
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO:] Random Seed used is   15
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (65, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.835338
# Starting prediction...
# Total elapsed time: 0.830665
# Starting prediction...
# Total elapsed time: 0.843944
# Starting prediction...
# Total elapsed time: 0.825495
# Starting prediction...
# Total elapsed time: 0.860479
# Starting prediction...
# Total elapsed time: 0.964162
# Starting prediction...
# Total elapsed time: 2.25618
# Starting prediction...
# Total elapsed time: 7.40725
# Starting prediction...
# Total elapsed time: 8.88903
# Starting prediction...
# Total elapsed time: 9.11416
# Total elapsed time: 9.11472
# Starting prediction...
# Total elapsed time: 7.45039
# ========================================================================
# AUROC:  0.8669877090598762
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO:] Random Seed used is   11
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (65, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.838559
# Starting prediction...
# Total elapsed time: 0.831529
# Starting prediction...
# Total elapsed time: 0.826119
# Starting prediction...
# Total elapsed time: 0.840217
# Starting prediction...
# Total elapsed time: 0.857411
# Starting prediction...
# Total elapsed time: 0.952998
# Starting prediction...
# Total elapsed time: 2.27637
# Starting prediction...
# Total elapsed time: 7.33771
# Starting prediction...
# Total elapsed time: 9.19289
# Starting prediction...
# Total elapsed time: 8.92041
# Total elapsed time: 8.92109
# Starting prediction...
# Total elapsed time: 7.42896
# ========================================================================
# AUROC:  0.8592726696556419
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.8759063730450851, 0.834281918085822, 0.8639090251861116, 0.8749092044035864, 0.8639600447188062, 0.8510699703494872, 0.8355436386335263, 0.8627673059317857, 0.8669877090598762, 0.8592726696556419]
# AUROC ===== 85.8860785906973 +/- 1.3746182275914889
# ========================================================================

# %% [markdown]
# ##** MNIST 4 Vs All  **##

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

import numpy as np 
from src.config import Configuration as Cfg
from src.models.svm import SVM


DATASET = "mnist"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/mnist/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/mnist/ISO_FOREST/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.mnist_val_frac = 0.1
Cfg.mnist_normal = 4
Cfg.mnist_outlier = -1


 # SVM parameters
Cfg.svm_nu = 0.1
Cfg.svm_GridSearchCV = 1

for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    
    # initialize OC-SVM
    ocsvm = SVM(loss="OneClassSVM", dataset=DATASET, kernel="rbf")

    # train OC-SVM model
    ocsvm.fit(GridSearch=Cfg.svm_GridSearchCV)

    # predict scores
    auc_roc = ocsvm.predict(which_set='test')
   
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    print("========================================================================",)
    AUC.append(auc_roc)

    
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean*100 ,"+/-",auc_roc_std*100)
print("========================================================================")
# Out:
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  4
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (62, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.766201
# Starting prediction...
# Total elapsed time: 0.756936
# Starting prediction...
# Total elapsed time: 0.770166
# Starting prediction...
# Total elapsed time: 0.768598
# Starting prediction...
# Total elapsed time: 0.79177
# Starting prediction...
# Total elapsed time: 0.858479
# Starting prediction...
# Total elapsed time: 1.6976
# Starting prediction...
# Total elapsed time: 5.82997
# Starting prediction...
# Total elapsed time: 8.10871
# Starting prediction...
# Total elapsed time: 8.15865
# Total elapsed time: 8.15886
# Starting prediction...
# Total elapsed time: 6.82729
# ========================================================================
# AUROC:  0.9498329299902952
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  4
# [INFO:] Random Seed used is   56
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (62, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.762057
# Starting prediction...
# Total elapsed time: 0.764299
# Starting prediction...
# Total elapsed time: 0.759838
# Starting prediction...
# Total elapsed time: 0.777777
# Starting prediction...
# Total elapsed time: 0.797378
# Starting prediction...
# Total elapsed time: 0.867039
# Starting prediction...
# Total elapsed time: 1.68356
# Starting prediction...
# Total elapsed time: 5.86206
# Starting prediction...
# Total elapsed time: 8.26336
# Starting prediction...
# Total elapsed time: 8.19623
# Total elapsed time: 8.19688
# Starting prediction...
# Total elapsed time: 6.80617
# ========================================================================
# AUROC:  0.9433214106527263
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  4
# [INFO:] Random Seed used is   81
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (62, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.770212
# Starting prediction...
# Total elapsed time: 0.758448
# Starting prediction...
# Total elapsed time: 0.763547
# Starting prediction...
# Total elapsed time: 0.773701
# Starting prediction...
# Total elapsed time: 0.798339
# Starting prediction...
# Total elapsed time: 0.847391
# Starting prediction...
# Total elapsed time: 1.67954
# Starting prediction...
# Total elapsed time: 5.84689
# Starting prediction...
# Total elapsed time: 7.98873
# Starting prediction...
# Total elapsed time: 8.17858
# Total elapsed time: 8.17939
# Starting prediction...
# Total elapsed time: 6.89783
# ========================================================================
# AUROC:  0.9509147065811356
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  4
# [INFO:] Random Seed used is   67
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (62, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.759645
# Starting prediction...
# Total elapsed time: 0.769003
# Starting prediction...
# Total elapsed time: 0.771486
# Starting prediction...
# Total elapsed time: 0.774661
# Starting prediction...
# Total elapsed time: 0.784015
# Starting prediction...
# Total elapsed time: 0.843568
# Starting prediction...
# Total elapsed time: 1.70144
# Starting prediction...
# Total elapsed time: 5.77124
# Starting prediction...
# Total elapsed time: 8.10701
# Starting prediction...
# Total elapsed time: 8.10155
# Total elapsed time: 8.10212
# Starting prediction...
# Total elapsed time: 6.80284
# ========================================================================
# AUROC:  0.9485983317568148
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  4
# [INFO:] Random Seed used is   33
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (62, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.760059
# Starting prediction...
# Total elapsed time: 0.766895
# Starting prediction...
# Total elapsed time: 0.759879
# Starting prediction...
# Total elapsed time: 0.77047
# Starting prediction...
# Total elapsed time: 0.79547
# Starting prediction...
# Total elapsed time: 0.852489
# Starting prediction...
# Total elapsed time: 1.6861
# Starting prediction...
# Total elapsed time: 5.94959
# Starting prediction...
# Total elapsed time: 8.10483
# Starting prediction...
# Total elapsed time: 8.18846
# Total elapsed time: 8.18901
# Starting prediction...
# Total elapsed time: 6.86575
# ========================================================================
# AUROC:  0.9126150192935589
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  4
# [INFO:] Random Seed used is   25
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (62, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.767075
# Starting prediction...
# Total elapsed time: 0.749434
# Starting prediction...
# Total elapsed time: 0.758085
# Starting prediction...
# Total elapsed time: 0.766618
# Starting prediction...
# Total elapsed time: 0.787941
# Starting prediction...
# Total elapsed time: 0.85951
# Starting prediction...
# Total elapsed time: 1.67828
# Starting prediction...
# Total elapsed time: 5.93199
# Starting prediction...
# Total elapsed time: 8.06818
# Starting prediction...
# Total elapsed time: 8.14228
# Total elapsed time: 8.14295
# Starting prediction...
# Total elapsed time: 6.85772
# ========================================================================
# AUROC:  0.9464185843058224
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  4
# [INFO:] Random Seed used is   90
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (62, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.763304
# Starting prediction...
# Total elapsed time: 0.760155
# Starting prediction...
# Total elapsed time: 0.767185
# Starting prediction...
# Total elapsed time: 0.766131
# Starting prediction...
# Total elapsed time: 0.790016
# Starting prediction...
# Total elapsed time: 0.859402
# Starting prediction...
# Total elapsed time: 1.69137
# Starting prediction...
# Total elapsed time: 5.82049
# Starting prediction...
# Total elapsed time: 8.01617
# Starting prediction...
# Total elapsed time: 8.16927
# Total elapsed time: 8.16948
# Starting prediction...
# Total elapsed time: 6.78104
# ========================================================================
# AUROC:  0.9179406671306262
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  4
# [INFO:] Random Seed used is   77
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (62, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.763221
# Starting prediction...
# Total elapsed time: 0.761379
# Starting prediction...
# Total elapsed time: 0.758295
# Starting prediction...
# Total elapsed time: 0.77039
# Starting prediction...
# Total elapsed time: 0.791839
# Starting prediction...
# Total elapsed time: 0.862073
# Starting prediction...
# Total elapsed time: 1.67023
# Starting prediction...
# Total elapsed time: 5.811
# Starting prediction...
# Total elapsed time: 8.18531
# Starting prediction...
# Total elapsed time: 8.25089
# Total elapsed time: 8.25151
# Starting prediction...
# Total elapsed time: 6.84429
# ========================================================================
# AUROC:  0.9623460169723514
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  4
# [INFO:] Random Seed used is   15
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (62, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.756327
# Starting prediction...
# Total elapsed time: 0.76119
# Starting prediction...
# Total elapsed time: 0.772087
# Starting prediction...
# Total elapsed time: 0.773737
# Starting prediction...
# Total elapsed time: 0.778514
# Starting prediction...
# Total elapsed time: 0.869281
# Starting prediction...
# Total elapsed time: 1.70301
# Starting prediction...
# Total elapsed time: 5.86274
# Starting prediction...
# Total elapsed time: 8.18156
# Starting prediction...
# Total elapsed time: 8.1014
# Total elapsed time: 8.102
# Starting prediction...
# Total elapsed time: 6.79849
# ========================================================================
# AUROC:  0.9538690476190477
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  4
# [INFO:] Random Seed used is   11
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (62, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.765481
# Starting prediction...
# Total elapsed time: 0.757893
# Starting prediction...
# Total elapsed time: 0.776442
# Starting prediction...
# Total elapsed time: 0.770192
# Starting prediction...
# Total elapsed time: 0.782949
# Starting prediction...
# Total elapsed time: 0.839558
# Starting prediction...
# Total elapsed time: 1.67859
# Starting prediction...
# Total elapsed time: 5.87202
# Starting prediction...
# Total elapsed time: 8.27477
# Starting prediction...
# Total elapsed time: 8.09567
# Total elapsed time: 8.09632
# Starting prediction...
# Total elapsed time: 6.83694
# ========================================================================
# AUROC:  0.9328034593319656
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.9498329299902952, 0.9433214106527263, 0.9509147065811356, 0.9485983317568148, 0.9126150192935589, 0.9464185843058224, 0.9179406671306262, 0.9623460169723514, 0.9538690476190477, 0.9328034593319656]
# AUROC ===== 94.18660173634346 +/- 1.512347484893561
# ========================================================================

# %% [markdown]
# ##** MNIST 5 Vs All  **##

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

import numpy as np 
from src.config import Configuration as Cfg
from src.models.svm import SVM


DATASET = "mnist"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/mnist/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/mnist/ISO_FOREST/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.mnist_val_frac = 0.1
Cfg.mnist_normal = 5
Cfg.mnist_outlier = -1


 # SVM parameters
Cfg.svm_nu = 0.1
Cfg.svm_GridSearchCV = 1

for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    
    # initialize OC-SVM
    ocsvm = SVM(loss="OneClassSVM", dataset=DATASET, kernel="rbf")

    # train OC-SVM model
    ocsvm.fit(GridSearch=Cfg.svm_GridSearchCV)

    # predict scores
    auc_roc = ocsvm.predict(which_set='test')
   
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    print("========================================================================",)
    AUC.append(auc_roc)

    
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean*100 ,"+/-",auc_roc_std*100)
print("========================================================================")
# Out:
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  5
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (5828, 28, 28, 1)
# The shape of POS data :  (57, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.652021
# Starting prediction...
# Total elapsed time: 0.653629
# Starting prediction...
# Total elapsed time: 0.654728
# Starting prediction...
# Total elapsed time: 0.657255
# Starting prediction...
# Total elapsed time: 0.684644
# Starting prediction...
# Total elapsed time: 0.777291
# Starting prediction...
# Total elapsed time: 1.9331
# Starting prediction...
# Total elapsed time: 5.96956
# Starting prediction...
# Total elapsed time: 6.98799
# Starting prediction...
# Total elapsed time: 6.8237
# Total elapsed time: 6.82397
# Starting prediction...
# Total elapsed time: 5.85687
# ========================================================================
# AUROC:  0.737487692067333
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  5
# [INFO:] Random Seed used is   56
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (5828, 28, 28, 1)
# The shape of POS data :  (57, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.64927
# Starting prediction...
# Total elapsed time: 0.645347
# Starting prediction...
# Total elapsed time: 0.667791
# Starting prediction...
# Total elapsed time: 0.65665
# Starting prediction...
# Total elapsed time: 0.676301
# Starting prediction...
# Total elapsed time: 0.767874
# Starting prediction...
# Total elapsed time: 1.91965
# Starting prediction...
# Total elapsed time: 5.95033
# Starting prediction...
# Total elapsed time: 6.62253
# Starting prediction...
# Total elapsed time: 6.77022
# Total elapsed time: 6.7709
# Starting prediction...
# Total elapsed time: 5.8424
# ========================================================================
# AUROC:  0.7132350583557778
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  5
# [INFO:] Random Seed used is   81
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (5828, 28, 28, 1)
# The shape of POS data :  (57, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.656893
# Starting prediction...
# Total elapsed time: 0.657605
# Starting prediction...
# Total elapsed time: 0.660768
# Starting prediction...
# Total elapsed time: 0.661033
# Starting prediction...
# Total elapsed time: 0.677868
# Starting prediction...
# Total elapsed time: 0.775754
# Starting prediction...
# Total elapsed time: 1.92522
# Starting prediction...
# Total elapsed time: 6.0673
# Starting prediction...
# Total elapsed time: 6.73865
# Starting prediction...
# Total elapsed time: 6.7628
# Total elapsed time: 6.76344
# Starting prediction...
# Total elapsed time: 5.8566
# ========================================================================
# AUROC:  0.6938579164588676
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  5
# [INFO:] Random Seed used is   67
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (5828, 28, 28, 1)
# The shape of POS data :  (57, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.644903
# Starting prediction...
# Total elapsed time: 0.657838
# Starting prediction...
# Total elapsed time: 0.658289
# Starting prediction...
# Total elapsed time: 0.663977
# Starting prediction...
# Total elapsed time: 0.673033
# Starting prediction...
# Total elapsed time: 0.775968
# Starting prediction...
# Total elapsed time: 1.90668
# Starting prediction...
# Total elapsed time: 5.83294
# Starting prediction...
# Total elapsed time: 6.69723
# Starting prediction...
# Total elapsed time: 6.71957
# Total elapsed time: 6.71976
# Starting prediction...
# Total elapsed time: 5.8189
# ========================================================================
# AUROC:  0.7089622374455076
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  5
# [INFO:] Random Seed used is   33
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (5828, 28, 28, 1)
# The shape of POS data :  (57, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.645503
# Starting prediction...
# Total elapsed time: 0.65562
# Starting prediction...
# Total elapsed time: 0.655616
# Starting prediction...
# Total elapsed time: 0.643954
# Starting prediction...
# Total elapsed time: 0.693585
# Starting prediction...
# Total elapsed time: 0.783324
# Starting prediction...
# Total elapsed time: 1.92207
# Starting prediction...
# Total elapsed time: 6.01764
# Starting prediction...
# Total elapsed time: 6.95349
# Starting prediction...
# Total elapsed time: 7.05216
# Total elapsed time: 7.05283
# Starting prediction...
# Total elapsed time: 5.86488
# ========================================================================
# AUROC:  0.8050463303704543
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  5
# [INFO:] Random Seed used is   25
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (5828, 28, 28, 1)
# The shape of POS data :  (57, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.648887
# Starting prediction...
# Total elapsed time: 0.647767
# Starting prediction...
# Total elapsed time: 0.658656
# Starting prediction...
# Total elapsed time: 0.672253
# Starting prediction...
# Total elapsed time: 0.684507
# Starting prediction...
# Total elapsed time: 0.77173
# Starting prediction...
# Total elapsed time: 1.94941
# Starting prediction...
# Total elapsed time: 5.8037
# Starting prediction...
# Total elapsed time: 6.72573
# Starting prediction...
# Total elapsed time: 6.63458
# Total elapsed time: 6.63526
# Starting prediction...
# Total elapsed time: 5.83551
# ========================================================================
# AUROC:  0.7750577367205543
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  5
# [INFO:] Random Seed used is   90
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (5828, 28, 28, 1)
# The shape of POS data :  (57, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.655041
# Starting prediction...
# Total elapsed time: 0.667362
# Starting prediction...
# Total elapsed time: 0.669199
# Starting prediction...
# Total elapsed time: 0.663895
# Starting prediction...
# Total elapsed time: 0.690465
# Starting prediction...
# Total elapsed time: 0.780142
# Starting prediction...
# Total elapsed time: 1.92647
# Starting prediction...
# Total elapsed time: 5.93583
# Starting prediction...
# Total elapsed time: 6.77613
# Starting prediction...
# Total elapsed time: 6.73472
# Total elapsed time: 6.73541
# Starting prediction...
# Total elapsed time: 5.87446
# ========================================================================
# AUROC:  0.7244527709487278
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  5
# [INFO:] Random Seed used is   77
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (5828, 28, 28, 1)
# The shape of POS data :  (57, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.657355
# Starting prediction...
# Total elapsed time: 0.653929
# Starting prediction...
# Total elapsed time: 0.664516
# Starting prediction...
# Total elapsed time: 0.664317
# Starting prediction...
# Total elapsed time: 0.672981
# Starting prediction...
# Total elapsed time: 0.778632
# Starting prediction...
# Total elapsed time: 1.93006
# Starting prediction...
# Total elapsed time: 5.93243
# Starting prediction...
# Total elapsed time: 6.81307
# Starting prediction...
# Total elapsed time: 6.75807
# Total elapsed time: 6.75829
# Starting prediction...
# Total elapsed time: 5.85602
# ========================================================================
# AUROC:  0.7485364887052028
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  5
# [INFO:] Random Seed used is   15
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (5828, 28, 28, 1)
# The shape of POS data :  (57, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.666611
# Starting prediction...
# Total elapsed time: 0.661161
# Starting prediction...
# Total elapsed time: 0.660337
# Starting prediction...
# Total elapsed time: 0.662465
# Starting prediction...
# Total elapsed time: 0.677535
# Starting prediction...
# Total elapsed time: 0.776411
# Starting prediction...
# Total elapsed time: 1.93059
# Starting prediction...
# Total elapsed time: 5.99183
# Starting prediction...
# Total elapsed time: 6.83143
# Starting prediction...
# Total elapsed time: 6.9534
# Total elapsed time: 6.9537
# Starting prediction...
# Total elapsed time: 5.88157
# ========================================================================
# AUROC:  0.6717768885503018
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  5
# [INFO:] Random Seed used is   11
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (5828, 28, 28, 1)
# The shape of POS data :  (57, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.657273
# Starting prediction...
# Total elapsed time: 0.645703
# Starting prediction...
# Total elapsed time: 0.65952
# Starting prediction...
# Total elapsed time: 0.668744
# Starting prediction...
# Total elapsed time: 0.678449
# Starting prediction...
# Total elapsed time: 0.773641
# Starting prediction...
# Total elapsed time: 1.91715
# Starting prediction...
# Total elapsed time: 5.87036
# Starting prediction...
# Total elapsed time: 6.75595
# Starting prediction...
# Total elapsed time: 6.92616
# Total elapsed time: 6.92681
# Starting prediction...
# Total elapsed time: 5.85973
# ========================================================================
# AUROC:  0.698923441933808
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.737487692067333, 0.7132350583557778, 0.6938579164588676, 0.7089622374455076, 0.8050463303704543, 0.7750577367205543, 0.7244527709487278, 0.7485364887052028, 0.6717768885503018, 0.698923441933808]
# AUROC ===== 72.77336561556534 +/- 3.798264206826011
# ========================================================================

# %% [markdown]
# ##** MNIST 6 Vs All  **##

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

import numpy as np 
from src.config import Configuration as Cfg
from src.models.svm import SVM


DATASET = "mnist"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/mnist/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/mnist/ISO_FOREST/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.mnist_val_frac = 0.1
Cfg.mnist_normal = 6
Cfg.mnist_outlier = -1


 # SVM parameters
Cfg.svm_nu = 0.1
Cfg.svm_GridSearchCV = 1

for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    
    # initialize OC-SVM
    ocsvm = SVM(loss="OneClassSVM", dataset=DATASET, kernel="rbf")

    # train OC-SVM model
    ocsvm.fit(GridSearch=Cfg.svm_GridSearchCV)

    # predict scores
    auc_roc = ocsvm.predict(which_set='test')
   
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    print("========================================================================",)
    AUC.append(auc_roc)

    
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean*100 ,"+/-",auc_roc_std*100)
print("========================================================================")
# Out:
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  6
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6347, 28, 28, 1)
# The shape of POS data :  (62, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.774088
# Starting prediction...
# Total elapsed time: 0.774853
# Starting prediction...
# Total elapsed time: 0.770591
# Starting prediction...
# Total elapsed time: 0.781694
# Starting prediction...
# Total elapsed time: 0.80719
# Starting prediction...
# Total elapsed time: 0.887732
# Starting prediction...
# Total elapsed time: 1.85626
# Starting prediction...
# Total elapsed time: 5.76147
# Starting prediction...
# Total elapsed time: 8.49232
# Starting prediction...
# Total elapsed time: 8.61234
# Total elapsed time: 8.61302
# Starting prediction...
# Total elapsed time: 6.95816
# ========================================================================
# AUROC:  0.9631366953710953
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  6
# [INFO:] Random Seed used is   56
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6347, 28, 28, 1)
# The shape of POS data :  (62, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.768195
# Starting prediction...
# Total elapsed time: 0.776042
# Starting prediction...
# Total elapsed time: 0.783119
# Starting prediction...
# Total elapsed time: 0.776286
# Starting prediction...
# Total elapsed time: 0.8073
# Starting prediction...
# Total elapsed time: 0.883667
# Starting prediction...
# Total elapsed time: 1.83751
# Starting prediction...
# Total elapsed time: 5.76498
# Starting prediction...
# Total elapsed time: 8.32051
# Starting prediction...
# Total elapsed time: 8.29175
# Total elapsed time: 8.29196
# Starting prediction...
# Total elapsed time: 6.81474
# ========================================================================
# AUROC:  0.9498724715270588
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  6
# [INFO:] Random Seed used is   81
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6347, 28, 28, 1)
# The shape of POS data :  (62, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.784737
# Starting prediction...
# Total elapsed time: 0.759668
# Starting prediction...
# Total elapsed time: 0.77536
# Starting prediction...
# Total elapsed time: 0.784148
# Starting prediction...
# Total elapsed time: 0.795771
# Starting prediction...
# Total elapsed time: 0.873528
# Starting prediction...
# Total elapsed time: 1.83682
# Starting prediction...
# Total elapsed time: 5.67748
# Starting prediction...
# Total elapsed time: 8.2828
# Starting prediction...
# Total elapsed time: 8.43733
# Total elapsed time: 8.43812
# Starting prediction...
# Total elapsed time: 6.93589
# ========================================================================
# AUROC:  0.9593539569304619
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  6
# [INFO:] Random Seed used is   67
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6347, 28, 28, 1)
# The shape of POS data :  (62, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.769301
# Starting prediction...
# Total elapsed time: 0.762566
# Starting prediction...
# Total elapsed time: 0.777227
# Starting prediction...
# Total elapsed time: 0.785276
# Starting prediction...
# Total elapsed time: 0.80161
# Starting prediction...
# Total elapsed time: 0.878188
# Starting prediction...
# Total elapsed time: 1.86389
# Starting prediction...
# Total elapsed time: 5.74802
# Starting prediction...
# Total elapsed time: 8.37925
# Starting prediction...
# Total elapsed time: 8.31073
# Total elapsed time: 8.31142
# Starting prediction...
# Total elapsed time: 6.87456
# ========================================================================
# AUROC:  0.944891285133463
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  6
# [INFO:] Random Seed used is   33
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6347, 28, 28, 1)
# The shape of POS data :  (62, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.755593
# Starting prediction...
# Total elapsed time: 0.770732
# Starting prediction...
# Total elapsed time: 0.769298
# Starting prediction...
# Total elapsed time: 0.786797
# Starting prediction...
# Total elapsed time: 0.809894
# Starting prediction...
# Total elapsed time: 0.871109
# Starting prediction...
# Total elapsed time: 1.84553
# Starting prediction...
# Total elapsed time: 5.66766
# Starting prediction...
# Total elapsed time: 8.50327
# Starting prediction...
# Total elapsed time: 8.44306
# Total elapsed time: 8.4437
# Starting prediction...
# Total elapsed time: 6.85377
# ========================================================================
# AUROC:  0.9454713327297908
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  6
# [INFO:] Random Seed used is   25
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6347, 28, 28, 1)
# The shape of POS data :  (62, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.778509
# Starting prediction...
# Total elapsed time: 0.779044
# Starting prediction...
# Total elapsed time: 0.781043
# Starting prediction...
# Total elapsed time: 0.778783
# Starting prediction...
# Total elapsed time: 0.804238
# Starting prediction...
# Total elapsed time: 0.873101
# Starting prediction...
# Total elapsed time: 1.86117
# Starting prediction...
# Total elapsed time: 5.62103
# Starting prediction...
# Total elapsed time: 8.37823
# Starting prediction...
# Total elapsed time: 8.39883
# Total elapsed time: 8.39953
# Starting prediction...
# Total elapsed time: 6.92376
# ========================================================================
# AUROC:  0.9595970307529161
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  6
# [INFO:] Random Seed used is   90
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6347, 28, 28, 1)
# The shape of POS data :  (62, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.777232
# Starting prediction...
# Total elapsed time: 0.778254
# Starting prediction...
# Total elapsed time: 0.778815
# Starting prediction...
# Total elapsed time: 0.776076
# Starting prediction...
# Total elapsed time: 0.803939
# Starting prediction...
# Total elapsed time: 0.877004
# Starting prediction...
# Total elapsed time: 1.85657
# Starting prediction...
# Total elapsed time: 5.6219
# Starting prediction...
# Total elapsed time: 8.25433
# Starting prediction...
# Total elapsed time: 8.36469
# Total elapsed time: 8.36529
# Starting prediction...
# Total elapsed time: 6.93463
# ========================================================================
# AUROC:  0.9662386365867546
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  6
# [INFO:] Random Seed used is   77
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6347, 28, 28, 1)
# The shape of POS data :  (62, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.778652
# Starting prediction...
# Total elapsed time: 0.77812
# Starting prediction...
# Total elapsed time: 0.780924
# Starting prediction...
# Total elapsed time: 0.780773
# Starting prediction...
# Total elapsed time: 0.791207
# Starting prediction...
# Total elapsed time: 0.887512
# Starting prediction...
# Total elapsed time: 1.8385
# Starting prediction...
# Total elapsed time: 5.75959
# Starting prediction...
# Total elapsed time: 8.28938
# Starting prediction...
# Total elapsed time: 8.4851
# Total elapsed time: 8.48566
# Starting prediction...
# Total elapsed time: 6.96277
# ========================================================================
# AUROC:  0.9285119007933862
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  6
# [INFO:] Random Seed used is   15
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6347, 28, 28, 1)
# The shape of POS data :  (62, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.77225
# Starting prediction...
# Total elapsed time: 0.76871
# Starting prediction...
# Total elapsed time: 0.790206
# Starting prediction...
# Total elapsed time: 0.773334
# Starting prediction...
# Total elapsed time: 0.795706
# Starting prediction...
# Total elapsed time: 0.879621
# Starting prediction...
# Total elapsed time: 1.82385
# Starting prediction...
# Total elapsed time: 5.6526
# Starting prediction...
# Total elapsed time: 8.51226
# Starting prediction...
# Total elapsed time: 8.38173
# Total elapsed time: 8.38196
# Starting prediction...
# Total elapsed time: 6.92312
# ========================================================================
# AUROC:  0.9561804120274684
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  6
# [INFO:] Random Seed used is   11
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6347, 28, 28, 1)
# The shape of POS data :  (62, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.774341
# Starting prediction...
# Total elapsed time: 0.776219
# Starting prediction...
# Total elapsed time: 0.784003
# Starting prediction...
# Total elapsed time: 0.783721
# Starting prediction...
# Total elapsed time: 0.799433
# Starting prediction...
# Total elapsed time: 0.879706
# Starting prediction...
# Total elapsed time: 1.84245
# Starting prediction...
# Total elapsed time: 5.71131
# Starting prediction...
# Total elapsed time: 8.3775
# Starting prediction...
# Total elapsed time: 8.35904
# Total elapsed time: 8.35925
# Starting prediction...
# Total elapsed time: 6.91413
# ========================================================================
# AUROC:  0.9415084032263248
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.9631366953710953, 0.9498724715270588, 0.9593539569304619, 0.944891285133463, 0.9454713327297908, 0.9595970307529161, 0.9662386365867546, 0.9285119007933862, 0.9561804120274684, 0.9415084032263248]
# AUROC ===== 95.14762125078718 +/- 1.1012450834248988
# ========================================================================

# %% [markdown]
# ##** MNIST 7 Vs All  **##

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

import numpy as np 
from src.config import Configuration as Cfg
from src.models.svm import SVM


DATASET = "mnist"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/mnist/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/mnist/ISO_FOREST/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.mnist_val_frac = 0.1
Cfg.mnist_normal = 7
Cfg.mnist_outlier = -1


 # SVM parameters
Cfg.svm_nu = 0.1
Cfg.svm_GridSearchCV = 1

for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    
    # initialize OC-SVM
    ocsvm = SVM(loss="OneClassSVM", dataset=DATASET, kernel="rbf")

    # train OC-SVM model
    ocsvm.fit(GridSearch=Cfg.svm_GridSearchCV)

    # predict scores
    auc_roc = ocsvm.predict(which_set='test')
   
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    print("========================================================================",)
    AUC.append(auc_roc)

    
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean*100 ,"+/-",auc_roc_std*100)
print("========================================================================")
# Out:
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  7
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6733, 28, 28, 1)
# The shape of POS data :  (66, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.878095
# Starting prediction...
# Total elapsed time: 0.867014
# Starting prediction...
# Total elapsed time: 0.873026
# Starting prediction...
# Total elapsed time: 0.882306
# Starting prediction...
# Total elapsed time: 0.882658
# Starting prediction...
# Total elapsed time: 0.936517
# Starting prediction...
# Total elapsed time: 1.49307
# Starting prediction...
# Total elapsed time: 4.83437
# Starting prediction...
# Total elapsed time: 9.03972
# Starting prediction...
# Total elapsed time: 9.65381
# Total elapsed time: 9.65401
# Starting prediction...
# Total elapsed time: 7.79582
# ========================================================================
# AUROC:  0.9231046704505396
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  7
# [INFO:] Random Seed used is   56
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6733, 28, 28, 1)
# The shape of POS data :  (66, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.868792
# Starting prediction...
# Total elapsed time: 0.877447
# Starting prediction...
# Total elapsed time: 0.863884
# Starting prediction...
# Total elapsed time: 0.876081
# Starting prediction...
# Total elapsed time: 0.892301
# Starting prediction...
# Total elapsed time: 0.957413
# Starting prediction...
# Total elapsed time: 1.50617
# Starting prediction...
# Total elapsed time: 4.85031
# Starting prediction...
# Total elapsed time: 9.28533
# Starting prediction...
# Total elapsed time: 9.69729
# Total elapsed time: 9.69799
# Starting prediction...
# Total elapsed time: 7.82118
# ========================================================================
# AUROC:  0.8961378128044796
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  7
# [INFO:] Random Seed used is   81
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6733, 28, 28, 1)
# The shape of POS data :  (66, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.872562
# Starting prediction...
# Total elapsed time: 0.878241
# Starting prediction...
# Total elapsed time: 0.875698
# Starting prediction...
# Total elapsed time: 0.880589
# Starting prediction...
# Total elapsed time: 0.890274
# Starting prediction...
# Total elapsed time: 0.947963
# Starting prediction...
# Total elapsed time: 1.4967
# Starting prediction...
# Total elapsed time: 4.85278
# Starting prediction...
# Total elapsed time: 9.20223
# Starting prediction...
# Total elapsed time: 9.47113
# Total elapsed time: 9.47177
# Starting prediction...
# Total elapsed time: 7.80611
# ========================================================================
# AUROC:  0.9118598832360301
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  7
# [INFO:] Random Seed used is   67
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6733, 28, 28, 1)
# The shape of POS data :  (66, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.875745
# Starting prediction...
# Total elapsed time: 0.862495
# Starting prediction...
# Total elapsed time: 0.871018
# Starting prediction...
# Total elapsed time: 0.874769
# Starting prediction...
# Total elapsed time: 0.887724
# Starting prediction...
# Total elapsed time: 0.961059
# Starting prediction...
# Total elapsed time: 1.49119
# Starting prediction...
# Total elapsed time: 4.85715
# Starting prediction...
# Total elapsed time: 9.07798
# Starting prediction...
# Total elapsed time: 9.45254
# Total elapsed time: 9.45283
# Starting prediction...
# Total elapsed time: 7.79101
# ========================================================================
# AUROC:  0.9307663442294863
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  7
# [INFO:] Random Seed used is   33
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6733, 28, 28, 1)
# The shape of POS data :  (66, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.866139
# Starting prediction...
# Total elapsed time: 0.878569
# Starting prediction...
# Total elapsed time: 0.867579
# Starting prediction...
# Total elapsed time: 0.866045
# Starting prediction...
# Total elapsed time: 0.887294
# Starting prediction...
# Total elapsed time: 0.965177
# Starting prediction...
# Total elapsed time: 1.49907
# Starting prediction...
# Total elapsed time: 4.86649
# Starting prediction...
# Total elapsed time: 9.00912
# Starting prediction...
# Total elapsed time: 9.43488
# Total elapsed time: 9.43554
# Starting prediction...
# Total elapsed time: 7.67462
# ========================================================================
# AUROC:  0.9354166666666667
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  7
# [INFO:] Random Seed used is   25
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6733, 28, 28, 1)
# The shape of POS data :  (66, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.862478
# Starting prediction...
# Total elapsed time: 0.867631
# Starting prediction...
# Total elapsed time: 0.870294
# Starting prediction...
# Total elapsed time: 0.8783
# Starting prediction...
# Total elapsed time: 0.883051
# Starting prediction...
# Total elapsed time: 0.946397
# Starting prediction...
# Total elapsed time: 1.51475
# Starting prediction...
# Total elapsed time: 4.86854
# Starting prediction...
# Total elapsed time: 9.29769
# Starting prediction...
# Total elapsed time: 9.75415
# Total elapsed time: 9.75497
# Starting prediction...
# Total elapsed time: 7.78338
# ========================================================================
# AUROC:  0.9386416666666666
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  7
# [INFO:] Random Seed used is   90
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6733, 28, 28, 1)
# The shape of POS data :  (66, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.866704
# Starting prediction...
# Total elapsed time: 0.866494
# Starting prediction...
# Total elapsed time: 0.872516
# Starting prediction...
# Total elapsed time: 0.879568
# Starting prediction...
# Total elapsed time: 0.882697
# Starting prediction...
# Total elapsed time: 0.946817
# Starting prediction...
# Total elapsed time: 1.49314
# Starting prediction...
# Total elapsed time: 4.84415
# Starting prediction...
# Total elapsed time: 9.07198
# Starting prediction...
# Total elapsed time: 9.52493
# Total elapsed time: 9.52516
# Starting prediction...
# Total elapsed time: 7.76176
# ========================================================================
# AUROC:  0.928875
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  7
# [INFO:] Random Seed used is   77
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6733, 28, 28, 1)
# The shape of POS data :  (66, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.867306
# Starting prediction...
# Total elapsed time: 0.875893
# Starting prediction...
# Total elapsed time: 0.869671
# Starting prediction...
# Total elapsed time: 0.895343
# Starting prediction...
# Total elapsed time: 0.883769
# Starting prediction...
# Total elapsed time: 0.940151
# Starting prediction...
# Total elapsed time: 1.4941
# Starting prediction...
# Total elapsed time: 4.962
# Starting prediction...
# Total elapsed time: 9.11449
# Starting prediction...
# Total elapsed time: 9.75749
# Total elapsed time: 9.75769
# Starting prediction...
# Total elapsed time: 7.64488
# ========================================================================
# AUROC:  0.9200438934148387
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  7
# [INFO:] Random Seed used is   15
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6733, 28, 28, 1)
# The shape of POS data :  (66, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.868502
# Starting prediction...
# Total elapsed time: 0.862506
# Starting prediction...
# Total elapsed time: 0.892024
# Starting prediction...
# Total elapsed time: 0.888874
# Starting prediction...
# Total elapsed time: 0.888961
# Starting prediction...
# Total elapsed time: 0.936289
# Starting prediction...
# Total elapsed time: 1.51597
# Starting prediction...
# Total elapsed time: 4.84496
# Starting prediction...
# Total elapsed time: 9.07491
# Starting prediction...
# Total elapsed time: 9.35369
# Total elapsed time: 9.35435
# Starting prediction...
# Total elapsed time: 7.77188
# ========================================================================
# AUROC:  0.9174128340795007
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  7
# [INFO:] Random Seed used is   11
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6733, 28, 28, 1)
# The shape of POS data :  (66, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.865274
# Starting prediction...
# Total elapsed time: 0.878989
# Starting prediction...
# Total elapsed time: 0.8779
# Starting prediction...
# Total elapsed time: 0.882606
# Starting prediction...
# Total elapsed time: 0.901027
# Starting prediction...
# Total elapsed time: 0.935881
# Starting prediction...
# Total elapsed time: 1.50322
# Starting prediction...
# Total elapsed time: 4.90741
# Starting prediction...
# Total elapsed time: 9.14062
# Starting prediction...
# Total elapsed time: 9.51345
# Total elapsed time: 9.51367
# Starting prediction...
# Total elapsed time: 7.71421
# ========================================================================
# AUROC:  0.8844350733663491
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.9231046704505396, 0.8961378128044796, 0.9118598832360301, 0.9307663442294863, 0.9354166666666667, 0.9386416666666666, 0.928875, 0.9200438934148387, 0.9174128340795007, 0.8844350733663491]
# AUROC ===== 91.86693844914558 +/- 1.636772306050795
# ========================================================================

# %% [markdown]
# ##** MNIST 8 Vs All  **##

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

import numpy as np 
from src.config import Configuration as Cfg
from src.models.svm import SVM


DATASET = "mnist"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/mnist/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/mnist/ISO_FOREST/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.mnist_val_frac = 0.1
Cfg.mnist_normal = 8
Cfg.mnist_outlier = -1


 # SVM parameters
Cfg.svm_nu = 0.1
Cfg.svm_GridSearchCV = 1

for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    
    # initialize OC-SVM
    ocsvm = SVM(loss="OneClassSVM", dataset=DATASET, kernel="rbf")

    # train OC-SVM model
    ocsvm.fit(GridSearch=Cfg.svm_GridSearchCV)

    # predict scores
    auc_roc = ocsvm.predict(which_set='test')
   
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    print("========================================================================",)
    AUC.append(auc_roc)

    
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean*100 ,"+/-",auc_roc_std*100)
print("========================================================================")
# Out:
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (62, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.771109
# Starting prediction...
# Total elapsed time: 0.767105
# Starting prediction...
# Total elapsed time: 0.772456
# Starting prediction...
# Total elapsed time: 0.774234
# Starting prediction...
# Total elapsed time: 0.794661
# Starting prediction...
# Total elapsed time: 0.902039
# Starting prediction...
# Total elapsed time: 2.35088
# Starting prediction...
# Total elapsed time: 7.25367
# Starting prediction...
# Total elapsed time: 7.92884
# Starting prediction...
# Total elapsed time: 8.00996
# Total elapsed time: 8.01064
# Starting prediction...
# Total elapsed time: 6.85969
# ========================================================================
# AUROC:  0.861604411241551
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   56
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (62, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.759038
# Starting prediction...
# Total elapsed time: 0.774503
# Starting prediction...
# Total elapsed time: 0.772705
# Starting prediction...
# Total elapsed time: 0.77493
# Starting prediction...
# Total elapsed time: 0.799478
# Starting prediction...
# Total elapsed time: 0.894067
# Starting prediction...
# Total elapsed time: 2.35921
# Starting prediction...
# Total elapsed time: 6.96441
# Starting prediction...
# Total elapsed time: 7.99633
# Starting prediction...
# Total elapsed time: 8.99985
# Total elapsed time: 9.00041
# Starting prediction...
# Total elapsed time: 7.26821
# ========================================================================
# AUROC:  0.8674650971803997
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   81
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (62, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.802246
# Starting prediction...
# Total elapsed time: 0.816116
# Starting prediction...
# Total elapsed time: 0.7803
# Starting prediction...
# Total elapsed time: 0.812315
# Starting prediction...
# Total elapsed time: 1.45314
# Starting prediction...
# Total elapsed time: 0.896883
# Starting prediction...
# Total elapsed time: 2.37848
# Starting prediction...
# Total elapsed time: 7.60969
# Starting prediction...
# Total elapsed time: 12.9775
# Starting prediction...
# Total elapsed time: 12.8443
# Total elapsed time: 12.8452
# Starting prediction...
# Total elapsed time: 9.22819
# ========================================================================
# AUROC:  0.8898714133089133
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   67
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (62, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 1.04163
# Starting prediction...
# Total elapsed time: 1.05163
# Starting prediction...
# Total elapsed time: 1.05264
# Starting prediction...
# Total elapsed time: 1.0752
# Starting prediction...
# Total elapsed time: 1.09501
# Starting prediction...
# Total elapsed time: 1.23399
# Starting prediction...
# Total elapsed time: 3.26616
# Starting prediction...
# Total elapsed time: 11.3781
# Starting prediction...
# Total elapsed time: 12.8931
# Starting prediction...
# Total elapsed time: 9.66605
# Total elapsed time: 9.66663
# Starting prediction...
# Total elapsed time: 7.34902
# ========================================================================
# AUROC:  0.8868305630634276
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   33
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (62, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.768271
# Starting prediction...
# Total elapsed time: 0.773778
# Starting prediction...
# Total elapsed time: 0.764392
# Starting prediction...
# Total elapsed time: 0.774819
# Starting prediction...
# Total elapsed time: 0.78919
# Starting prediction...
# Total elapsed time: 0.904011
# Starting prediction...
# Total elapsed time: 2.69213
# Starting prediction...
# Total elapsed time: 7.70245
# Starting prediction...
# Total elapsed time: 8.04737

# %% [markdown]
# ##** MNIST 9 Vs All  **##

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

import numpy as np 
from src.config import Configuration as Cfg
from src.models.svm import SVM


DATASET = "mnist"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/mnist/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/mnist/ISO_FOREST/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.mnist_val_frac = 0.1
Cfg.mnist_normal = 9
Cfg.mnist_outlier = -1


 # SVM parameters
Cfg.svm_nu = 0.1
Cfg.svm_GridSearchCV = 1

for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    
    # initialize OC-SVM
    ocsvm = SVM(loss="OneClassSVM", dataset=DATASET, kernel="rbf")

    # train OC-SVM model
    ocsvm.fit(GridSearch=Cfg.svm_GridSearchCV)

    # predict scores
    auc_roc = ocsvm.predict(which_set='test')
   
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    print("========================================================================",)
    AUC.append(auc_roc)

    
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean*100 ,"+/-",auc_roc_std*100)
print("========================================================================")
# Out:
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  9
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6427, 28, 28, 1)
# The shape of POS data :  (63, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.791343
# Starting prediction...
# Total elapsed time: 0.791692
# Starting prediction...
# Total elapsed time: 0.794492
# Starting prediction...
# Total elapsed time: 0.795332
# Starting prediction...
# Total elapsed time: 0.814112
# Starting prediction...
# Total elapsed time: 0.860607
# Starting prediction...
# Total elapsed time: 1.48901
# Starting prediction...
# Total elapsed time: 4.81748
# Starting prediction...
# Total elapsed time: 8.51088
# Starting prediction...
# Total elapsed time: 8.58455
# Total elapsed time: 8.58477
# Starting prediction...
# Total elapsed time: 7.09427
# ========================================================================
# AUROC:  0.9290154336153259
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  9
# [INFO:] Random Seed used is   56
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6427, 28, 28, 1)
# The shape of POS data :  (63, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.789675
# Starting prediction...
# Total elapsed time: 0.786139
# Starting prediction...
# Total elapsed time: 0.794197
# Starting prediction...
# Total elapsed time: 0.786943
# Starting prediction...
# Total elapsed time: 0.808163
# Starting prediction...
# Total elapsed time: 0.887984
# Starting prediction...
# Total elapsed time: 1.49522
# Starting prediction...
# Total elapsed time: 4.79438
# Starting prediction...
# Total elapsed time: 8.47071
# Starting prediction...
# Total elapsed time: 8.62049
# Total elapsed time: 8.62116
# Starting prediction...
# Total elapsed time: 7.04456
# ========================================================================
# AUROC:  0.9390706678427867
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  9
# [INFO:] Random Seed used is   81
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6427, 28, 28, 1)
# The shape of POS data :  (63, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.801621
# Starting prediction...
# Total elapsed time: 0.787212
# Starting prediction...
# Total elapsed time: 0.793753
# Starting prediction...
# Total elapsed time: 0.792217
# Starting prediction...
# Total elapsed time: 0.80687
# Starting prediction...
# Total elapsed time: 0.85887
# Starting prediction...
# Total elapsed time: 1.50407
# Starting prediction...
# Total elapsed time: 4.75906
# Starting prediction...
# Total elapsed time: 8.56093
# Starting prediction...
# Total elapsed time: 8.71681
# Total elapsed time: 8.71705
# Starting prediction...
# Total elapsed time: 7.12883
# ========================================================================
# AUROC:  0.9092261098366481
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  9
# [INFO:] Random Seed used is   67
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6427, 28, 28, 1)
# The shape of POS data :  (63, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.791746
# Starting prediction...
# Total elapsed time: 0.794674
# Starting prediction...
# Total elapsed time: 0.797646
# Starting prediction...
# Total elapsed time: 0.801292
# Starting prediction...
# Total elapsed time: 0.815369
# Starting prediction...
# Total elapsed time: 0.874474
# Starting prediction...
# Total elapsed time: 1.50563
# Starting prediction...
# Total elapsed time: 4.80236
# Starting prediction...
# Total elapsed time: 8.56778
# Starting prediction...
# Total elapsed time: 8.69033
# Total elapsed time: 8.69091
# Starting prediction...
# Total elapsed time: 7.07121
# ========================================================================
# AUROC:  0.8852143231179712
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  9
# [INFO:] Random Seed used is   33
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6427, 28, 28, 1)
# The shape of POS data :  (63, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.787972
# Starting prediction...
# Total elapsed time: 0.794546
# Starting prediction...
# Total elapsed time: 0.799458
# Starting prediction...
# Total elapsed time: 0.785298
# Starting prediction...
# Total elapsed time: 0.807117
# Starting prediction...
# Total elapsed time: 0.876633
# Starting prediction...
# Total elapsed time: 1.49285
# Starting prediction...
# Total elapsed time: 4.77325
# Starting prediction...
# Total elapsed time: 8.65175
# Starting prediction...
# Total elapsed time: 8.59714
# Total elapsed time: 8.5978
# Starting prediction...
# Total elapsed time: 7.04314
# ========================================================================
# AUROC:  0.9265674582717577
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  9
# [INFO:] Random Seed used is   25
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6427, 28, 28, 1)
# The shape of POS data :  (63, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.798391
# Starting prediction...
# Total elapsed time: 0.786491
# Starting prediction...
# Total elapsed time: 0.802966
# Starting prediction...
# Total elapsed time: 0.806667
# Starting prediction...
# Total elapsed time: 0.799062
# Starting prediction...
# Total elapsed time: 0.863933
# Starting prediction...
# Total elapsed time: 1.46425
# Starting prediction...
# Total elapsed time: 4.77304
# Starting prediction...
# Total elapsed time: 8.51763
# Starting prediction...
# Total elapsed time: 8.74972
# Total elapsed time: 8.75034
# Starting prediction...
# Total elapsed time: 7.08974
# ========================================================================
# AUROC:  0.9199841345391084
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  9
# [INFO:] Random Seed used is   90
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6427, 28, 28, 1)
# The shape of POS data :  (63, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.79174
# Starting prediction...
# Total elapsed time: 0.796595
# Starting prediction...
# Total elapsed time: 0.790976
# Starting prediction...
# Total elapsed time: 0.794135
# Starting prediction...
# Total elapsed time: 0.799767
# Starting prediction...
# Total elapsed time: 0.860502
# Starting prediction...
# Total elapsed time: 1.50317
# Starting prediction...
# Total elapsed time: 4.82041
# Starting prediction...
# Total elapsed time: 8.6738
# Starting prediction...
# Total elapsed time: 8.64291
# Total elapsed time: 8.64355
# Starting prediction...
# Total elapsed time: 7.11548
# ========================================================================
# AUROC:  0.9164993890731366
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  9
# [INFO:] Random Seed used is   77
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6427, 28, 28, 1)
# The shape of POS data :  (63, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.79349
# Starting prediction...
# Total elapsed time: 0.792143
# Starting prediction...
# Total elapsed time: 0.790095
# Starting prediction...
# Total elapsed time: 0.797746
# Starting prediction...
# Total elapsed time: 0.810783
# Starting prediction...
# Total elapsed time: 0.888475
# Starting prediction...
# Total elapsed time: 1.48566
# Starting prediction...
# Total elapsed time: 4.78398
# Starting prediction...
# Total elapsed time: 8.54782
# Starting prediction...
# Total elapsed time: 8.68916
# Total elapsed time: 8.68989
# Starting prediction...
# Total elapsed time: 7.11283
# ========================================================================
# AUROC:  0.9613246065778944
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  9
# [INFO:] Random Seed used is   15
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6427, 28, 28, 1)
# The shape of POS data :  (63, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.790968
# Starting prediction...
# Total elapsed time: 0.793057
# Starting prediction...
# Total elapsed time: 0.791189
# Starting prediction...
# Total elapsed time: 0.811551
# Starting prediction...
# Total elapsed time: 0.812962
# Starting prediction...
# Total elapsed time: 0.867074
# Starting prediction...
# Total elapsed time: 1.46595
# Starting prediction...
# Total elapsed time: 4.78293
# Starting prediction...
# Total elapsed time: 8.39891
# Starting prediction...
# Total elapsed time: 8.62667
# Total elapsed time: 8.62725
# Starting prediction...
# Total elapsed time: 7.10668
# ========================================================================
# AUROC:  0.9259617179362125
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  9
# [INFO:] Random Seed used is   11
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6427, 28, 28, 1)
# The shape of POS data :  (63, 28, 28, 1)
# The shape of NEG data :  (0, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.786465
# Starting prediction...
# Total elapsed time: 0.798127
# Starting prediction...
# Total elapsed time: 0.795995
# Starting prediction...
# Total elapsed time: 0.79923
# Starting prediction...
# Total elapsed time: 0.813253
# Starting prediction...
# Total elapsed time: 0.868904
# Starting prediction...
# Total elapsed time: 1.47711
# Starting prediction...
# Total elapsed time: 4.7569
# Starting prediction...
# Total elapsed time: 8.59737
# Starting prediction...
# Total elapsed time: 8.63554
# Total elapsed time: 8.63613
# Starting prediction...
# Total elapsed time: 7.10486
# ========================================================================
# AUROC:  0.9404505709688051
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.9290154336153259, 0.9390706678427867, 0.9092261098366481, 0.8852143231179712, 0.9265674582717577, 0.9199841345391084, 0.9164993890731366, 0.9613246065778944, 0.9259617179362125, 0.9404505709688051]
# AUROC ===== 92.53314411779647 +/- 1.9245058767222327
# ========================================================================
