# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install picklable_itertools

# !pip install fuel
# !pip install foolbox

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
import numpy as np
PROJECT_DIR = "/content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/"
import sys,os
import numpy as np
sys.path.append(PROJECT_DIR)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# Collecting picklable_itertools
#   Downloading https://files.pythonhosted.org/packages/75/bc/cda9191f0c92960ede6aa95e364443965246385faf62775cc30749931c2c/picklable-itertools-0.1.1.tar.gz
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from picklable_itertools) (1.11.0)
# Building wheels for collected packages: picklable-itertools
# done
#   Stored in directory: /root/.cache/pip/wheels/36/dd/e2/ec30ef7c475e1d9fb966735984ba05f8710c67d7de5358c326
# Successfully built picklable-itertools
# Installing collected packages: picklable-itertools
# Successfully installed picklable-itertools-0.1.1
# Collecting fuel
#   Downloading https://files.pythonhosted.org/packages/16/c2/b5fb651c90e908f79769b7dd3643982b6a9b1bac9449b8ab16f72612d4f5/fuel-0.2.0.tar.gz (184kB)
#     100% |████████████████████████████████| 194kB 12.7MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from fuel) (1.14.6)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from fuel) (1.11.0)
# Requirement already satisfied: picklable_itertools in /usr/local/lib/python3.6/dist-packages (from fuel) (0.1.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from fuel) (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from fuel) (2.8.0)
# Collecting tables (from fuel)
#   Downloading https://files.pythonhosted.org/packages/d7/1b/21f4c7f296b718575c17ef25e61c05742a283c45077b4c8d5a190b3e0b59/tables-3.4.4-cp36-cp36m-manylinux1_x86_64.whl (3.8MB)
#     100% |████████████████████████████████| 3.8MB 10.1MB/s
# Collecting progressbar2 (from fuel)
#   Downloading https://files.pythonhosted.org/packages/4f/6f/acb2dd76f2c77527584bd3a4c2509782bb35c481c610521fc3656de5a9e0/progressbar2-3.38.0-py2.py3-none-any.whl
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.6/dist-packages (from fuel) (17.0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from fuel) (1.1.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from fuel) (4.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from fuel) (2.18.4)
# Collecting numexpr>=2.5.2 (from tables->fuel)
#   Downloading https://files.pythonhosted.org/packages/db/ea/efd9e16283637eb5b6c0042b6cc3521f1b9a5b47767ac463c88bbd37670c/numexpr-2.6.8-cp36-cp36m-manylinux1_x86_64.whl (162kB)
#     100% |████████████████████████████████| 163kB 28.5MB/s
# Collecting python-utils>=2.3.0 (from progressbar2->fuel)
#   Downloading https://files.pythonhosted.org/packages/eb/a0/19119d8b7c05be49baf6c593f11c432d571b70d805f2fe94c0585e55e4c8/python_utils-2.3.0-py2.py3-none-any.whl
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from pillow->fuel) (0.46)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->fuel) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->fuel) (2018.10.15)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->fuel) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->fuel) (1.22)
# Building wheels for collected packages: fuel
# done
#   Stored in directory: /root/.cache/pip/wheels/96/ff/1b/f3708731cf77a6d759cd12e68c0a27700c299fbe2bffd34fa3
# Successfully built fuel
# Installing collected packages: numexpr, tables, python-utils, progressbar2, fuel
# Successfully installed fuel-0.2.0 numexpr-2.6.8 progressbar2-3.38.0 python-utils-2.3.0 tables-3.4.4
# Collecting foolbox
#   Downloading https://files.pythonhosted.org/packages/d5/6d/31f6bbd461f3276288b9bd9c0cf6d93e01231e5da2133b250e23f7df6566/foolbox-1.8.0.tar.gz (239kB)
#     100% |████████████████████████████████| 245kB 15.7MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from foolbox) (1.14.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from foolbox) (1.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from foolbox) (40.6.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from foolbox) (2.18.4)
# Collecting GitPython (from foolbox)
#   Downloading https://files.pythonhosted.org/packages/fe/e5/fafe827507644c32d6dc553a1c435cdf882e0c28918a5bab29f7fbebfb70/GitPython-2.1.11-py2.py3-none-any.whl (448kB)
#     100% |████████████████████████████████| 450kB 24.9MB/s
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->foolbox) (2018.10.15)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->foolbox) (1.22)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->foolbox) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->foolbox) (3.0.4)
# Collecting gitdb2>=2.0.0 (from GitPython->foolbox)
#   Downloading https://files.pythonhosted.org/packages/da/30/a407568aa8d8f25db817cf50121a958722f3fc5f87e3a6fba1f40c0633e3/gitdb2-2.0.5-py2.py3-none-any.whl (62kB)
#     100% |████████████████████████████████| 71kB 21.2MB/s
# Collecting smmap2>=2.0.0 (from gitdb2>=2.0.0->GitPython->foolbox)
#   Downloading https://files.pythonhosted.org/packages/55/d2/866d45e3a121ee15a1dc013824d58072fd5c7799c9c34d01378eb262ca8f/smmap2-2.0.5-py2.py3-none-any.whl
# Building wheels for collected packages: foolbox
# done
#   Stored in directory: /root/.cache/pip/wheels/d7/e7/c8/153284a6e5e5c3fd4da42a8453175b45e2e185e8b5a09ced06
# Successfully built foolbox
# Installing collected packages: smmap2, gitdb2, GitPython, foolbox
# Successfully installed GitPython-2.1.11 foolbox-1.8.0 gitdb2-2.0.5 smmap2-2.0.5

# %% [markdown]
# ##** Aeroplane Vs All  **##

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

import numpy as np 
from src.config import Configuration as Cfg
from src.models.svm import SVM


DATASET = "cifar10"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/cifar10/OCSVM_SVDD/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/cifar10/OCSVM_SVDD/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []



## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.cifar10_val_frac = 0.1
Cfg.cifar10_normal = 0
Cfg.cifar10_outlier = -1


 # SVM parameters
Cfg.svm_nu = 0.1
Cfg.svm_GridSearchCV = 1

for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    
    # initialize OC-SVM
    ocsvm = SVM(loss="OneClassSVM", dataset=DATASET, kernel="rbf")

    # train OC-SVM model
    ocsvm.fit(GridSearch=Cfg.svm_GridSearchCV)

    # predict scores
    auc_roc = ocsvm.predict(which_set='test')
   
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    print("========================================================================",)
    AUC.append(auc_roc)

    
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean*100 ,"+/-",auc_roc_std*100)
print("========================================================================")
# Out:
# Using TensorFlow backend.
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/utils/visualization/mosaic_plot.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-6569f4f7c1be>", line 10, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')  # or 'PS', 'PDF', 'SVG'
# [INFO:] Loading data...
# The normal label used in experiment, 0
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 48s 0us/step
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.09496
# Starting prediction...
# Total elapsed time: 3.07562
# Starting prediction...
# Total elapsed time: 3.15185
# Starting prediction...
# Total elapsed time: 3.30604
# Starting prediction...
# Total elapsed time: 6.50529
# Starting prediction...
# Total elapsed time: 21.5142
# Starting prediction...
# Total elapsed time: 34.1363
# Starting prediction...
# Total elapsed time: 36.7587
# Starting prediction...
# Total elapsed time: 36.8465
# Starting prediction...
# Total elapsed time: 36.5873
# Total elapsed time: 36.5881
# Starting prediction...
# Total elapsed time: 27.2848
# ========================================================================
# AUROC:  0.6024933599273726
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.04752
# Starting prediction...
# Total elapsed time: 3.01622
# Starting prediction...
# Total elapsed time: 3.12802
# Starting prediction...
# Total elapsed time: 3.30028
# Starting prediction...
# Total elapsed time: 6.44878
# Starting prediction...
# Total elapsed time: 21.55
# Starting prediction...
# Total elapsed time: 34.1909
# Starting prediction...
# Total elapsed time: 36.5544
# Starting prediction...
# Total elapsed time: 36.4658
# Starting prediction...
# Total elapsed time: 36.4599
# Total elapsed time: 36.4609
# Starting prediction...
# Total elapsed time: 27.3561
# ========================================================================
# AUROC:  0.5861328429696654
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.08411
# Starting prediction...
# Total elapsed time: 3.10196
# Starting prediction...
# Total elapsed time: 3.14675
# Starting prediction...
# Total elapsed time: 3.36423
# Starting prediction...
# Total elapsed time: 6.38493
# Starting prediction...
# Total elapsed time: 21.7068
# Starting prediction...
# Total elapsed time: 33.9815
# Starting prediction...
# Total elapsed time: 36.7941
# Starting prediction...
# Total elapsed time: 36.708
# Starting prediction...
# Total elapsed time: 36.6466
# Total elapsed time: 36.647
# Starting prediction...
# Total elapsed time: 27.3938
# ========================================================================
# AUROC:  0.5875545154506507
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.05304
# Starting prediction...
# Total elapsed time: 3.04498
# Starting prediction...
# Total elapsed time: 3.14422
# Starting prediction...
# Total elapsed time: 3.35268
# Starting prediction...
# Total elapsed time: 6.52166
# Starting prediction...
# Total elapsed time: 21.5826
# Starting prediction...
# Total elapsed time: 34.9684
# Starting prediction...
# Total elapsed time: 36.1739
# Starting prediction...
# Total elapsed time: 36.4099
# Starting prediction...
# Total elapsed time: 36.5938
# Total elapsed time: 36.5961
# Starting prediction...
# Total elapsed time: 27.5725
# ========================================================================
# AUROC:  0.6125993091851221
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.07569
# Starting prediction...
# Total elapsed time: 3.06912
# Starting prediction...
# Total elapsed time: 3.12296
# Starting prediction...
# Total elapsed time: 3.33802
# Starting prediction...
# Total elapsed time: 6.71844
# Starting prediction...
# Total elapsed time: 21.7226
# Starting prediction...
# Total elapsed time: 34.0532
# Starting prediction...
# Total elapsed time: 36.5137
# Starting prediction...
# Total elapsed time: 36.6469
# Starting prediction...
# Total elapsed time: 36.4576
# Total elapsed time: 36.4581
# Starting prediction...
# Total elapsed time: 27.2883
# ========================================================================
# AUROC:  0.6058590993110401
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.04006
# Starting prediction...
# Total elapsed time: 3.04666
# Starting prediction...
# Total elapsed time: 3.14018
# Starting prediction...
# Total elapsed time: 3.31892
# Starting prediction...
# Total elapsed time: 6.56256
# Starting prediction...
# Total elapsed time: 21.7803
# Starting prediction...
# Total elapsed time: 34.5554
# Starting prediction...
# Total elapsed time: 36.4204
# Starting prediction...
# Total elapsed time: 36.6641
# Starting prediction...
# Total elapsed time: 36.5836
# Total elapsed time: 36.5845
# Starting prediction...
# Total elapsed time: 27.5086
# ========================================================================
# AUROC:  0.6182522633744855
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.0784
# Starting prediction...
# Total elapsed time: 3.02002
# Starting prediction...
# Total elapsed time: 3.12234
# Starting prediction...
# Total elapsed time: 3.2533
# Starting prediction...
# Total elapsed time: 6.65916
# Starting prediction...
# Total elapsed time: 21.6763
# Starting prediction...
# Total elapsed time: 34.502
# Starting prediction...
# Total elapsed time: 36.7076
# Starting prediction...
# Total elapsed time: 36.8383
# Starting prediction...
# Total elapsed time: 36.6844
# Total elapsed time: 36.6852
# Starting prediction...
# Total elapsed time: 26.9164
# ========================================================================
# AUROC:  0.5952811067571641
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 2.99641
# Starting prediction...
# Total elapsed time: 3.03071
# Starting prediction...
# Total elapsed time: 3.03041
# Starting prediction...
# Total elapsed time: 3.27822
# Starting prediction...
# Total elapsed time: 6.74823
# Starting prediction...
# Total elapsed time: 21.632
# Starting prediction...
# Total elapsed time: 34.2276
# Starting prediction...
# Total elapsed time: 36.6521
# Starting prediction...
# Total elapsed time: 36.4148
# Starting prediction...
# Total elapsed time: 36.8639
# Total elapsed time: 36.8642
# Starting prediction...
# Total elapsed time: 26.9136
# ========================================================================
# AUROC:  0.6246631171515856
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 2.98605
# Starting prediction...
# Total elapsed time: 3.03813
# Starting prediction...
# Total elapsed time: 3.05098
# Starting prediction...
# Total elapsed time: 3.26569
# Starting prediction...
# Total elapsed time: 6.67317
# Starting prediction...
# Total elapsed time: 21.4578
# Starting prediction...
# Total elapsed time: 33.8321
# Starting prediction...
# Total elapsed time: 36.153
# Starting prediction...
# Total elapsed time: 36.0255
# Starting prediction...
# Total elapsed time: 36.318
# Total elapsed time: 36.3186
# Starting prediction...
# Total elapsed time: 26.8797
# ========================================================================
# AUROC:  0.6239234065423096
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.05455
# Starting prediction...
# Total elapsed time: 3.01126
# Starting prediction...
# Total elapsed time: 3.04187
# Starting prediction...
# Total elapsed time: 3.27225
# Starting prediction...
# Total elapsed time: 6.59372
# Starting prediction...
# Total elapsed time: 21.5453
# Starting prediction...
# Total elapsed time: 33.9843
# Starting prediction...
# Total elapsed time: 36.3819
# Starting prediction...
# Total elapsed time: 36.435
# Starting prediction...
# Total elapsed time: 36.4945
# Total elapsed time: 36.4952
# Starting prediction...
# Total elapsed time: 27.0579
# ========================================================================
# AUROC:  0.5806148538902939
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.6024933599273726, 0.5861328429696654, 0.5875545154506507, 0.6125993091851221, 0.6058590993110401, 0.6182522633744855, 0.5952811067571641, 0.6246631171515856, 0.6239234065423096, 0.5806148538902939]
# AUROC ===== 60.3737387455969 +/- 1.522692237408153
# ========================================================================

# %% [markdown]
# ##** AUTOMOBILE VS All

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

import numpy as np 
from src.config import Configuration as Cfg
from src.models.svm import SVM


DATASET = "cifar10"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/cifar10/OCSVM_SVDD/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/cifar10/OCSVM_SVDD/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []



## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.cifar10_val_frac = 0.1
Cfg.cifar10_normal = 1
Cfg.cifar10_outlier = -1


 # SVM parameters
Cfg.svm_nu = 0.1
Cfg.svm_GridSearchCV = 1

for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    
    # initialize OC-SVM
    ocsvm = SVM(loss="OneClassSVM", dataset=DATASET, kernel="rbf")

    # train OC-SVM model
    ocsvm.fit(GridSearch=Cfg.svm_GridSearchCV)

    # predict scores
    auc_roc = ocsvm.predict(which_set='test')
   
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    print("========================================================================",)
    AUC.append(auc_roc)

    
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean*100 ,"+/-",auc_roc_std*100)
print("========================================================================")
# Out:
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 2.98006
# Starting prediction...
# Total elapsed time: 3.00008
# Starting prediction...
# Total elapsed time: 3.01439
# Starting prediction...
# Total elapsed time: 3.04085
# Starting prediction...
# Total elapsed time: 2.9708
# Starting prediction...
# Total elapsed time: 2.99731
# Starting prediction...
# Total elapsed time: 2.98403
# Starting prediction...
# Total elapsed time: 2.99156
# Starting prediction...
# Total elapsed time: 3.03801
# Starting prediction...
# Total elapsed time: 2.9996
# Total elapsed time: 2.99991
# Starting prediction...
# Total elapsed time: 27.0266
# ========================================================================
# AUROC:  0.6439039577195274
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 2.96301
# Starting prediction...
# Total elapsed time: 2.96033
# Starting prediction...
# Total elapsed time: 2.96836
# Starting prediction...
# Total elapsed time: 2.97906
# Starting prediction...
# Total elapsed time: 2.97112
# Starting prediction...
# Total elapsed time: 3.00007
# Starting prediction...
# Total elapsed time: 3.04033
# Starting prediction...
# Total elapsed time: 3.00543
# Starting prediction...
# Total elapsed time: 3.04359
# Starting prediction...
# Total elapsed time: 3.00846
# Total elapsed time: 3.00909
# Starting prediction...
# Total elapsed time: 26.8928
# ========================================================================
# AUROC:  0.645281024187365
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 2.99138
# Starting prediction...
# Total elapsed time: 3.02938
# Starting prediction...
# Total elapsed time: 2.97177
# Starting prediction...
# Total elapsed time: 3.00844
# Starting prediction...
# Total elapsed time: 2.98124
# Starting prediction...
# Total elapsed time: 3.04007
# Starting prediction...
# Total elapsed time: 2.95395
# Starting prediction...
# Total elapsed time: 3.01388
# Starting prediction...
# Total elapsed time: 2.96119
# Starting prediction...
# Total elapsed time: 2.96068
# Total elapsed time: 2.9614
# Starting prediction...
# Total elapsed time: 26.6989
# ========================================================================
# AUROC:  0.6187005230750503
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 2.95734
# Starting prediction...
# Total elapsed time: 2.94942
# Starting prediction...
# Total elapsed time: 2.95237
# Starting prediction...
# Total elapsed time: 2.95167
# Starting prediction...
# Total elapsed time: 2.95508
# Starting prediction...
# Total elapsed time: 2.95696
# Starting prediction...
# Total elapsed time: 2.96416
# Starting prediction...
# Total elapsed time: 3.00175
# Starting prediction...
# Total elapsed time: 2.95926
# Starting prediction...
# Total elapsed time: 2.96182
# Total elapsed time: 2.9621
# Starting prediction...
# Total elapsed time: 26.6384
# ========================================================================
# AUROC:  0.6470365965384897
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 2.96947
# Starting prediction...
# Total elapsed time: 3.02139
# Starting prediction...
# Total elapsed time: 2.96092
# Starting prediction...
# Total elapsed time: 2.98656
# Starting prediction...
# Total elapsed time: 2.96191
# Starting prediction...
# Total elapsed time: 2.96846
# Starting prediction...
# Total elapsed time: 2.959
# Starting prediction...
# Total elapsed time: 2.96527
# Starting prediction...
# Total elapsed time: 2.96948
# Starting prediction...
# Total elapsed time: 2.97333
# Total elapsed time: 2.97406
# Starting prediction...
# Total elapsed time: 26.7073
# ========================================================================
# AUROC:  0.6411355234414384
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 2.96507
# Starting prediction...
# Total elapsed time: 2.9849
# Starting prediction...
# Total elapsed time: 2.98958
# Starting prediction...
# Total elapsed time: 2.99701
# Starting prediction...
# Total elapsed time: 2.98641
# Starting prediction...
# Total elapsed time: 2.99285
# Starting prediction...
# Total elapsed time: 2.99114
# Starting prediction...
# Total elapsed time: 3.02748
# Starting prediction...
# Total elapsed time: 2.97637
# Starting prediction...
# Total elapsed time: 3.02255
# Total elapsed time: 3.02284
# Starting prediction...
# Total elapsed time: 27.04
# ========================================================================
# AUROC:  0.6601111111111111
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 2.99722
# Starting prediction...
# Total elapsed time: 3.02371
# Starting prediction...
# Total elapsed time: 3.00833
# Starting prediction...
# Total elapsed time: 2.9849
# Starting prediction...
# Total elapsed time: 2.95654
# Starting prediction...
# Total elapsed time: 2.99727
# Starting prediction...
# Total elapsed time: 3.00106
# Starting prediction...
# Total elapsed time: 3.01489
# Starting prediction...
# Total elapsed time: 2.97555
# Starting prediction...
# Total elapsed time: 3.00823
# Total elapsed time: 3.00893
# Starting prediction...
# Total elapsed time: 27.0702
# ========================================================================
# AUROC:  0.6151104366535355
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 2.96215
# Starting prediction...
# Total elapsed time: 3.04484
# Starting prediction...
# Total elapsed time: 2.99786
# Starting prediction...
# Total elapsed time: 3.01575
# Starting prediction...
# Total elapsed time: 2.95016
# Starting prediction...
# Total elapsed time: 2.94847
# Starting prediction...
# Total elapsed time: 2.94972
# Starting prediction...
# Total elapsed time: 2.96079
# Starting prediction...
# Total elapsed time: 2.96282
# Starting prediction...
# Total elapsed time: 2.96462
# Total elapsed time: 2.96532
# Starting prediction...
# Total elapsed time: 26.6944
# ========================================================================
# AUROC:  0.6264456461585846
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.00185
# Starting prediction...
# Total elapsed time: 3.02537
# Starting prediction...
# Total elapsed time: 2.99587
# Starting prediction...
# Total elapsed time: 2.97539
# Starting prediction...
# Total elapsed time: 3.02334
# Starting prediction...
# Total elapsed time: 3.00221
# Starting prediction...
# Total elapsed time: 2.98112
# Starting prediction...
# Total elapsed time: 2.97371
# Starting prediction...
# Total elapsed time: 2.97101
# Starting prediction...
# Total elapsed time: 2.96319
# Total elapsed time: 2.9638
# Starting prediction...
# Total elapsed time: 26.6289
# ========================================================================
# AUROC:  0.6561380888320807
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 2.96791
# Starting prediction...
# Total elapsed time: 2.96241
# Starting prediction...
# Total elapsed time: 2.96648
# Starting prediction...
# Total elapsed time: 3.02727
# Starting prediction...
# Total elapsed time: 2.95551
# Starting prediction...
# Total elapsed time: 2.95341
# Starting prediction...
# Total elapsed time: 2.96895
# Starting prediction...
# Total elapsed time: 2.95294
# Starting prediction...
# Total elapsed time: 2.97667
# Starting prediction...
# Total elapsed time: 2.97325
# Total elapsed time: 2.97398
# Starting prediction...
# Total elapsed time: 26.6272
# ========================================================================
# AUROC:  0.6393753213399154
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.6439039577195274, 0.645281024187365, 0.6187005230750503, 0.6470365965384897, 0.6411355234414384, 0.6601111111111111, 0.6151104366535355, 0.6264456461585846, 0.6561380888320807, 0.6393753213399154]
# AUROC ===== 63.93238229057096 +/- 1.4182822588127095
# ========================================================================

# %% [markdown]
# ##** BIRD  vs All

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

import numpy as np 
from src.config import Configuration as Cfg
from src.models.svm import SVM


DATASET = "cifar10"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/cifar10/OCSVM_SVDD/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/cifar10/OCSVM_SVDD/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []



## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.cifar10_val_frac = 0.1
Cfg.cifar10_normal = 2
Cfg.cifar10_outlier = -1


 # SVM parameters
Cfg.svm_nu = 0.1
Cfg.svm_GridSearchCV = 1

for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    
    # initialize OC-SVM
    ocsvm = SVM(loss="OneClassSVM", dataset=DATASET, kernel="rbf")

    # train OC-SVM model
    ocsvm.fit(GridSearch=Cfg.svm_GridSearchCV)

    # predict scores
    auc_roc = ocsvm.predict(which_set='test')
   
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    print("========================================================================",)
    AUC.append(auc_roc)

    
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean*100 ,"+/-",auc_roc_std*100)
print("========================================================================")
# Out:
# Using TensorFlow backend.
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/utils/visualization/mosaic_plot.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-6569f4f7c1be>", line 10, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')  # or 'PS', 'PDF', 'SVG'
# [INFO:] Loading data...
# The normal label used in experiment, 2
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 49s 0us/step
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.17285
# Starting prediction...
# Total elapsed time: 3.11819
# Starting prediction...
# Total elapsed time: 3.16149
# Starting prediction...
# Total elapsed time: 3.8909
# Starting prediction...
# Total elapsed time: 6.76322
# Starting prediction...
# Total elapsed time: 19.6002
# Starting prediction...
# Total elapsed time: 30.0486
# Starting prediction...
# Total elapsed time: 34.0144
# Starting prediction...
# Total elapsed time: 36.4637
# Starting prediction...
# Total elapsed time: 33.3171
# Total elapsed time: 33.3177
# Starting prediction...
# Total elapsed time: 27.9436
# ========================================================================
# AUROC:  0.6497374344851793
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.04092
# Starting prediction...
# Total elapsed time: 3.10001
# Starting prediction...
# Total elapsed time: 3.206
# Starting prediction...
# Total elapsed time: 3.57642
# Starting prediction...
# Total elapsed time: 6.2057
# Starting prediction...
# Total elapsed time: 17.4965
# Starting prediction...
# Total elapsed time: 29.3139
# Starting prediction...
# Total elapsed time: 35.3505
# Starting prediction...
# Total elapsed time: 34.3703
# Starting prediction...
# Total elapsed time: 33.3971
# Total elapsed time: 33.3978
# Starting prediction...
# Total elapsed time: 27.6471
# ========================================================================
# AUROC:  0.6358912846488068
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.05775
# Starting prediction...
# Total elapsed time: 3.12213
# Starting prediction...
# Total elapsed time: 3.15582
# Starting prediction...
# Total elapsed time: 3.62261
# Starting prediction...
# Total elapsed time: 6.44214
# Starting prediction...
# Total elapsed time: 18.8299
# Starting prediction...
# Total elapsed time: 29.8463
# Starting prediction...
# Total elapsed time: 33.234
# Starting prediction...
# Total elapsed time: 38.007
# Starting prediction...
# Total elapsed time: 34.0782
# Total elapsed time: 34.0788
# Starting prediction...
# Total elapsed time: 28.3925
# ========================================================================
# AUROC:  0.6301280132298693
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.12717
# Starting prediction...
# Total elapsed time: 3.12457
# Starting prediction...
# Total elapsed time: 3.12305
# Starting prediction...
# Total elapsed time: 3.37363
# Starting prediction...
# Total elapsed time: 5.88224
# Starting prediction...
# Total elapsed time: 17.7533
# Starting prediction...
# Total elapsed time: 31.9224
# Starting prediction...
# Total elapsed time: 33.9572
# Starting prediction...
# Total elapsed time: 34.2012
# Starting prediction...
# Total elapsed time: 36.8991
# Total elapsed time: 36.9
# Starting prediction...
# Total elapsed time: 29.4196
# ========================================================================
# AUROC:  0.6285085810329408
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.09692
# Starting prediction...
# Total elapsed time: 3.07351
# Starting prediction...
# Total elapsed time: 3.11548
# Starting prediction...
# Total elapsed time: 3.59047
# Starting prediction...
# Total elapsed time: 6.09358
# Starting prediction...
# Total elapsed time: 18.0705
# Starting prediction...
# Total elapsed time: 28.7503
# Starting prediction...
# Total elapsed time: 35.5196
# Starting prediction...
# Total elapsed time: 35.6147
# Starting prediction...
# Total elapsed time: 33.562
# Total elapsed time: 33.563
# Starting prediction...
# Total elapsed time: 27.9834
# ========================================================================
# AUROC:  0.6193811964375735
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.05643
# Starting prediction...
# Total elapsed time: 3.19804
# Starting prediction...
# Total elapsed time: 3.20605
# Starting prediction...
# Total elapsed time: 3.42021
# Starting prediction...
# Total elapsed time: 6.05631
# Starting prediction...
# Total elapsed time: 19.2302
# Starting prediction...
# Total elapsed time: 29.3241
# Starting prediction...
# Total elapsed time: 32.5454
# Starting prediction...
# Total elapsed time: 33.1906
# Starting prediction...
# Total elapsed time: 36.9403
# Total elapsed time: 36.9411
# Starting prediction...
# Total elapsed time: 28.7584
# ========================================================================
# AUROC:  0.6447621399176955
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.30229
# Starting prediction...
# Total elapsed time: 3.41397
# Starting prediction...
# Total elapsed time: 3.18748
# Starting prediction...
# Total elapsed time: 3.41751
# Starting prediction...
# Total elapsed time: 6.00689
# Starting prediction...
# Total elapsed time: 17.1669
# Starting prediction...
# Total elapsed time: 29.4882
# Starting prediction...
# Total elapsed time: 36.703
# Starting prediction...
# Total elapsed time: 36.4542
# Starting prediction...
# Total elapsed time: 33.8115
# Total elapsed time: 33.8122
# Starting prediction...
# Total elapsed time: 28.7752
# ========================================================================
# AUROC:  0.6407180201436457
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.12776
# Starting prediction...
# Total elapsed time: 3.09603
# Starting prediction...
# Total elapsed time: 3.10671
# Starting prediction...
# Total elapsed time: 3.42966
# Starting prediction...
# Total elapsed time: 6.05185
# Starting prediction...
# Total elapsed time: 17.9476
# Starting prediction...
# Total elapsed time: 31.8413
# Starting prediction...
# Total elapsed time: 33.8952
# Starting prediction...
# Total elapsed time: 33.6901
# Starting prediction...
# Total elapsed time: 36.8597
# Total elapsed time: 36.8606
# Starting prediction...
# Total elapsed time: 29.3636
# ========================================================================
# AUROC:  0.6336326165996071
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.63679
# Starting prediction...
# Total elapsed time: 3.13994
# Starting prediction...
# Total elapsed time: 3.14846
# Starting prediction...
# Total elapsed time: 3.50204
# Starting prediction...
# Total elapsed time: 6.13807
# Starting prediction...
# Total elapsed time: 17.9426
# Starting prediction...
# Total elapsed time: 29.3726
# Starting prediction...
# Total elapsed time: 33.7509
# Starting prediction...
# Total elapsed time: 34.0604
# Starting prediction...
# Total elapsed time: 33.8181
# Total elapsed time: 33.8189
# Starting prediction...
# Total elapsed time: 27.7765
# ========================================================================
# AUROC:  0.6470549752581733
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.09354
# Starting prediction...
# Total elapsed time: 2.8241
# Starting prediction...
# Total elapsed time: 2.88745
# Starting prediction...
# Total elapsed time: 3.46994
# Starting prediction...
# Total elapsed time: 5.66713
# Starting prediction...
# Total elapsed time: 17.2
# Starting prediction...
# Total elapsed time: 27.925
# Starting prediction...
# Total elapsed time: 32.032
# Starting prediction...
# Total elapsed time: 31.974
# Starting prediction...
# Total elapsed time: 33.2305
# Total elapsed time: 33.2308
# Starting prediction...
# Total elapsed time: 26.9379
# ========================================================================
# AUROC:  0.6171922836699809
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.6497374344851793, 0.6358912846488068, 0.6301280132298693, 0.6285085810329408, 0.6193811964375735, 0.6447621399176955, 0.6407180201436457, 0.6336326165996071, 0.6470549752581733, 0.6171922836699809]
# AUROC ===== 63.47006545423473 +/- 1.0579291769210917
# ========================================================================

# %% [markdown]
# ##** CAT  vs All

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

import numpy as np 
from src.config import Configuration as Cfg
from src.models.svm import SVM


DATASET = "cifar10"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/cifar10/OCSVM_SVDD/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/cifar10/OCSVM_SVDD/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []



## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.cifar10_val_frac = 0.1
Cfg.cifar10_normal = 3
Cfg.cifar10_outlier = -1


 # SVM parameters
Cfg.svm_nu = 0.1
Cfg.svm_GridSearchCV = 1

for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    
    # initialize OC-SVM
    ocsvm = SVM(loss="OneClassSVM", dataset=DATASET, kernel="rbf")

    # train OC-SVM model
    ocsvm.fit(GridSearch=Cfg.svm_GridSearchCV)

    # predict scores
    auc_roc = ocsvm.predict(which_set='test')
   
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    print("========================================================================",)
    AUC.append(auc_roc)

    
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean*100 ,"+/-",auc_roc_std*100)
print("========================================================================")
# Out:
# Using TensorFlow backend.
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/utils/visualization/mosaic_plot.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-6569f4f7c1be>", line 10, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')  # or 'PS', 'PDF', 'SVG'
# [INFO:] Loading data...
# The normal label used in experiment, 3
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 121s 1us/step
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.05619
# Starting prediction...
# Total elapsed time: 3.04914
# Starting prediction...
# Total elapsed time: 3.05169
# Starting prediction...
# Total elapsed time: 3.07003
# Starting prediction...
# Total elapsed time: 3.01195
# Starting prediction...
# Total elapsed time: 3.04849
# Starting prediction...
# Total elapsed time: 3.04702
# Starting prediction...
# Total elapsed time: 3.05322
# Starting prediction...
# Total elapsed time: 3.05047
# Starting prediction...
# Total elapsed time: 3.05346
# Total elapsed time: 3.05418
# Starting prediction...
# Total elapsed time: 27.2865
# ========================================================================
# AUROC:  0.6006759880799306
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.05836
# Starting prediction...
# Total elapsed time: 3.04432
# Starting prediction...
# Total elapsed time: 3.03941
# Starting prediction...
# Total elapsed time: 3.03708
# Starting prediction...
# Total elapsed time: 3.05028
# Starting prediction...
# Total elapsed time: 3.03564
# Starting prediction...
# Total elapsed time: 3.04327
# Starting prediction...
# Total elapsed time: 3.03259
# Starting prediction...
# Total elapsed time: 3.03917
# Starting prediction...
# Total elapsed time: 3.03972
# Total elapsed time: 3.04081
# Starting prediction...
# Total elapsed time: 27.2108
# ========================================================================
# AUROC:  0.6135062717203333
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.02534
# Starting prediction...
# Total elapsed time: 3.02567
# Starting prediction...
# Total elapsed time: 3.02484
# Starting prediction...
# Total elapsed time: 3.02031
# Starting prediction...
# Total elapsed time: 3.00103
# Starting prediction...
# Total elapsed time: 3.02297
# Starting prediction...
# Total elapsed time: 3.03713
# Starting prediction...
# Total elapsed time: 3.03284
# Starting prediction...
# Total elapsed time: 3.0217
# Starting prediction...
# Total elapsed time: 3.02938
# Total elapsed time: 3.03016
# Starting prediction...
# Total elapsed time: 27.3104
# ========================================================================
# AUROC:  0.6185373856019173
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.027
# Starting prediction...
# Total elapsed time: 3.03199
# Starting prediction...
# Total elapsed time: 3.02208
# Starting prediction...
# Total elapsed time: 3.0096
# Starting prediction...
# Total elapsed time: 3.02415
# Starting prediction...
# Total elapsed time: 3.03422
# Starting prediction...
# Total elapsed time: 3.0376
# Starting prediction...
# Total elapsed time: 3.04422
# Starting prediction...
# Total elapsed time: 3.0337
# Starting prediction...
# Total elapsed time: 3.04576
# Total elapsed time: 3.04679
# Starting prediction...
# Total elapsed time: 27.2213
# ========================================================================
# AUROC:  0.6025785734232274
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.03314
# Starting prediction...
# Total elapsed time: 3.03537
# Starting prediction...
# Total elapsed time: 3.01667
# Starting prediction...
# Total elapsed time: 3.0226
# Starting prediction...
# Total elapsed time: 3.04069
# Starting prediction...
# Total elapsed time: 3.02283
# Starting prediction...
# Total elapsed time: 3.02175
# Starting prediction...
# Total elapsed time: 3.01539
# Starting prediction...
# Total elapsed time: 3.01205
# Starting prediction...
# Total elapsed time: 3.02259
# Total elapsed time: 3.02286
# Starting prediction...
# Total elapsed time: 27.1464
# ========================================================================
# AUROC:  0.6039921861871954
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.00329
# Starting prediction...
# Total elapsed time: 3.0165
# Starting prediction...
# Total elapsed time: 3.01268
# Starting prediction...
# Total elapsed time: 3.02005
# Starting prediction...
# Total elapsed time: 3.01696
# Starting prediction...
# Total elapsed time: 3.01964
# Starting prediction...
# Total elapsed time: 3.01828
# Starting prediction...
# Total elapsed time: 3.00606
# Starting prediction...
# Total elapsed time: 3.0277
# Starting prediction...
# Total elapsed time: 3.01585
# Total elapsed time: 3.01667
# Starting prediction...
# Total elapsed time: 27.1972
# ========================================================================
# AUROC:  0.5996559670781892
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.02792
# Starting prediction...
# Total elapsed time: 3.01406
# Starting prediction...
# Total elapsed time: 3.00619
# Starting prediction...
# Total elapsed time: 3.01554
# Starting prediction...
# Total elapsed time: 3.02284
# Starting prediction...
# Total elapsed time: 3.01834
# Starting prediction...
# Total elapsed time: 3.01624
# Starting prediction...
# Total elapsed time: 3.02597
# Starting prediction...
# Total elapsed time: 3.00555
# Starting prediction...
# Total elapsed time: 3.02156
# Total elapsed time: 3.02194
# Starting prediction...
# Total elapsed time: 27.1302
# ========================================================================
# AUROC:  0.5867471858142169
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.00956
# Starting prediction...
# Total elapsed time: 3.01948
# Starting prediction...
# Total elapsed time: 3.00709
# Starting prediction...
# Total elapsed time: 3.00767
# Starting prediction...
# Total elapsed time: 3.01794
# Starting prediction...
# Total elapsed time: 3.03158
# Starting prediction...
# Total elapsed time: 3.02089
# Starting prediction...
# Total elapsed time: 3.01127
# Starting prediction...
# Total elapsed time: 3.01579
# Starting prediction...
# Total elapsed time: 3.01883
# Total elapsed time: 3.01915
# Starting prediction...
# Total elapsed time: 27.1077
# ========================================================================
# AUROC:  0.597365227431968
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3
# Starting prediction...
# Total elapsed time: 2.99023
# Starting prediction...
# Total elapsed time: 3.0051
# Starting prediction...
# Total elapsed time: 3.00293
# Starting prediction...
# Total elapsed time: 3.00927
# Starting prediction...
# Total elapsed time: 3.01422
# Starting prediction...
# Total elapsed time: 3.00947
# Starting prediction...
# Total elapsed time: 2.98711
# Starting prediction...
# Total elapsed time: 3.00212
# Starting prediction...
# Total elapsed time: 2.98388
# Total elapsed time: 2.98412
# Starting prediction...
# Total elapsed time: 27.0241
# ========================================================================
# AUROC:  0.5896769588193815
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 2.99677
# Starting prediction...
# Total elapsed time: 2.98867
# Starting prediction...
# Total elapsed time: 3.00892
# Starting prediction...
# Total elapsed time: 3.00127
# Starting prediction...
# Total elapsed time: 3.01468
# Starting prediction...
# Total elapsed time: 3.00436
# Starting prediction...
# Total elapsed time: 3.02531
# Starting prediction...
# Total elapsed time: 3.00961
# Starting prediction...
# Total elapsed time: 3.02273
# Starting prediction...
# Total elapsed time: 3.02365
# Total elapsed time: 3.02435
# Starting prediction...
# Total elapsed time: 27.1603
# ========================================================================
# AUROC:  0.6130901764163805
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.6006759880799306, 0.6135062717203333, 0.6185373856019173, 0.6025785734232274, 0.6039921861871954, 0.5996559670781892, 0.5867471858142169, 0.597365227431968, 0.5896769588193815, 0.6130901764163805]
# AUROC ===== 60.258259205727406 +/- 0.9710896670953003
# ========================================================================

# %% [markdown]
# ##** DEER  vs All

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

import numpy as np 
from src.config import Configuration as Cfg
from src.models.svm import SVM


DATASET = "cifar10"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/cifar10/OCSVM_SVDD/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/cifar10/OCSVM_SVDD/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []



## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.cifar10_val_frac = 0.1
Cfg.cifar10_normal = 4
Cfg.cifar10_outlier = -1


 # SVM parameters
Cfg.svm_nu = 0.1
Cfg.svm_GridSearchCV = 1

for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    
    # initialize OC-SVM
    ocsvm = SVM(loss="OneClassSVM", dataset=DATASET, kernel="rbf")

    # train OC-SVM model
    ocsvm.fit(GridSearch=Cfg.svm_GridSearchCV)

    # predict scores
    auc_roc = ocsvm.predict(which_set='test')
   
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    print("========================================================================",)
    AUC.append(auc_roc)

    
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean*100 ,"+/-",auc_roc_std*100)
print("========================================================================")
# Out:
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.06473
# Starting prediction...
# Total elapsed time: 3.04153
# Starting prediction...
# Total elapsed time: 3.10126
# Starting prediction...
# Total elapsed time: 3.2483
# Starting prediction...
# Total elapsed time: 4.75189
# Starting prediction...
# Total elapsed time: 15.3604
# Starting prediction...
# Total elapsed time: 28.805
# Starting prediction...
# Total elapsed time: 33.8616
# Starting prediction...
# Total elapsed time: 34.1384
# Starting prediction...
# Total elapsed time: 34.2064
# Total elapsed time: 34.2071
# Starting prediction...
# Total elapsed time: 27.4742
# ========================================================================
# AUROC:  0.6844902415400244
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.0475
# Starting prediction...
# Total elapsed time: 3.05193
# Starting prediction...
# Total elapsed time: 3.07789
# Starting prediction...
# Total elapsed time: 3.21201
# Starting prediction...
# Total elapsed time: 4.72795
# Starting prediction...
# Total elapsed time: 15.3357
# Starting prediction...
# Total elapsed time: 28.8928
# Starting prediction...
# Total elapsed time: 33.7726
# Starting prediction...
# Total elapsed time: 34.0961
# Starting prediction...
# Total elapsed time: 34.1281
# Total elapsed time: 34.1288
# Starting prediction...
# Total elapsed time: 27.3255
# ========================================================================
# AUROC:  0.7017335605912246
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.04592
# Starting prediction...
# Total elapsed time: 3.03661
# Starting prediction...
# Total elapsed time: 3.06943
# Starting prediction...
# Total elapsed time: 3.20616
# Starting prediction...
# Total elapsed time: 4.73819
# Starting prediction...
# Total elapsed time: 15.1309
# Starting prediction...
# Total elapsed time: 28.4052
# Starting prediction...
# Total elapsed time: 33.5771
# Starting prediction...
# Total elapsed time: 33.9671
# Starting prediction...
# Total elapsed time: 33.9411
# Total elapsed time: 33.9417
# Starting prediction...
# Total elapsed time: 27.3119
# ========================================================================
# AUROC:  0.695437243622629
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.03755
# Starting prediction...
# Total elapsed time: 3.05872
# Starting prediction...
# Total elapsed time: 3.07575
# Starting prediction...
# Total elapsed time: 3.20526
# Starting prediction...
# Total elapsed time: 4.68509
# Starting prediction...
# Total elapsed time: 15.0268
# Starting prediction...
# Total elapsed time: 28.1982
# Starting prediction...
# Total elapsed time: 33.3121
# Starting prediction...
# Total elapsed time: 33.8152
# Starting prediction...
# Total elapsed time: 34.1072
# Total elapsed time: 34.1075
# Starting prediction...
# Total elapsed time: 27.4426
# ========================================================================
# AUROC:  0.6869267709557081
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.05739
# Starting prediction...
# Total elapsed time: 3.06273
# Starting prediction...
# Total elapsed time: 3.09643
# Starting prediction...
# Total elapsed time: 3.21979
# Starting prediction...
# Total elapsed time: 4.77078
# Starting prediction...
# Total elapsed time: 15.3465
# Starting prediction...
# Total elapsed time: 28.4565
# Starting prediction...
# Total elapsed time: 33.5918
# Starting prediction...
# Total elapsed time: 33.8315
# Starting prediction...
# Total elapsed time: 34.3352
# Total elapsed time: 34.336
# Starting prediction...
# Total elapsed time: 27.655
# ========================================================================
# AUROC:  0.6930087380272223
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.0752
# Starting prediction...
# Total elapsed time: 3.04647
# Starting prediction...
# Total elapsed time: 3.10887
# Starting prediction...
# Total elapsed time: 3.23778
# Starting prediction...
# Total elapsed time: 4.81065
# Starting prediction...
# Total elapsed time: 15.4863
# Starting prediction...
# Total elapsed time: 29.0381
# Starting prediction...
# Total elapsed time: 33.5985
# Starting prediction...
# Total elapsed time: 34.2563
# Starting prediction...
# Total elapsed time: 34.367
# Total elapsed time: 34.3673
# Starting prediction...
# Total elapsed time: 27.5731
# ========================================================================
# AUROC:  0.7036259259259259
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.06123
# Starting prediction...
# Total elapsed time: 3.06407
# Starting prediction...
# Total elapsed time: 3.08659
# Starting prediction...
# Total elapsed time: 3.28771
# Starting prediction...
# Total elapsed time: 4.77788
# Starting prediction...
# Total elapsed time: 15.1375
# Starting prediction...
# Total elapsed time: 28.2131
# Starting prediction...
# Total elapsed time: 33.907
# Starting prediction...
# Total elapsed time: 34.1356
# Starting prediction...
# Total elapsed time: 33.7992
# Total elapsed time: 33.8003
# Starting prediction...
# Total elapsed time: 27.5008
# ========================================================================
# AUROC:  0.6964849442359863
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.05867
# Starting prediction...
# Total elapsed time: 3.07915
# Starting prediction...
# Total elapsed time: 3.10637
# Starting prediction...
# Total elapsed time: 3.20027
# Starting prediction...
# Total elapsed time: 4.73077
# Starting prediction...
# Total elapsed time: 15.1058
# Starting prediction...
# Total elapsed time: 28.9779
# Starting prediction...
# Total elapsed time: 34.0663
# Starting prediction...
# Total elapsed time: 33.9252
# Starting prediction...
# Total elapsed time: 34.3405
# Total elapsed time: 34.3415
# Starting prediction...
# Total elapsed time: 27.464
# ========================================================================
# AUROC:  0.6720854239600857
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.08306
# Starting prediction...
# Total elapsed time: 3.07544
# Starting prediction...
# Total elapsed time: 3.1146
# Starting prediction...
# Total elapsed time: 3.27538
# Starting prediction...
# Total elapsed time: 4.80271
# Starting prediction...
# Total elapsed time: 15.2572
# Starting prediction...
# Total elapsed time: 29.0145
# Starting prediction...
# Total elapsed time: 33.5433
# Starting prediction...
# Total elapsed time: 34.1237
# Starting prediction...
# Total elapsed time: 34.1245
# Total elapsed time: 34.1252
# Starting prediction...
# Total elapsed time: 27.5581
# ========================================================================
# AUROC:  0.6851392941447311
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.06811
# Starting prediction...
# Total elapsed time: 3.07581
# Starting prediction...
# Total elapsed time: 3.10019
# Starting prediction...
# Total elapsed time: 3.24335
# Starting prediction...
# Total elapsed time: 4.64136
# Starting prediction...
# Total elapsed time: 15.0279
# Starting prediction...
# Total elapsed time: 28.7002
# Starting prediction...
# Total elapsed time: 33.8547
# Starting prediction...
# Total elapsed time: 34.1327
# Starting prediction...
# Total elapsed time: 34.0257
# Total elapsed time: 34.0268
# Starting prediction...
# Total elapsed time: 27.3903
# ========================================================================
# AUROC:  0.696345079291455
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.6844902415400244, 0.7017335605912246, 0.695437243622629, 0.6869267709557081, 0.6930087380272223, 0.7036259259259259, 0.6964849442359863, 0.6720854239600857, 0.6851392941447311, 0.696345079291455]
# AUROC ===== 69.15277222294993 +/- 0.8973819009852722
# ========================================================================

# %% [markdown]
# ##** DOG  vs All

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

import numpy as np 
from src.config import Configuration as Cfg
from src.models.svm import SVM


DATASET = "cifar10"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/cifar10/OCSVM_SVDD/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/cifar10/OCSVM_SVDD/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []



## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.cifar10_val_frac = 0.1
Cfg.cifar10_normal = 5
Cfg.cifar10_outlier = -1


 # SVM parameters
Cfg.svm_nu = 0.1
Cfg.svm_GridSearchCV = 1

for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    
    # initialize OC-SVM
    ocsvm = SVM(loss="OneClassSVM", dataset=DATASET, kernel="rbf")

    # train OC-SVM model
    ocsvm.fit(GridSearch=Cfg.svm_GridSearchCV)

    # predict scores
    auc_roc = ocsvm.predict(which_set='test')
   
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    print("========================================================================",)
    AUC.append(auc_roc)

    
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean*100 ,"+/-",auc_roc_std*100)
print("========================================================================")
# Out:
# Using TensorFlow backend.
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/utils/visualization/mosaic_plot.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-6569f4f7c1be>", line 10, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')  # or 'PS', 'PDF', 'SVG'
# [INFO:] Loading data...
# The normal label used in experiment, 5
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 30s 0us/step
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.05316
# Starting prediction...
# Total elapsed time: 3.05442
# Starting prediction...
# Total elapsed time: 3.05031
# Starting prediction...
# Total elapsed time: 3.04562
# Starting prediction...
# Total elapsed time: 3.04319
# Starting prediction...
# Total elapsed time: 3.04919
# Starting prediction...
# Total elapsed time: 3.02962
# Starting prediction...
# Total elapsed time: 3.03515
# Starting prediction...
# Total elapsed time: 3.03983
# Starting prediction...
# Total elapsed time: 3.01917
# Total elapsed time: 3.02023
# Starting prediction...
# Total elapsed time: 27.2619
# ========================================================================
# AUROC:  0.6528786022604934
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.03437
# Starting prediction...
# Total elapsed time: 3.02895
# Starting prediction...
# Total elapsed time: 3.06049
# Starting prediction...
# Total elapsed time: 3.04642
# Starting prediction...
# Total elapsed time: 3.05774
# Starting prediction...
# Total elapsed time: 3.0448
# Starting prediction...
# Total elapsed time: 3.0614
# Starting prediction...
# Total elapsed time: 3.03824
# Starting prediction...
# Total elapsed time: 3.05669
# Starting prediction...
# Total elapsed time: 2.95139
# Total elapsed time: 2.95197
# Starting prediction...
# Total elapsed time: 26.6742
# ========================================================================
# AUROC:  0.6889963587842256
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 2.95052
# Starting prediction...
# Total elapsed time: 2.9694
# Starting prediction...
# Total elapsed time: 2.98521
# Starting prediction...
# Total elapsed time: 2.97156
# Starting prediction...
# Total elapsed time: 3.06548
# Starting prediction...
# Total elapsed time: 3.06914
# Starting prediction...
# Total elapsed time: 3.04381
# Starting prediction...
# Total elapsed time: 3.05567
# Starting prediction...
# Total elapsed time: 3.05788
# Starting prediction...
# Total elapsed time: 3.06416
# Total elapsed time: 3.0647
# Starting prediction...
# Total elapsed time: 27.4928
# ========================================================================
# AUROC:  0.6530289535890451
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.05229
# Starting prediction...
# Total elapsed time: 3.05184
# Starting prediction...
# Total elapsed time: 3.06779
# Starting prediction...
# Total elapsed time: 3.08129
# Starting prediction...
# Total elapsed time: 3.01116
# Starting prediction...
# Total elapsed time: 3.06181
# Starting prediction...
# Total elapsed time: 3.0555
# Starting prediction...
# Total elapsed time: 3.05145
# Starting prediction...
# Total elapsed time: 3.04231
# Starting prediction...
# Total elapsed time: 3.0837
# Total elapsed time: 3.08448
# Starting prediction...
# Total elapsed time: 27.4859
# ========================================================================
# AUROC:  0.6360794982681133
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.0525
# Starting prediction...
# Total elapsed time: 3.03877
# Starting prediction...
# Total elapsed time: 3.07137
# Starting prediction...
# Total elapsed time: 3.05194
# Starting prediction...
# Total elapsed time: 3.05982
# Starting prediction...
# Total elapsed time: 3.05332
# Starting prediction...
# Total elapsed time: 3.04704
# Starting prediction...
# Total elapsed time: 3.05235
# Starting prediction...
# Total elapsed time: 3.05332
# Starting prediction...
# Total elapsed time: 3.06794
# Total elapsed time: 3.06905
# Starting prediction...
# Total elapsed time: 27.4608
# ========================================================================
# AUROC:  0.6766215762056798
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.0597
# Starting prediction...
# Total elapsed time: 3.04891
# Starting prediction...
# Total elapsed time: 3.0387
# Starting prediction...
# Total elapsed time: 2.99562
# Starting prediction...
# Total elapsed time: 3.03931
# Starting prediction...
# Total elapsed time: 3.03758
# Starting prediction...
# Total elapsed time: 3.03859
# Starting prediction...
# Total elapsed time: 3.03502
# Starting prediction...
# Total elapsed time: 3.03686
# Starting prediction...
# Total elapsed time: 3.03553
# Total elapsed time: 3.03722
# Starting prediction...
# Total elapsed time: 27.2343
# ========================================================================
# AUROC:  0.6612555555555555
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.04496
# Starting prediction...
# Total elapsed time: 3.04712
# Starting prediction...
# Total elapsed time: 3.04594
# Starting prediction...
# Total elapsed time: 3.03383
# Starting prediction...
# Total elapsed time: 3.03483
# Starting prediction...
# Total elapsed time: 3.04408
# Starting prediction...
# Total elapsed time: 3.0559
# Starting prediction...
# Total elapsed time: 3.02997
# Starting prediction...
# Total elapsed time: 3.0492
# Starting prediction...
# Total elapsed time: 3.06356
# Total elapsed time: 3.06383
# Starting prediction...
# Total elapsed time: 27.4824
# ========================================================================
# AUROC:  0.6640572087850409
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.02262
# Starting prediction...
# Total elapsed time: 3.05504
# Starting prediction...
# Total elapsed time: 3.00491
# Starting prediction...
# Total elapsed time: 3.03053
# Starting prediction...
# Total elapsed time: 3.02862
# Starting prediction...
# Total elapsed time: 3.03416
# Starting prediction...
# Total elapsed time: 3.04249
# Starting prediction...
# Total elapsed time: 3.03494
# Starting prediction...
# Total elapsed time: 3.04196
# Starting prediction...
# Total elapsed time: 3.0355
# Total elapsed time: 3.03577
# Starting prediction...
# Total elapsed time: 27.3875
# ========================================================================
# AUROC:  0.6439776656232451
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.03318
# Starting prediction...
# Total elapsed time: 3.02078
# Starting prediction...
# Total elapsed time: 3.02681
# Starting prediction...
# Total elapsed time: 3.03348
# Starting prediction...
# Total elapsed time: 3.02264
# Starting prediction...
# Total elapsed time: 3.02884
# Starting prediction...
# Total elapsed time: 3.0274
# Starting prediction...
# Total elapsed time: 3.05215
# Starting prediction...
# Total elapsed time: 3.04914
# Starting prediction...
# Total elapsed time: 3.05509
# Total elapsed time: 3.05627
# Starting prediction...
# Total elapsed time: 27.3158
# ========================================================================
# AUROC:  0.6640428032980269
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.03774
# Starting prediction...
# Total elapsed time: 3.01119
# Starting prediction...
# Total elapsed time: 3.03193
# Starting prediction...
# Total elapsed time: 3.01708
# Starting prediction...
# Total elapsed time: 3.03655
# Starting prediction...
# Total elapsed time: 3.02143
# Starting prediction...
# Total elapsed time: 3.0332
# Starting prediction...
# Total elapsed time: 3.02122
# Starting prediction...
# Total elapsed time: 3.04217
# Starting prediction...
# Total elapsed time: 3.04189
# Total elapsed time: 3.04225
# Starting prediction...
# Total elapsed time: 27.4011
# ========================================================================
# AUROC:  0.6831057725226303
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.6528786022604934, 0.6889963587842256, 0.6530289535890451, 0.6360794982681133, 0.6766215762056798, 0.6612555555555555, 0.6640572087850409, 0.6439776656232451, 0.6640428032980269, 0.6831057725226303]
# AUROC ===== 66.24043994892055 +/- 1.5986644395663785
# ========================================================================

# %% [markdown]
# ##** FROG  vs All

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

import numpy as np 
from src.config import Configuration as Cfg
from src.models.svm import SVM


DATASET = "cifar10"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/cifar10/OCSVM_SVDD/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/cifar10/OCSVM_SVDD/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []



## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.cifar10_val_frac = 0.1
Cfg.cifar10_normal = 6
Cfg.cifar10_outlier = -1


 # SVM parameters
Cfg.svm_nu = 0.1
Cfg.svm_GridSearchCV = 1

for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    
    # initialize OC-SVM
    ocsvm = SVM(loss="OneClassSVM", dataset=DATASET, kernel="rbf")

    # train OC-SVM model
    ocsvm.fit(GridSearch=Cfg.svm_GridSearchCV)

    # predict scores
    auc_roc = ocsvm.predict(which_set='test')
   
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    print("========================================================================",)
    AUC.append(auc_roc)

    
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean*100 ,"+/-",auc_roc_std*100)
print("========================================================================")
# Out:
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.01791
# Starting prediction...
# Total elapsed time: 3.03815
# Starting prediction...
# Total elapsed time: 3.01979
# Starting prediction...
# Total elapsed time: 3.03642
# Starting prediction...
# Total elapsed time: 3.02414
# Starting prediction...
# Total elapsed time: 3.03104
# Starting prediction...
# Total elapsed time: 3.01862
# Starting prediction...
# Total elapsed time: 3.03882
# Starting prediction...
# Total elapsed time: 3.02979
# Starting prediction...
# Total elapsed time: 3.03785
# Total elapsed time: 3.03842
# Starting prediction...
# Total elapsed time: 27.3854
# ========================================================================
# AUROC:  0.7143056019601293
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.02761
# Starting prediction...
# Total elapsed time: 3.02353
# Starting prediction...
# Total elapsed time: 3.03393
# Starting prediction...
# Total elapsed time: 3.02239
# Starting prediction...
# Total elapsed time: 3.0409
# Starting prediction...
# Total elapsed time: 3.03407
# Starting prediction...
# Total elapsed time: 3.06752
# Starting prediction...
# Total elapsed time: 3.02653
# Starting prediction...
# Total elapsed time: 3.01087
# Starting prediction...
# Total elapsed time: 3.01842
# Total elapsed time: 3.0192
# Starting prediction...
# Total elapsed time: 27.0995
# ========================================================================
# AUROC:  0.7305014886830217
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 2.98864
# Starting prediction...
# Total elapsed time: 3.00019
# Starting prediction...
# Total elapsed time: 3.02701
# Starting prediction...
# Total elapsed time: 2.9899
# Starting prediction...
# Total elapsed time: 3.00371
# Starting prediction...
# Total elapsed time: 3.021
# Starting prediction...
# Total elapsed time: 3.02618
# Starting prediction...
# Total elapsed time: 3.01241
# Starting prediction...
# Total elapsed time: 3.01804
# Starting prediction...
# Total elapsed time: 3.0419
# Total elapsed time: 3.04251
# Starting prediction...
# Total elapsed time: 27.259
# ========================================================================
# AUROC:  0.7296406296775221
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 2.96505
# Starting prediction...
# Total elapsed time: 2.99431
# Starting prediction...
# Total elapsed time: 3.00903
# Starting prediction...
# Total elapsed time: 3.01287
# Starting prediction...
# Total elapsed time: 3.00062
# Starting prediction...
# Total elapsed time: 3.00634
# Starting prediction...
# Total elapsed time: 3.02542
# Starting prediction...
# Total elapsed time: 3.00377
# Starting prediction...
# Total elapsed time: 3.02151
# Starting prediction...
# Total elapsed time: 3.01313
# Total elapsed time: 3.01383
# Starting prediction...
# Total elapsed time: 27.0235
# ========================================================================
# AUROC:  0.7035553890551872
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.02802
# Starting prediction...
# Total elapsed time: 3.01998
# Starting prediction...
# Total elapsed time: 2.99267
# Starting prediction...
# Total elapsed time: 2.97778
# Starting prediction...
# Total elapsed time: 3.02263
# Starting prediction...
# Total elapsed time: 3.0083
# Starting prediction...
# Total elapsed time: 2.97759
# Starting prediction...
# Total elapsed time: 2.99467
# Starting prediction...
# Total elapsed time: 3.02866
# Starting prediction...
# Total elapsed time: 3.00821
# Total elapsed time: 3.0089
# Starting prediction...
# Total elapsed time: 27.0782
# ========================================================================
# AUROC:  0.6971210720887246
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.00222
# Starting prediction...
# Total elapsed time: 3.02084
# Starting prediction...
# Total elapsed time: 3.03026
# Starting prediction...
# Total elapsed time: 3.01694
# Starting prediction...
# Total elapsed time: 3.01215
# Starting prediction...
# Total elapsed time: 2.99222
# Starting prediction...
# Total elapsed time: 3.0051
# Starting prediction...
# Total elapsed time: 2.99702
# Starting prediction...
# Total elapsed time: 3.00872
# Starting prediction...
# Total elapsed time: 2.99659
# Total elapsed time: 2.99691
# Starting prediction...
# Total elapsed time: 27.1679
# ========================================================================
# AUROC:  0.7301827160493828
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.05346
# Starting prediction...
# Total elapsed time: 2.9392
# Starting prediction...
# Total elapsed time: 3.06439
# Starting prediction...
# Total elapsed time: 3.05628
# Starting prediction...
# Total elapsed time: 3.02052
# Starting prediction...
# Total elapsed time: 3.07597
# Starting prediction...
# Total elapsed time: 3.04207
# Starting prediction...
# Total elapsed time: 3.05225
# Starting prediction...
# Total elapsed time: 3.02801
# Starting prediction...
# Total elapsed time: 3.02632
# Total elapsed time: 3.0266
# Starting prediction...
# Total elapsed time: 27.2449
# ========================================================================
# AUROC:  0.71973224958164
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.03336
# Starting prediction...
# Total elapsed time: 3.03509
# Starting prediction...
# Total elapsed time: 3.02527
# Starting prediction...
# Total elapsed time: 3.02488
# Starting prediction...
# Total elapsed time: 3.01018
# Starting prediction...
# Total elapsed time: 3.05668
# Starting prediction...
# Total elapsed time: 3.02554
# Starting prediction...
# Total elapsed time: 3.04366
# Starting prediction...
# Total elapsed time: 3.06914
# Starting prediction...
# Total elapsed time: 3.04601
# Total elapsed time: 3.04681
# Starting prediction...
# Total elapsed time: 27.3721
# ========================================================================
# AUROC:  0.7023479236482045
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.03242
# Starting prediction...
# Total elapsed time: 3.03899
# Starting prediction...
# Total elapsed time: 3.04455
# Starting prediction...
# Total elapsed time: 3.03343
# Starting prediction...
# Total elapsed time: 3.08314
# Starting prediction...
# Total elapsed time: 3.05836
# Starting prediction...
# Total elapsed time: 3.06686
# Starting prediction...
# Total elapsed time: 3.05189
# Starting prediction...
# Total elapsed time: 3.00297
# Starting prediction...
# Total elapsed time: 3.04793
# Total elapsed time: 3.04821
# Starting prediction...
# Total elapsed time: 27.4478
# ========================================================================
# AUROC:  0.711822208309991
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.04829
# Starting prediction...
# Total elapsed time: 3.03999
# Starting prediction...
# Total elapsed time: 3.0667
# Starting prediction...
# Total elapsed time: 3.02311
# Starting prediction...
# Total elapsed time: 3.05337
# Starting prediction...
# Total elapsed time: 3.04214
# Starting prediction...
# Total elapsed time: 3.06293
# Starting prediction...
# Total elapsed time: 3.04476
# Starting prediction...
# Total elapsed time: 3.02231
# Starting prediction...
# Total elapsed time: 3.03398
# Total elapsed time: 3.03424
# Starting prediction...
# Total elapsed time: 27.3509
# ========================================================================
# AUROC:  0.7181599948626516
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.7143056019601293, 0.7305014886830217, 0.7296406296775221, 0.7035553890551872, 0.6971210720887246, 0.7301827160493828, 0.71973224958164, 0.7023479236482045, 0.711822208309991, 0.7181599948626516]
# AUROC ===== 71.57369273916456 +/- 1.1547289538324372
# ========================================================================

# %% [markdown]
# ##** HORSE  vs All

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

import numpy as np 
from src.config import Configuration as Cfg
from src.models.svm import SVM


DATASET = "cifar10"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/cifar10/OCSVM_SVDD/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/cifar10/OCSVM_SVDD/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []



## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.cifar10_val_frac = 0.1
Cfg.cifar10_normal = 7
Cfg.cifar10_outlier = -1


 # SVM parameters
Cfg.svm_nu = 0.1
Cfg.svm_GridSearchCV = 1

for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    
    # initialize OC-SVM
    ocsvm = SVM(loss="OneClassSVM", dataset=DATASET, kernel="rbf")

    # train OC-SVM model
    ocsvm.fit(GridSearch=Cfg.svm_GridSearchCV)

    # predict scores
    auc_roc = ocsvm.predict(which_set='test')
   
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    print("========================================================================",)
    AUC.append(auc_roc)

    
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean*100 ,"+/-",auc_roc_std*100)
print("========================================================================")
# Out:
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.06272
# Starting prediction...
# Total elapsed time: 3.05488
# Starting prediction...
# Total elapsed time: 3.04778
# Starting prediction...
# Total elapsed time: 3.02241
# Starting prediction...
# Total elapsed time: 2.98508
# Starting prediction...
# Total elapsed time: 2.99613
# Starting prediction...
# Total elapsed time: 2.97702
# Starting prediction...
# Total elapsed time: 2.98764
# Starting prediction...
# Total elapsed time: 2.98848
# Starting prediction...
# Total elapsed time: 3.00079
# Total elapsed time: 3.00106
# Starting prediction...
# Total elapsed time: 27.1017
# ========================================================================
# AUROC:  0.6164354031460613
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 2.94144
# Starting prediction...
# Total elapsed time: 2.97797
# Starting prediction...
# Total elapsed time: 3.04818
# Starting prediction...
# Total elapsed time: 3.07619
# Starting prediction...
# Total elapsed time: 3.05702
# Starting prediction...
# Total elapsed time: 3.07137
# Starting prediction...
# Total elapsed time: 3.07644
# Starting prediction...
# Total elapsed time: 3.04993
# Starting prediction...
# Total elapsed time: 3.01322
# Starting prediction...
# Total elapsed time: 3.01448
# Total elapsed time: 3.01474
# Starting prediction...
# Total elapsed time: 27.3272
# ========================================================================
# AUROC:  0.633853265974714
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.04201
# Starting prediction...
# Total elapsed time: 3.0446
# Starting prediction...
# Total elapsed time: 3.07313
# Starting prediction...
# Total elapsed time: 3.03382
# Starting prediction...
# Total elapsed time: 3.06147
# Starting prediction...
# Total elapsed time: 3.05757
# Starting prediction...
# Total elapsed time: 3.04384
# Starting prediction...
# Total elapsed time: 3.00349
# Starting prediction...
# Total elapsed time: 3.04924
# Starting prediction...
# Total elapsed time: 3.05486
# Total elapsed time: 3.05521
# Starting prediction...
# Total elapsed time: 27.4064
# ========================================================================
# AUROC:  0.6284237649064796
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.03744
# Starting prediction...
# Total elapsed time: 3.06478
# Starting prediction...
# Total elapsed time: 3.04849
# Starting prediction...
# Total elapsed time: 3.05657
# Starting prediction...
# Total elapsed time: 3.0301
# Starting prediction...
# Total elapsed time: 3.01608
# Starting prediction...
# Total elapsed time: 3.0273
# Starting prediction...
# Total elapsed time: 3.05195
# Starting prediction...
# Total elapsed time: 3.0461
# Starting prediction...
# Total elapsed time: 3.06606
# Total elapsed time: 3.06718
# Starting prediction...
# Total elapsed time: 27.4863
# ========================================================================
# AUROC:  0.6516480909641624
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.04306
# Starting prediction...
# Total elapsed time: 3.0472
# Starting prediction...
# Total elapsed time: 3.04808
# Starting prediction...
# Total elapsed time: 3.05659
# Starting prediction...
# Total elapsed time: 3.04813
# Starting prediction...
# Total elapsed time: 3.03861
# Starting prediction...
# Total elapsed time: 3.03682
# Starting prediction...
# Total elapsed time: 3.03893
# Starting prediction...
# Total elapsed time: 3.043
# Starting prediction...
# Total elapsed time: 3.05378
# Total elapsed time: 3.05471
# Starting prediction...
# Total elapsed time: 27.4611
# ========================================================================
# AUROC:  0.6289711813140649
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.04776
# Starting prediction...
# Total elapsed time: 3.05095
# Starting prediction...
# Total elapsed time: 3.04462
# Starting prediction...
# Total elapsed time: 3.04338
# Starting prediction...
# Total elapsed time: 3.01185
# Starting prediction...
# Total elapsed time: 3.04873
# Starting prediction...
# Total elapsed time: 3.00143
# Starting prediction...
# Total elapsed time: 3.04737
# Starting prediction...
# Total elapsed time: 3.04817
# Starting prediction...
# Total elapsed time: 3.06859
# Total elapsed time: 3.06924
# Starting prediction...
# Total elapsed time: 27.4772
# ========================================================================
# AUROC:  0.6431781893004115
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.03823
# Starting prediction...
# Total elapsed time: 3.07057
# Total elapsed time: 3.05301
# Starting prediction...
# Total elapsed time: 3.0356
# Starting prediction...
# Total elapsed time: 3.05308
# Starting prediction...
# Total elapsed time: 3.04723
# Starting prediction...
# Total elapsed time: 3.03913
# Starting prediction...
# Total elapsed time: 3.07634
# Starting prediction...
# Total elapsed time: 3.07505
# Starting prediction...
# Total elapsed time: 27.4681
# ========================================================================
# AUROC:  0.6329478531114552
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.06009
# Starting prediction...
# Total elapsed time: 3.0513
# Starting prediction...
# Total elapsed time: 3.05583
# Starting prediction...
# Total elapsed time: 3.04095
# Starting prediction...
# Total elapsed time: 3.06918
# Starting prediction...
# Total elapsed time: 3.05274
# Starting prediction...
# Total elapsed time: 3.05065
# Starting prediction...
# Total elapsed time: 3.0437
# Starting prediction...
# Total elapsed time: 3.05058
# Starting prediction...
# Total elapsed time: 3.0578
# Total elapsed time: 3.05882
# Starting prediction...
# Total elapsed time: 27.5338
# ========================================================================
# AUROC:  0.6366299485324403
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.03822
# Starting prediction...
# Total elapsed time: 3.08038
# Starting prediction...
# Total elapsed time: 3.0388
# Starting prediction...
# Total elapsed time: 3.06241
# Starting prediction...
# Total elapsed time: 3.06171
# Starting prediction...
# Total elapsed time: 3.00063
# Starting prediction...
# Total elapsed time: 3.05086
# Starting prediction...
# Total elapsed time: 3.05753
# Starting prediction...
# Total elapsed time: 3.0818
# Starting prediction...
# Total elapsed time: 3.05386
# Total elapsed time: 3.05464
# Starting prediction...
# Total elapsed time: 27.4143
# ========================================================================
# AUROC:  0.6293471064422326
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.0456
# Starting prediction...
# Total elapsed time: 3.04787
# Starting prediction...
# Total elapsed time: 3.0574
# Starting prediction...
# Total elapsed time: 3.0366
# Starting prediction...
# Total elapsed time: 3.03858
# Starting prediction...
# Total elapsed time: 3.04374
# Starting prediction...
# Total elapsed time: 3.03819
# Starting prediction...
# Total elapsed time: 3.05505
# Starting prediction...
# Total elapsed time: 3.02624
# Starting prediction...
# Total elapsed time: 3.02268
# Total elapsed time: 3.02369
# Starting prediction...
# Total elapsed time: 27.3686
# ========================================================================
# AUROC:  0.6372389860935742
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.6164354031460613, 0.633853265974714, 0.6284237649064796, 0.6516480909641624, 0.6289711813140649, 0.6431781893004115, 0.6329478531114552, 0.6366299485324403, 0.6293471064422326, 0.6372389860935742]
# AUROC ===== 63.38673789785596 +/- 0.8947639300970341
# ========================================================================

# %% [markdown]
# ##** SHIP  vs All

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

import numpy as np 
from src.config import Configuration as Cfg
from src.models.svm import SVM


DATASET = "cifar10"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/cifar10/OCSVM_SVDD/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/cifar10/OCSVM_SVDD/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []



## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.cifar10_val_frac = 0.1
Cfg.cifar10_normal = 8
Cfg.cifar10_outlier = -1


 # SVM parameters
Cfg.svm_nu = 0.1
Cfg.svm_GridSearchCV = 1

for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    
    # initialize OC-SVM
    ocsvm = SVM(loss="OneClassSVM", dataset=DATASET, kernel="rbf")

    # train OC-SVM model
    ocsvm.fit(GridSearch=Cfg.svm_GridSearchCV)

    # predict scores
    auc_roc = ocsvm.predict(which_set='test')
   
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    print("========================================================================",)
    AUC.append(auc_roc)

    
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean*100 ,"+/-",auc_roc_std*100)
print("========================================================================")
# Out:
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.05699
# Starting prediction...
# Total elapsed time: 3.09469
# Starting prediction...
# Total elapsed time: 3.15823
# Starting prediction...
# Total elapsed time: 3.38305
# Starting prediction...
# Total elapsed time: 6.23227
# Starting prediction...
# Total elapsed time: 20.0419
# Starting prediction...
# Total elapsed time: 32.2511
# Starting prediction...
# Total elapsed time: 33.9512
# Starting prediction...
# Total elapsed time: 34.4069
# Starting prediction...
# Total elapsed time: 34.5813
# Total elapsed time: 34.5824
# Starting prediction...
# Total elapsed time: 27.6736
# ========================================================================
# AUROC:  0.6149538316678309
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.07782
# Starting prediction...
# Total elapsed time: 3.08007
# Starting prediction...
# Total elapsed time: 3.13775
# Starting prediction...
# Total elapsed time: 3.36443
# Starting prediction...
# Total elapsed time: 6.25758
# Starting prediction...
# Total elapsed time: 19.95
# Starting prediction...
# Total elapsed time: 32.071
# Starting prediction...
# Total elapsed time: 34.3782
# Starting prediction...
# Total elapsed time: 34.4086
# Starting prediction...
# Total elapsed time: 34.5996
# Total elapsed time: 34.6
# Starting prediction...
# Total elapsed time: 27.5844
# ========================================================================
# AUROC:  0.6074034181622648
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.04352
# Starting prediction...
# Total elapsed time: 3.04827
# Starting prediction...
# Total elapsed time: 3.11024
# Starting prediction...
# Total elapsed time: 3.35793
# Starting prediction...
# Total elapsed time: 6.23856
# Starting prediction...
# Total elapsed time: 19.4821
# Starting prediction...
# Total elapsed time: 31.6811
# Starting prediction...
# Total elapsed time: 34.6599
# Starting prediction...
# Total elapsed time: 34.8963
# Starting prediction...
# Total elapsed time: 34.682
# Total elapsed time: 34.6826
# Starting prediction...
# Total elapsed time: 27.7704
# ========================================================================
# AUROC:  0.5997393112865874
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.09553
# Starting prediction...
# Total elapsed time: 3.11507
# Starting prediction...
# Total elapsed time: 3.13771
# Starting prediction...
# Total elapsed time: 3.40686
# Starting prediction...
# Total elapsed time: 6.27441
# Starting prediction...
# Total elapsed time: 20.1938
# Starting prediction...
# Total elapsed time: 31.6625
# Starting prediction...
# Total elapsed time: 34.1123
# Starting prediction...
# Total elapsed time: 34.5177
# Starting prediction...
# Total elapsed time: 34.1454
# Total elapsed time: 34.1457
# Starting prediction...
# Total elapsed time: 27.7917
# ========================================================================
# AUROC:  0.607761099452044
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.10709
# Starting prediction...
# Total elapsed time: 3.09355
# Starting prediction...
# Total elapsed time: 3.14107
# Starting prediction...
# Total elapsed time: 3.39532
# Starting prediction...
# Total elapsed time: 6.23191
# Starting prediction...
# Total elapsed time: 20.1088
# Starting prediction...
# Total elapsed time: 32.3129
# Starting prediction...
# Total elapsed time: 34.7709
# Starting prediction...
# Total elapsed time: 34.9606
# Starting prediction...
# Total elapsed time: 34.8196
# Total elapsed time: 34.8202
# Starting prediction...
# Total elapsed time: 27.6839
# ========================================================================
# AUROC:  0.6028785078138128
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.09493
# Starting prediction...
# Total elapsed time: 3.08763
# Starting prediction...
# Total elapsed time: 3.13557
# Starting prediction...
# Total elapsed time: 3.37481
# Starting prediction...
# Total elapsed time: 6.35876
# Starting prediction...
# Total elapsed time: 20.1729
# Starting prediction...
# Total elapsed time: 32.1807
# Starting prediction...
# Total elapsed time: 34.4977
# Starting prediction...
# Total elapsed time: 34.5629
# Starting prediction...
# Total elapsed time: 34.6824
# Total elapsed time: 34.6831
# Starting prediction...
# Total elapsed time: 27.4994
# ========================================================================
# AUROC:  0.5966316872427984
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.09263
# Starting prediction...
# Total elapsed time: 3.10995
# Starting prediction...
# Total elapsed time: 3.10528
# Starting prediction...
# Total elapsed time: 3.42188
# Starting prediction...
# Total elapsed time: 6.30807
# Starting prediction...
# Total elapsed time: 19.7954
# Starting prediction...
# Total elapsed time: 32.1581
# Starting prediction...
# Total elapsed time: 34.3237
# Starting prediction...
# Total elapsed time: 34.355
# Starting prediction...
# Total elapsed time: 34.7034
# Total elapsed time: 34.7045
# Starting prediction...
# Total elapsed time: 27.8285
# ========================================================================
# AUROC:  0.6294766601877164
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.06894
# Starting prediction...
# Total elapsed time: 3.10129
# Starting prediction...
# Total elapsed time: 3.11574
# Starting prediction...
# Total elapsed time: 3.3427
# Starting prediction...
# Total elapsed time: 6.22434
# Starting prediction...
# Total elapsed time: 20.183
# Starting prediction...
# Total elapsed time: 32.4532
# Starting prediction...
# Total elapsed time: 34.4672
# Starting prediction...
# Total elapsed time: 34.752
# Starting prediction...
# Total elapsed time: 34.4207
# Total elapsed time: 34.4211
# Starting prediction...
# Total elapsed time: 27.6702
# ========================================================================
# AUROC:  0.600067652661257
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.07657
# Starting prediction...
# Total elapsed time: 3.0941
# Starting prediction...
# Total elapsed time: 3.12716
# Starting prediction...
# Total elapsed time: 3.38375
# Starting prediction...
# Total elapsed time: 6.2271
# Starting prediction...
# Total elapsed time: 20.1891
# Starting prediction...
# Total elapsed time: 32.3287
# Starting prediction...
# Total elapsed time: 34.176
# Starting prediction...
# Total elapsed time: 34.6195
# Starting prediction...
# Total elapsed time: 34.5694
# Total elapsed time: 34.5701
# Starting prediction...
# Total elapsed time: 27.5902
# ========================================================================
# AUROC:  0.6008415243664862
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.07593
# Starting prediction...
# Total elapsed time: 3.10295
# Starting prediction...
# Total elapsed time: 3.08115
# Starting prediction...
# Total elapsed time: 3.3427
# Starting prediction...
# Total elapsed time: 6.23032
# Starting prediction...
# Total elapsed time: 19.9286
# Starting prediction...
# Total elapsed time: 32.166
# Starting prediction...
# Total elapsed time: 34.0699
# Starting prediction...
# Total elapsed time: 34.5157
# Starting prediction...
# Total elapsed time: 34.6775
# Total elapsed time: 34.6778
# Starting prediction...
# Total elapsed time: 27.6787
# ========================================================================
# AUROC:  0.5849063395124673
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.6149538316678309, 0.6074034181622648, 0.5997393112865874, 0.607761099452044, 0.6028785078138128, 0.5966316872427984, 0.6294766601877164, 0.600067652661257, 0.6008415243664862, 0.5849063395124673]
# AUROC ===== 60.44660032353265 +/- 1.120854413965976
# ========================================================================

# %% [markdown]
# ##** Truck vs All

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

import numpy as np 
from src.config import Configuration as Cfg
from src.models.svm import SVM


DATASET = "cifar10"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/cifar10/OCSVM_SVDD/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/cifar10/OCSVM_SVDD/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []



## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.cifar10_val_frac = 0.1
Cfg.cifar10_normal = 9
Cfg.cifar10_outlier = -1


 # SVM parameters
Cfg.svm_nu = 0.1
Cfg.svm_GridSearchCV = 1

for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    
    # initialize OC-SVM
    ocsvm = SVM(loss="OneClassSVM", dataset=DATASET, kernel="rbf")

    # train OC-SVM model
    ocsvm.fit(GridSearch=Cfg.svm_GridSearchCV)

    # predict scores
    auc_roc = ocsvm.predict(which_set='test')
   
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    print("========================================================================",)
    AUC.append(auc_roc)

    
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean*100 ,"+/-",auc_roc_std*100)
print("========================================================================")
# Out:
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.0226
# Starting prediction...
# Total elapsed time: 3.02645
# Starting prediction...
# Total elapsed time: 3.06238
# Starting prediction...
# Total elapsed time: 3.04086
# Starting prediction...
# Total elapsed time: 3.04222
# Starting prediction...
# Total elapsed time: 3.05157
# Starting prediction...
# Total elapsed time: 3.04071
# Starting prediction...
# Total elapsed time: 3.01909
# Starting prediction...
# Total elapsed time: 3.02535
# Starting prediction...
# Total elapsed time: 3.01346
# Total elapsed time: 3.01375
# Starting prediction...
# Total elapsed time: 27.2741
# ========================================================================
# AUROC:  0.738881042297347
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.05061
# Starting prediction...
# Total elapsed time: 3.04651
# Starting prediction...
# Total elapsed time: 2.99132
# Starting prediction...
# Total elapsed time: 3.03013
# Starting prediction...
# Total elapsed time: 3.00503
# Starting prediction...
# Total elapsed time: 3.0326
# Starting prediction...
# Total elapsed time: 3.02875
# Starting prediction...
# Total elapsed time: 3.03032
# Starting prediction...
# Total elapsed time: 3.03349
# Starting prediction...
# Total elapsed time: 3.01046
# Total elapsed time: 3.01073
# Starting prediction...
# Total elapsed time: 27.2249
# ========================================================================
# AUROC:  0.7564194268985273
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.04828
# Starting prediction...
# Total elapsed time: 3.02304
# Starting prediction...
# Total elapsed time: 3.0468
# Starting prediction...
# Total elapsed time: 3.00377
# Starting prediction...
# Total elapsed time: 2.99907
# Starting prediction...
# Total elapsed time: 3.01152
# Starting prediction...
# Total elapsed time: 3.04316
# Starting prediction...
# Total elapsed time: 3.0085
# Starting prediction...
# Total elapsed time: 3.05042
# Starting prediction...
# Total elapsed time: 3.04123
# Total elapsed time: 3.04181
# Starting prediction...
# Total elapsed time: 27.3148
# ========================================================================
# AUROC:  0.7586691625871945
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.03265
# Starting prediction...
# Total elapsed time: 3.04037
# Starting prediction...
# Total elapsed time: 3.03055
# Starting prediction...
# Total elapsed time: 3.0563
# Starting prediction...
# Total elapsed time: 3.02941
# Starting prediction...
# Total elapsed time: 3.03222
# Starting prediction...
# Total elapsed time: 3.05411
# Starting prediction...
# Total elapsed time: 3.03229
# Starting prediction...
# Total elapsed time: 3.04882
# Starting prediction...
# Total elapsed time: 3.04724
# Total elapsed time: 3.04752
# Starting prediction...
# Total elapsed time: 27.348
# ========================================================================
# AUROC:  0.7682795783661059
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.05346
# Starting prediction...
# Total elapsed time: 3.04626
# Starting prediction...
# Total elapsed time: 3.05304
# Starting prediction...
# Total elapsed time: 3.06495
# Starting prediction...
# Total elapsed time: 3.05611
# Starting prediction...
# Total elapsed time: 3.03856
# Starting prediction...
# Total elapsed time: 3.02774
# Starting prediction...
# Total elapsed time: 3.04455
# Starting prediction...
# Total elapsed time: 3.04985
# Starting prediction...
# Total elapsed time: 3.05018
# Total elapsed time: 3.05048
# Starting prediction...
# Total elapsed time: 27.3586
# ========================================================================
# AUROC:  0.7692904553856496
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.03711
# Starting prediction...
# Total elapsed time: 3.01614
# Starting prediction...
# Total elapsed time: 3.08
# Starting prediction...
# Total elapsed time: 3.00298
# Starting prediction...
# Total elapsed time: 3.02445
# Starting prediction...
# Total elapsed time: 3.05467
# Starting prediction...
# Total elapsed time: 3.05434
# Starting prediction...
# Total elapsed time: 3.05383
# Starting prediction...
# Total elapsed time: 3.04502
# Starting prediction...
# Total elapsed time: 3.03156
# Total elapsed time: 3.03182
# Starting prediction...
# Total elapsed time: 27.2027
# ========================================================================
# AUROC:  0.7568012345679014
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.00357
# Starting prediction...
# Total elapsed time: 3.01604
# Starting prediction...
# Total elapsed time: 3.04358
# Starting prediction...
# Total elapsed time: 3.01668
# Starting prediction...
# Total elapsed time: 3.02847
# Starting prediction...
# Total elapsed time: 3.03549
# Starting prediction...
# Total elapsed time: 3.04206
# Starting prediction...
# Total elapsed time: 3.0272
# Starting prediction...
# Total elapsed time: 3.0147
# Starting prediction...
# Total elapsed time: 3.00652
# Total elapsed time: 3.00725
# Starting prediction...
# Total elapsed time: 27.2577
# ========================================================================
# AUROC:  0.7611242191478966
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.02544
# Starting prediction...
# Total elapsed time: 3.01103
# Starting prediction...
# Total elapsed time: 3.04195
# Starting prediction...
# Total elapsed time: 3.03626
# Starting prediction...
# Total elapsed time: 3.04022
# Starting prediction...
# Total elapsed time: 3.05247
# Starting prediction...
# Total elapsed time: 3.03908
# Starting prediction...
# Total elapsed time: 3.02224
# Starting prediction...
# Total elapsed time: 3.03444
# Starting prediction...
# Total elapsed time: 3.00906
# Total elapsed time: 3.00937
# Starting prediction...
# Total elapsed time: 27.3997
# ========================================================================
# AUROC:  0.7658862069148873
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.00604
# Starting prediction...
# Total elapsed time: 3.03896
# Starting prediction...
# Total elapsed time: 3.02349
# Starting prediction...
# Total elapsed time: 3.02946
# Starting prediction...
# Total elapsed time: 3.02722
# Starting prediction...
# Total elapsed time: 3.05339
# Starting prediction...
# Total elapsed time: 3.0431
# Starting prediction...
# Total elapsed time: 3.07022
# Starting prediction...
# Total elapsed time: 3.03542
# Starting prediction...
# Total elapsed time: 3.03887
# Total elapsed time: 3.03957
# Starting prediction...
# Total elapsed time: 27.2877
# ========================================================================
# AUROC:  0.750529679219557
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 3.05427
# Starting prediction...
# Total elapsed time: 3.06258
# Starting prediction...
# Total elapsed time: 3.05578
# Starting prediction...
# Total elapsed time: 3.04618
# Starting prediction...
# Total elapsed time: 3.0387
# Starting prediction...
# Total elapsed time: 3.02682
# Starting prediction...
# Total elapsed time: 3.03992
# Starting prediction...
# Total elapsed time: 3.00748
# Starting prediction...
# Total elapsed time: 3.04042
# Starting prediction...
# Total elapsed time: 3.03484
# Total elapsed time: 3.03511
# Starting prediction...
# Total elapsed time: 27.1675
# ========================================================================
# AUROC:  0.7557587589540588
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.738881042297347, 0.7564194268985273, 0.7586691625871945, 0.7682795783661059, 0.7692904553856496, 0.7568012345679014, 0.7611242191478966, 0.7658862069148873, 0.750529679219557, 0.7557587589540588]
# AUROC ===== 75.81639764339127 +/- 0.8576564943862605
# ========================================================================
