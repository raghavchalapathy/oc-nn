# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install fuel
# !pip install picklable_itertools
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# Collecting fuel
#   Downloading https://files.pythonhosted.org/packages/16/c2/b5fb651c90e908f79769b7dd3643982b6a9b1bac9449b8ab16f72612d4f5/fuel-0.2.0.tar.gz (184kB)
#     100% |████████████████████████████████| 194kB 5.7MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from fuel) (1.14.6)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from fuel) (1.11.0)
# Collecting picklable_itertools (from fuel)
#   Downloading https://files.pythonhosted.org/packages/75/bc/cda9191f0c92960ede6aa95e364443965246385faf62775cc30749931c2c/picklable-itertools-0.1.1.tar.gz
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from fuel) (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from fuel) (2.8.0)
# Collecting tables (from fuel)
#   Downloading https://files.pythonhosted.org/packages/d7/1b/21f4c7f296b718575c17ef25e61c05742a283c45077b4c8d5a190b3e0b59/tables-3.4.4-cp36-cp36m-manylinux1_x86_64.whl (3.8MB)
#     100% |████████████████████████████████| 3.8MB 2.3MB/s
# Collecting progressbar2 (from fuel)
#   Downloading https://files.pythonhosted.org/packages/4f/6f/acb2dd76f2c77527584bd3a4c2509782bb35c481c610521fc3656de5a9e0/progressbar2-3.38.0-py2.py3-none-any.whl
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.6/dist-packages (from fuel) (17.0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from fuel) (1.1.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from fuel) (4.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from fuel) (2.18.4)
# Collecting numexpr>=2.5.2 (from tables->fuel)
#   Downloading https://files.pythonhosted.org/packages/db/ea/efd9e16283637eb5b6c0042b6cc3521f1b9a5b47767ac463c88bbd37670c/numexpr-2.6.8-cp36-cp36m-manylinux1_x86_64.whl (162kB)
#     100% |████████████████████████████████| 163kB 19.3MB/s
# Collecting python-utils>=2.3.0 (from progressbar2->fuel)
#   Downloading https://files.pythonhosted.org/packages/eb/a0/19119d8b7c05be49baf6c593f11c432d571b70d805f2fe94c0585e55e4c8/python_utils-2.3.0-py2.py3-none-any.whl
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from pillow->fuel) (0.46)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->fuel) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->fuel) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->fuel) (2018.10.15)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->fuel) (1.22)
# Building wheels for collected packages: fuel, picklable-itertools
# done
#   Stored in directory: /root/.cache/pip/wheels/96/ff/1b/f3708731cf77a6d759cd12e68c0a27700c299fbe2bffd34fa3
# done
#   Stored in directory: /root/.cache/pip/wheels/36/dd/e2/ec30ef7c475e1d9fb966735984ba05f8710c67d7de5358c326
# Successfully built fuel picklable-itertools
# Installing collected packages: picklable-itertools, numexpr, tables, python-utils, progressbar2, fuel
# Successfully installed fuel-0.2.0 numexpr-2.6.8 picklable-itertools-0.1.1 progressbar2-3.38.0 python-utils-2.3.0 tables-3.4.4
# Requirement already satisfied: picklable_itertools in /usr/local/lib/python3.6/dist-packages (0.1.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from picklable_itertools) (1.11.0)

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np

PROJECT_DIR = "/content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/"
import sys,os
import numpy as np

sys.path.append(PROJECT_DIR)

# %% [markdown]
# ##  **Soft Bound Deep SVDD _Aeroplane Vs All-**

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

from src.models.OneClass_SVDD import OneClass_SVDD
from src.models.config import Configuration as Cfg

DATASET = "cifar10"
IMG_DIM= 3072
IMG_HGT =32
IMG_WDT=32
IMG_CHANNEL=3
HIDDEN_LAYER_SIZE= 128
MODEL_SAVE_PATH = PROJECT_DIR + "/models/CIFAR10/OC_NN/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/CIFAR10/OC_NN/"
PRETRAINED_WT_PATH = ""
LOSS_FUNCTION = "SOFT_BOUND_DEEP_SVDD"
# LOSS_FUNCTION = "ONE_CLASS_DEEP_SVDD"
# LOSS_FUNCTION = "ONE_CLASS_NEURAL_NETWORK"

import os
os.chdir(PROJECT_DIR)
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []

for seed in RANDOM_SEED:  
  Cfg.seed = seed
  ocnn = OneClass_SVDD(DATASET,LOSS_FUNCTION,IMG_DIM, HIDDEN_LAYER_SIZE, IMG_HGT, IMG_WDT,IMG_CHANNEL, MODEL_SAVE_PATH, REPORT_SAVE_PATH,PRETRAINED_WT_PATH,seed)
 
  print("[INFO:] Testing with ALL other  Image Classes  as anomalies")
  ocnn.fit()
  print("==============PREDICTING THE LABELS ==============================")
  auc_score = ocnn.predict()
  AUC.append(auc_score)

print("===========TRAINING AND PREDICTING WITH OCSVDD============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# Using TensorFlow backend.
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/utils/visualization/mosaic_plot.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-78044201dfde>", line 3, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')  # or 'PS', 'PDF', 'SVG'
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/data/GTSRB.py:9: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-78044201dfde>", line 3, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')  # or 'PS', 'PDF', 'SVG'
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 20.66969759769495
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.022927124565529977
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6722494999999999
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 21.13630384847457
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.029917411156591744
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.7084269999999999
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 8.261041084509685
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.014839269602341137
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6936023333333333
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 9.442554512943687
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.01678516942092792
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.661786
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 46.11538087843735
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.012592143593267546
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6666446666666667
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 19.39480365193114
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.013278813523720248
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6694916666666667
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 15.108854383039471
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.0117174074463776
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6739130000000001
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 7.271388098871583
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.020442413620913175
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6882013333333333
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 6.097182853033004
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.021973267258939333
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6878080000000001
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 9.519928744521309
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.03957742825835947
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.7291023333333333
# ===================================
# ===========TRAINING AND PREDICTING WITH OCSVDD============================
# AUROC computed  [0.6722494999999999, 0.7084269999999999, 0.6936023333333333, 0.661786, 0.6666446666666667, 0.6694916666666667, 0.6739130000000001, 0.6882013333333333, 0.6878080000000001, 0.7291023333333333]
# AUROC ===== 0.6851225833333334 +/- 0.019969067793471906
# ========================================================================

# %% [markdown]
# ##** Horse Vs All

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

from src.models.OneClass_SVDD import OneClass_SVDD
from src.models.config import Configuration as Cfg

DATASET = "cifar10"
IMG_DIM= 3072
IMG_HGT =32
IMG_WDT=32
IMG_CHANNEL=3
HIDDEN_LAYER_SIZE= 128
MODEL_SAVE_PATH = PROJECT_DIR + "/models/CIFAR10/OC_NN/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/CIFAR10/OC_NN/"
PRETRAINED_WT_PATH = ""
LOSS_FUNCTION = "SOFT_BOUND_DEEP_SVDD"
# LOSS_FUNCTION = "ONE_CLASS_DEEP_SVDD"
# LOSS_FUNCTION = "ONE_CLASS_NEURAL_NETWORK"

import os
os.chdir(PROJECT_DIR)
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
# RANDOM_SEED = [42,56,81]
AUC = []

for seed in RANDOM_SEED:  
  Cfg.seed = seed
  ocnn = OneClass_SVDD(DATASET,LOSS_FUNCTION,IMG_DIM, HIDDEN_LAYER_SIZE, IMG_HGT, IMG_WDT,IMG_CHANNEL, MODEL_SAVE_PATH, REPORT_SAVE_PATH,PRETRAINED_WT_PATH,seed)
 
  print("[INFO:] Testing with ALL other  Image Classes  as anomalies")
  ocnn.fit()
  print("==============PREDICTING THE LABELS ==============================")
  auc_score = ocnn.predict()
  AUC.append(auc_score)

print("===========TRAINING AND PREDICTING WITH OCSVDD============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# Using TensorFlow backend.
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/utils/visualization/mosaic_plot.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-78044201dfde>", line 3, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')  # or 'PS', 'PDF', 'SVG'
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/data/GTSRB.py:9: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-78044201dfde>", line 3, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')  # or 'PS', 'PDF', 'SVG'
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 49s 0us/step
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 24.40503999324767
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.030406303338868096
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.608633
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 38.833943974895476
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.019552972548520925
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.5709006666666667
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 17.828861328743898
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.017484514503976728
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6020476666666668
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 13.65966588472314
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.01451206918809074
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.614484
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 16.084281213011394
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.0132246807396358
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.5723653333333334
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 42.40262921761996
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.021619105822875934
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6020046666666667
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 37.73378149428231
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.022207929992497266
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6002299999999999
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 34.272697532220604
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.0404498696358957
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6415771666666666
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 53.98612215794628
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.027356035289475944
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.582284
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 14.137892543911647
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.022554859175733993
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.5768951666666666
# ===================================
# ===========TRAINING AND PREDICTING WITH OCSVDD============================
# AUROC computed  [0.608633, 0.5709006666666667, 0.6020476666666668, 0.614484, 0.5723653333333334, 0.6020046666666667, 0.6002299999999999, 0.6415771666666666, 0.582284, 0.5768951666666666]
# AUROC ===== 0.5971421666666666 +/- 0.02097070367971046
# ========================================================================

# %% [markdown]
# # **  Soft  Bound Deep SVDD _        SHIP Vs All-  **##

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

from src.models.OneClass_SVDD import OneClass_SVDD
from src.models.config import Configuration as Cfg

DATASET = "cifar10"
IMG_DIM= 3072
IMG_HGT =32
IMG_WDT=32
IMG_CHANNEL=3
HIDDEN_LAYER_SIZE= 128
MODEL_SAVE_PATH = PROJECT_DIR + "/models/CIFAR10/OC_NN/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/CIFAR10/OC_NN/"
PRETRAINED_WT_PATH = ""
LOSS_FUNCTION = "SOFT_BOUND_DEEP_SVDD"
# LOSS_FUNCTION = "ONE_CLASS_DEEP_SVDD"
# LOSS_FUNCTION = "ONE_CLASS_NEURAL_NETWORK"

import os
os.chdir(PROJECT_DIR)
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []

for seed in RANDOM_SEED:  
  Cfg.seed = seed
  ocnn = OneClass_SVDD(DATASET,LOSS_FUNCTION,IMG_DIM, HIDDEN_LAYER_SIZE, IMG_HGT, IMG_WDT,IMG_CHANNEL, MODEL_SAVE_PATH, REPORT_SAVE_PATH,PRETRAINED_WT_PATH,seed)
 
  print("[INFO:] Testing with ALL other  Image Classes  as anomalies")
  ocnn.fit()
  print("==============PREDICTING THE LABELS ==============================")
  auc_score = ocnn.predict()
  AUC.append(auc_score)

print("===========TRAINING AND PREDICTING WITH OCSVDD============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# Using TensorFlow backend.
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/utils/visualization/mosaic_plot.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-78044201dfde>", line 3, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')  # or 'PS', 'PDF', 'SVG'
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/data/GTSRB.py:9: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-78044201dfde>", line 3, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')  # or 'PS', 'PDF', 'SVG'
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 19.30218529207059
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.028179321997444357
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6591313333333333
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 16.408657345132838
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.025038154083609765
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6581686666666667
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 16.34579105125934
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.02713713207219509
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6761849999999999
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 17.45234416571546
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.027668616318118427
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6640448333333334
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 17.315010121042633
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.027950505653344337
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6757376666666667
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 18.33739586752003
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.02912116281792093
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6436668333333333
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 15.7207219081169
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.029815141183224564
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.7021473333333335
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 18.07923585380803
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.02396752052214743
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6929025000000001
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 16.19532710896766
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.026899062139823487
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6972203333333333
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 15.590360545058388
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.028042274003957646
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6584146666666666
# ===================================
# ===========TRAINING AND PREDICTING WITH OCSVDD============================
# AUROC computed  [0.6591313333333333, 0.6581686666666667, 0.6761849999999999, 0.6640448333333334, 0.6757376666666667, 0.6436668333333333, 0.7021473333333335, 0.6929025000000001, 0.6972203333333333, 0.6584146666666666]
# AUROC ===== 0.6727619166666667 +/- 0.018479835738545197
# ========================================================================

# %% [markdown]
# ##** Truck Vs All

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

from src.models.OneClass_SVDD import OneClass_SVDD
from src.models.config import Configuration as Cfg

DATASET = "cifar10"
IMG_DIM= 3072
IMG_HGT =32
IMG_WDT=32
IMG_CHANNEL=3
HIDDEN_LAYER_SIZE= 128
MODEL_SAVE_PATH = PROJECT_DIR + "/models/CIFAR10/OC_NN/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/CIFAR10/OC_NN/"
PRETRAINED_WT_PATH = ""
LOSS_FUNCTION = "SOFT_BOUND_DEEP_SVDD"
# LOSS_FUNCTION = "ONE_CLASS_DEEP_SVDD"
# LOSS_FUNCTION = "ONE_CLASS_NEURAL_NETWORK"

import os
os.chdir(PROJECT_DIR)
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
# RANDOM_SEED = [42,11]
AUC = []

for seed in RANDOM_SEED:  
  Cfg.seed = seed
  ocnn = OneClass_SVDD(DATASET,LOSS_FUNCTION,IMG_DIM, HIDDEN_LAYER_SIZE, IMG_HGT, IMG_WDT,IMG_CHANNEL, MODEL_SAVE_PATH, REPORT_SAVE_PATH,PRETRAINED_WT_PATH,seed)
 
  print("[INFO:] Testing with ALL other  Image Classes  as anomalies")
  ocnn.fit()
  print("==============PREDICTING THE LABELS ==============================")
  auc_score = ocnn.predict()
  AUC.append(auc_score)

print("===========TRAINING AND PREDICTING WITH OCSVDD============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# Using TensorFlow backend.
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/utils/visualization/mosaic_plot.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-78044201dfde>", line 3, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')  # or 'PS', 'PDF', 'SVG'
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/data/GTSRB.py:9: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-78044201dfde>", line 3, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')  # or 'PS', 'PDF', 'SVG'
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 40s 0us/step
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 119.18146283705312
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 600.9070802932783
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6682618333333334
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 26.76819587857463
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 106.3816772622007
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.7254176666666665
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 31.85060730844924
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 144.59493408557773
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6824693333333334
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 41.31657874332507
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 167.08647210879985
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6435951666666667
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 103.94582836410427
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 315.39528816632446
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.7540431666666666
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 57.5409579597507
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 247.65096131198607
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.7446816666666666
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 112.27912643420666
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 570.8582888803985
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.7300606666666666
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 35.283313069998144
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 153.68735046504935
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6547014999999999
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 30.158115432032787
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 133.57315979506325
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.7285421666666667
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# INFO Saving images befoer gcn ....
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 45.9086418391982
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 143.89490357568366
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.7661286666666667
# ===================================
# ===========TRAINING AND PREDICTING WITH OCSVDD============================
# AUROC computed  [0.6682618333333334, 0.7254176666666665, 0.6824693333333334, 0.6435951666666667, 0.7540431666666666, 0.7446816666666666, 0.7300606666666666, 0.6547014999999999, 0.7285421666666667, 0.7661286666666667]
# AUROC ===== 0.7097901833333333 +/- 0.04152600440396418
# ========================================================================

# %% [markdown]
# ## **Automobile Vs All **

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

from src.models.OneClass_SVDD import OneClass_SVDD
from src.models.config import Configuration as Cfg

DATASET = "cifar10"
IMG_DIM= 3072
IMG_HGT =32
IMG_WDT=32
IMG_CHANNEL=3
HIDDEN_LAYER_SIZE= 128
MODEL_SAVE_PATH = PROJECT_DIR + "/models/CIFAR10/OC_NN/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/CIFAR10/OC_NN/"
PRETRAINED_WT_PATH = ""
LOSS_FUNCTION = "SOFT_BOUND_DEEP_SVDD"
# LOSS_FUNCTION = "ONE_CLASS_DEEP_SVDD"
# LOSS_FUNCTION = "ONE_CLASS_NEURAL_NETWORK"

import os
os.chdir(PROJECT_DIR)
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
# RANDOM_SEED = [42,11]
AUC = []

for seed in RANDOM_SEED:  
  Cfg.seed = seed
  ocnn = OneClass_SVDD(DATASET,LOSS_FUNCTION,IMG_DIM, HIDDEN_LAYER_SIZE, IMG_HGT, IMG_WDT,IMG_CHANNEL, MODEL_SAVE_PATH, REPORT_SAVE_PATH,PRETRAINED_WT_PATH,seed)
 
  print("[INFO:] Testing with ALL other  Image Classes  as anomalies")
  ocnn.fit()
  print("==============PREDICTING THE LABELS ==============================")
  auc_score = ocnn.predict()
  AUC.append(auc_score)

print("===========TRAINING AND PREDICTING WITH OCSVDD============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# Using TensorFlow backend.
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/utils/visualization/mosaic_plot.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-78044201dfde>", line 3, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')  # or 'PS', 'PDF', 'SVG'
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/data/GTSRB.py:9: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-78044201dfde>", line 3, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')  # or 'PS', 'PDF', 'SVG'
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 13s 0us/step
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 53.19378927135574
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.021467015908249204
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.5245111666666666
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 137.6245942648677
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.082370594749956
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.5253253333333333
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 7.171286058776722
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.01700558664871374
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6199878333333333
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 13.376620306055244
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.019410727175471043
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6096830000000001
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 20.70213795871888
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.016907956494469634
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.5657535
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 28.862942012732162
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.017874264221622582
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6073523333333333
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 26.18902863833668
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.015886659560602034
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.5479623333333333
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 14.709441390213897
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.015868419233680875
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6020735
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 7.086939068605233
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.027378977919092773
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.5736731666666667
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 18.740242841145175
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.02274061744838199
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.5881286666666667
# ===================================
# ===========TRAINING AND PREDICTING WITH OCSVDD============================
# AUROC computed  [0.5245111666666666, 0.5253253333333333, 0.6199878333333333, 0.6096830000000001, 0.5657535, 0.6073523333333333, 0.5479623333333333, 0.6020735, 0.5736731666666667, 0.5881286666666667]
# AUROC ===== 0.5764450833333333 +/- 0.03315558958751652
# ========================================================================

# %% [markdown]
# ##** Bird Vs All

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

from src.models.OneClass_SVDD import OneClass_SVDD
from src.models.config import Configuration as Cfg

DATASET = "cifar10"
IMG_DIM= 3072
IMG_HGT =32
IMG_WDT=32
IMG_CHANNEL=3
HIDDEN_LAYER_SIZE= 128
MODEL_SAVE_PATH = PROJECT_DIR + "/models/CIFAR10/OC_NN/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/CIFAR10/OC_NN/"
PRETRAINED_WT_PATH = ""
LOSS_FUNCTION = "SOFT_BOUND_DEEP_SVDD"
# LOSS_FUNCTION = "ONE_CLASS_DEEP_SVDD"
# LOSS_FUNCTION = "ONE_CLASS_NEURAL_NETWORK"

import os
os.chdir(PROJECT_DIR)
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
# RANDOM_SEED = [42,11]
AUC = []

for seed in RANDOM_SEED:  
  Cfg.seed = seed
  ocnn = OneClass_SVDD(DATASET,LOSS_FUNCTION,IMG_DIM, HIDDEN_LAYER_SIZE, IMG_HGT, IMG_WDT,IMG_CHANNEL, MODEL_SAVE_PATH, REPORT_SAVE_PATH,PRETRAINED_WT_PATH,seed)
 
  print("[INFO:] Testing with ALL other  Image Classes  as anomalies")
  ocnn.fit()
  print("==============PREDICTING THE LABELS ==============================")
  auc_score = ocnn.predict()
  AUC.append(auc_score)

print("===========TRAINING AND PREDICTING WITH OCSVDD============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# Using TensorFlow backend.
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/utils/visualization/mosaic_plot.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-78044201dfde>", line 3, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')  # or 'PS', 'PDF', 'SVG'
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/data/GTSRB.py:9: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-78044201dfde>", line 3, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')  # or 'PS', 'PDF', 'SVG'
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 15.55272696615296
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.03122847681602081
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6115480000000001
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 18.382195895709884
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.035860419317390035
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6150683333333333
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 19.312751433656643
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.024837038050250726
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6194486666666668
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 16.864525427033612
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.02573098317250455
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6137855
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 18.858777311266863
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.027490319737360963
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6327699999999999
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 18.852832160438055
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.037899345190917366
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.5985966666666667
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 18.998044225658333
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.02907479185745926
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6309596666666666
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 20.67902813441657
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.033060546266681534
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6006426666666667
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 18.32793621293743
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.025578160058982724
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6416683333333333
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 17.85152138246923
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.029045725038912118
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6349393333333334
# ===================================
# ===========TRAINING AND PREDICTING WITH OCSVDD============================
# AUROC computed  [0.6115480000000001, 0.6150683333333333, 0.6194486666666668, 0.6137855, 0.6327699999999999, 0.5985966666666667, 0.6309596666666666, 0.6006426666666667, 0.6416683333333333, 0.6349393333333334]
# AUROC ===== 0.6199427166666667 +/- 0.01394039231833761
# ========================================================================

# %% [markdown]
# ##** Cat Vs All

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

from src.models.OneClass_SVDD import OneClass_SVDD
from src.models.config import Configuration as Cfg

DATASET = "cifar10"
IMG_DIM= 3072
IMG_HGT =32
IMG_WDT=32
IMG_CHANNEL=3
HIDDEN_LAYER_SIZE= 128
MODEL_SAVE_PATH = PROJECT_DIR + "/models/CIFAR10/OC_NN/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/CIFAR10/OC_NN/"
PRETRAINED_WT_PATH = ""
LOSS_FUNCTION = "SOFT_BOUND_DEEP_SVDD"
# LOSS_FUNCTION = "ONE_CLASS_DEEP_SVDD"
# LOSS_FUNCTION = "ONE_CLASS_NEURAL_NETWORK"

import os
os.chdir(PROJECT_DIR)
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
# RANDOM_SEED = [42,11]
AUC = []

for seed in RANDOM_SEED:  
  Cfg.seed = seed
  ocnn = OneClass_SVDD(DATASET,LOSS_FUNCTION,IMG_DIM, HIDDEN_LAYER_SIZE, IMG_HGT, IMG_WDT,IMG_CHANNEL, MODEL_SAVE_PATH, REPORT_SAVE_PATH,PRETRAINED_WT_PATH,seed)
 
  print("[INFO:] Testing with ALL other  Image Classes  as anomalies")
  ocnn.fit()
  print("==============PREDICTING THE LABELS ==============================")
  auc_score = ocnn.predict()
  AUC.append(auc_score)

print("===========TRAINING AND PREDICTING WITH OCSVDD============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 22.20100104150748
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.046592293070520985
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.5152715000000001
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 23.44061102581705
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.024188622143231253
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.5603193333333333
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 13.124214938368965
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.01857941079492964
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.618409
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 72.97722481434437
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.03473457248865941
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.5421003333333334
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 24.009628298484415
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.02044976886694433
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.64462
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 24.403623650015163
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.012099906828152651
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.5771753333333334
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 17.712906668820153
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.04802727997707068
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.520236
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 33.083330557463114
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.010290885170798625
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.5818336666666667
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 11.874603851391484
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.0229495480729138
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6447036666666666
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 20.56251766153821
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.02261857176713622
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.5522718333333334
# ===================================
# ===========TRAINING AND PREDICTING WITH OCSVDD============================
# AUROC computed  [0.5152715000000001, 0.5603193333333333, 0.618409, 0.5421003333333334, 0.64462, 0.5771753333333334, 0.520236, 0.5818336666666667, 0.6447036666666666, 0.5522718333333334]
# AUROC ===== 0.5756940666666666 +/- 0.0447409986773379
# ========================================================================

# %% [markdown]
# ##** Deer Vs All

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

from src.models.OneClass_SVDD import OneClass_SVDD
from src.models.config import Configuration as Cfg

DATASET = "cifar10"
IMG_DIM= 3072
IMG_HGT =32
IMG_WDT=32
IMG_CHANNEL=3
HIDDEN_LAYER_SIZE= 128
MODEL_SAVE_PATH = PROJECT_DIR + "/models/CIFAR10/OC_NN/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/CIFAR10/OC_NN/"
PRETRAINED_WT_PATH = ""
LOSS_FUNCTION = "SOFT_BOUND_DEEP_SVDD"
# LOSS_FUNCTION = "ONE_CLASS_DEEP_SVDD"
# LOSS_FUNCTION = "ONE_CLASS_NEURAL_NETWORK"

import os
os.chdir(PROJECT_DIR)
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
# RANDOM_SEED = [42,56]
AUC = []

for seed in RANDOM_SEED:  
  Cfg.seed = seed
  ocnn = OneClass_SVDD(DATASET,LOSS_FUNCTION,IMG_DIM, HIDDEN_LAYER_SIZE, IMG_HGT, IMG_WDT,IMG_CHANNEL, MODEL_SAVE_PATH, REPORT_SAVE_PATH,PRETRAINED_WT_PATH,seed)
 
  print("[INFO:] Testing with ALL other  Image Classes  as anomalies")
  ocnn.fit()
  print("==============PREDICTING THE LABELS ==============================")
  auc_score = ocnn.predict()
  AUC.append(auc_score)

print("===========TRAINING AND PREDICTING WITH OCSVDD============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/utils/visualization/mosaic_plot.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-78044201dfde>", line 3, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')  # or 'PS', 'PDF', 'SVG'
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/data/GTSRB.py:9: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-78044201dfde>", line 3, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')  # or 'PS', 'PDF', 'SVG'
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 19.100372777159492
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.034619541959621025
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.608214
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 16.768703487291987
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.029913064878150264
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6326341666666666
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 20.345547725404174
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.035065975080242506
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6430466666666667
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 16.50950508424299
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.02797451657651523
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6189656666666666
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 19.162170473882128
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.030667350081098776
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6152023333333334
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 18.945527016504315
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.03489247714491295
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6527094999999999
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 16.141679822163155
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.029766810181979853
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.666791
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 19.760056742997335
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.03073552106446681
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6227056666666666
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 17.080314660612544
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.02824292555898744
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6380983333333334
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 21.530218516351056
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.031905046924833036
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6384479999999999
# ===================================
# ===========TRAINING AND PREDICTING WITH OCSVDD============================
# AUROC computed  [0.608214, 0.6326341666666666, 0.6430466666666667, 0.6189656666666666, 0.6152023333333334, 0.6527094999999999, 0.666791, 0.6227056666666666, 0.6380983333333334, 0.6384479999999999]
# AUROC ===== 0.6336815333333334 +/- 0.01707756654792739
# ========================================================================

# %% [markdown]
# ##** Dog Vs All

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

from src.models.OneClass_SVDD import OneClass_SVDD
from src.models.config import Configuration as Cfg

DATASET = "cifar10"
IMG_DIM= 3072
IMG_HGT =32
IMG_WDT=32
IMG_CHANNEL=3
HIDDEN_LAYER_SIZE= 128
MODEL_SAVE_PATH = PROJECT_DIR + "/models/CIFAR10/OC_NN/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/CIFAR10/OC_NN/"
PRETRAINED_WT_PATH = ""
LOSS_FUNCTION = "SOFT_BOUND_DEEP_SVDD"
# LOSS_FUNCTION = "ONE_CLASS_DEEP_SVDD"
# LOSS_FUNCTION = "ONE_CLASS_NEURAL_NETWORK"

import os
os.chdir(PROJECT_DIR)
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
# RANDOM_SEED = [42,67]
AUC = []

for seed in RANDOM_SEED:  
  Cfg.seed = seed
  ocnn = OneClass_SVDD(DATASET,LOSS_FUNCTION,IMG_DIM, HIDDEN_LAYER_SIZE, IMG_HGT, IMG_WDT,IMG_CHANNEL, MODEL_SAVE_PATH, REPORT_SAVE_PATH,PRETRAINED_WT_PATH,seed)
 
  print("[INFO:] Testing with ALL other  Image Classes  as anomalies")
  ocnn.fit()
  print("==============PREDICTING THE LABELS ==============================")
  auc_score = ocnn.predict()
  AUC.append(auc_score)

print("===========TRAINING AND PREDICTING WITH OCSVDD============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 14.07953702925522
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.01448982285305711
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.5662083333333334
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 17.278762598497195
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.018436062068891174
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.581
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 41.81905823300656
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.017031628398594845
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6150829999999999
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 78.80725124107107
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.056933638632351846
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.5664966666666666
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 9.021062094736237
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.013964546860417343
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.5871356666666667
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 24.359711861485664
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.022413794065816478
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.5643308333333334
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 21.524997735563716
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.03379903215920005
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.590582
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 25.64325647836199
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.011495026461808722
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.5887028333333333
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 12.35953541982316
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.016518536213379176
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.5869989999999999
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 17.65573734805804
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.040689666599104446
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6121601666666666
# ===================================
# ===========TRAINING AND PREDICTING WITH OCSVDD============================
# AUROC computed  [0.5662083333333334, 0.581, 0.6150829999999999, 0.5664966666666666, 0.5871356666666667, 0.5643308333333334, 0.590582, 0.5887028333333333, 0.5869989999999999, 0.6121601666666666]
# AUROC ===== 0.5858698499999999 +/- 0.016814388050689365
# ========================================================================

# %% [markdown]
# ##** Frog Vs All

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

from src.models.OneClass_SVDD import OneClass_SVDD
from src.models.config import Configuration as Cfg

DATASET = "cifar10"
IMG_DIM= 3072
IMG_HGT =32
IMG_WDT=32
IMG_CHANNEL=3
HIDDEN_LAYER_SIZE= 128
MODEL_SAVE_PATH = PROJECT_DIR + "/models/CIFAR10/OC_NN/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/CIFAR10/OC_NN/"
PRETRAINED_WT_PATH = ""
LOSS_FUNCTION = "SOFT_BOUND_DEEP_SVDD"
# LOSS_FUNCTION = "ONE_CLASS_DEEP_SVDD"
# LOSS_FUNCTION = "ONE_CLASS_NEURAL_NETWORK"

import os
os.chdir(PROJECT_DIR)
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
# RANDOM_SEED = [42]
AUC = []

for seed in RANDOM_SEED:  
  Cfg.seed = seed
  ocnn = OneClass_SVDD(DATASET,LOSS_FUNCTION,IMG_DIM, HIDDEN_LAYER_SIZE, IMG_HGT, IMG_WDT,IMG_CHANNEL, MODEL_SAVE_PATH, REPORT_SAVE_PATH,PRETRAINED_WT_PATH,seed)
 
  print("[INFO:] Testing with ALL other  Image Classes  as anomalies")
  ocnn.fit()
  print("==============PREDICTING THE LABELS ==============================")
  auc_score = ocnn.predict()
  AUC.append(auc_score)

print("===========TRAINING AND PREDICTING WITH OCSVDD============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# Using TensorFlow backend.
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/utils/visualization/mosaic_plot.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-78044201dfde>", line 3, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')  # or 'PS', 'PDF', 'SVG'
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/data/GTSRB.py:9: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-78044201dfde>", line 3, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')  # or 'PS', 'PDF', 'SVG'
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 12.789181908872152
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.01593119130959958
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6019658333333333
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 49.38283884305838
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.03339360815148357
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.5855173333333334
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 18.518739715648536
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.02145683035920412
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.560172
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 13.174385094813431
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.025910518424371948
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.5409323333333333
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 23.519498148653213
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.028059809660615137
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.5504030000000001
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 55.934236226145345
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.022524255150021738
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.5516996666666666
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 10.766805677803603
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.02338372245676268
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6277276666666667
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 9.911527064750288
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.017514750386696254
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.523891
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 35.179267225721446
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.02166479084487044
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.629067
# ===================================
# OneClass_SVDD.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/CIFAR10/OC_NN/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# Data loaded.
# [INFO:] Testing with ALL other  Image Classes  as anomalies
# [INFO:] Obtained the initial representations of input using pretrained weights
# [INFO:] Initializing c and Radius R value...
# [INFO:] Radius (R)  initialized. 30.972815934941025
# [INFO:] Hypersphere Loss function.....
# [INFO:]
#  Model compiled and fit Initial Radius Value... 0.01753748957184606
# ==============PREDICTING THE LABELS ==============================
# [INFO: ] Shape of One Class Input Data used in testing (6500, 32, 32, 3)
# [INFO: ] Shape of (Positive) One Class Input Data used in testing (6000, 32, 32, 3)
# [INFO: ] Shape of (Negative) One Class Input Data used in testing (500, 32, 32, 3)
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] SOFT BOUNDARY SVDD Algorithm
# ===================================
# [INFO:]  AUROC Oneclass SVDD (Hypersphere).... 0.6393273333333334
# ===================================
# ===========TRAINING AND PREDICTING WITH OCSVDD============================
# AUROC computed  [0.6019658333333333, 0.5855173333333334, 0.560172, 0.5409323333333333, 0.5504030000000001, 0.5516996666666666, 0.6277276666666667, 0.523891, 0.629067, 0.6393273333333334]
# AUROC ===== 0.5810703166666666 +/- 0.039308090106126875
# ========================================================================
