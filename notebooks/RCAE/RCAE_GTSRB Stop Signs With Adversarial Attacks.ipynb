# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install picklable_itertools

# !pip install fuel
# !pip install foolbox
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: picklable_itertools in /usr/local/lib/python3.6/dist-packages (0.1.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from picklable_itertools) (1.11.0)
# Requirement already satisfied: fuel in /usr/local/lib/python3.6/dist-packages (0.2.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from fuel) (3.13)
# Requirement already satisfied: tables in /usr/local/lib/python3.6/dist-packages (from fuel) (3.4.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from fuel) (2.18.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from fuel) (1.1.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from fuel) (4.0.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from fuel) (1.11.0)
# Requirement already satisfied: picklable-itertools in /usr/local/lib/python3.6/dist-packages (from fuel) (0.1.1)
# Requirement already satisfied: progressbar2 in /usr/local/lib/python3.6/dist-packages (from fuel) (3.38.0)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.6/dist-packages (from fuel) (17.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from fuel) (1.14.6)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from fuel) (2.8.0)
# Requirement already satisfied: numexpr>=2.5.2 in /usr/local/lib/python3.6/dist-packages (from tables->fuel) (2.6.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->fuel) (2018.10.15)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->fuel) (1.22)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->fuel) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->fuel) (3.0.4)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from pillow->fuel) (0.46)
# Requirement already satisfied: python-utils>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from progressbar2->fuel) (2.3.0)
# Requirement already satisfied: foolbox in /usr/local/lib/python3.6/dist-packages (1.7.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from foolbox) (40.6.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from foolbox) (1.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from foolbox) (1.14.6)

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
import numpy as np
PROJECT_DIR = "/content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/"
import sys,os
import numpy as np
sys.path.append(PROJECT_DIR)

# %% [markdown]
# ##** GTSRB Experiments **##

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2
from src.models.RCAE import RCAE_AD
import numpy as np 
from src.config import Configuration as Cfg

DATASET = "gtsrb"
IMG_DIM= 3072
IMG_HGT =32
IMG_WDT=32
IMG_CHANNEL=3
HIDDEN_LAYER_SIZE= 32
MODEL_SAVE_PATH = PROJECT_DIR + "/models/gtsrb/DCAE/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/gtsrb/DCAE/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
# RANDOM_SEED = [42]
AUC = []

for seed in RANDOM_SEED:  
  Cfg.seed = seed
  rcae = RCAE_AD(DATASET,IMG_DIM, HIDDEN_LAYER_SIZE, IMG_HGT, IMG_WDT,IMG_CHANNEL, MODEL_SAVE_PATH, REPORT_SAVE_PATH,PRETRAINED_WT_PATH,seed)
  print("Train Data Shape: ",rcae.data._X_train.shape)
  print("Train Label Shape: ",rcae.data._y_train.shape)
  print("Validation Data Shape: ",rcae.data._X_val.shape)
  print("Validation Label Shape: ",rcae.data._y_val.shape)
  print("Test Data Shape: ",rcae.data._X_test.shape)
  print("Test Label Shape: ",rcae.data._y_test.shape)
  print("===========TRAINING AND PREDICTING WITH DCAE============================")
  auc_roc = rcae.fit_and_predict()
  print("========================================================================")
  AUC.append(auc_roc)
  
print("===========TRAINING AND PREDICTING WITH DCAE============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# Using TensorFlow backend.
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/utils/visualization/mosaic_plot.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-49aa195c7a4f>", line 3, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')  # or 'PS', 'PDF', 'SVG'
# RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/gtsrb/DCAE/
# INFO: The dataset is  gtsrb
# [INFO:] Loading data...
# The random seed used in the experiment is  42
# [INFO:] Loading adversarial data...
# [INFO:] Negative Y_test labels 100
# [INFO:] Positive Y_test labels 270
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The random seed used in the experiment is  42
# [INFO:] Loading adversarial data...
# [INFO:] Negative Y_test labels 100
# [INFO:] Positive Y_test labels 270
# Data loaded.
# Train Data Shape:  (780, 3, 32, 32)
# Train Label Shape:  (780,)
# Validation Data Shape:  (0, 3, 32, 32)
# Validation Label Shape:  (0,)
# Test Data Shape:  (370, 3, 32, 32)
# Test Label Shape:  (370,)
# ===========TRAINING AND PREDICTING WITH DCAE============================
# [INFO:] X_train.shape (1150, 32, 32, 3)
# [INFO:] y_train.shape (1150,)
# [INFO:] X_test.shape (1150, 32, 32, 3)
# [INFO:] y_test.shape (1150,)
# [INFO] compiling model...
# [INFO:] Shape of U, V (256, 32) (256, 32)
# (lamda,Threshold) 0.5 0.25
# The type of b is ..., its len is  <class 'numpy.ndarray'> (1150, 3072) 3072
# Iteration NUmber is :  0
# NUmber of non zero elements  for N,lamda 49759 0.5
# The shape of N (1150, 3072)
# The minimum value of N  -0.6066407561302185
# The max value of N 0.5947943329811096
# [INFO:] The shape of input data   (1150, 32, 32, 3)
# [INFO:] The shape of decoded  data   (1150, 32, 32, 3)
# [INFO:] The shape of N  data   (1150, 32, 32, 3)
# img shape: (128, 320, 3)
#
# Saving results for best after being encoded and decoded: @
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/gtsrb/RCAE//best/
#
# Saving results for worst after being encoded and decoded: @
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/gtsrb/RCAE//worst/
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# =====================
# AUROC 0.5 0.8446666666666667
# =======================
# ========================================================================
# RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/gtsrb/DCAE/
# INFO: The dataset is  gtsrb
# [INFO:] Loading data...
# The random seed used in the experiment is  56
# [INFO:] Loading adversarial data...
# [INFO:] Negative Y_test labels 100
# [INFO:] Positive Y_test labels 270
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The random seed used in the experiment is  56
# [INFO:] Loading adversarial data...
# [INFO:] Negative Y_test labels 100
# [INFO:] Positive Y_test labels 270
# Data loaded.
# Train Data Shape:  (780, 3, 32, 32)
# Train Label Shape:  (780,)
# Validation Data Shape:  (0, 3, 32, 32)
# Validation Label Shape:  (0,)
# Test Data Shape:  (370, 3, 32, 32)
# Test Label Shape:  (370,)
# ===========TRAINING AND PREDICTING WITH DCAE============================
# [INFO:] X_train.shape (1150, 32, 32, 3)
# [INFO:] y_train.shape (1150,)
# [INFO:] X_test.shape (1150, 32, 32, 3)
# [INFO:] y_test.shape (1150,)
# [INFO] compiling model...
# [INFO:] Shape of U, V (256, 32) (256, 32)
# (lamda,Threshold) 0.5 0.25
# The type of b is ..., its len is  <class 'numpy.ndarray'> (1150, 3072) 3072
# Iteration NUmber is :  0
# NUmber of non zero elements  for N,lamda 59046 0.5
# The shape of N (1150, 3072)
# The minimum value of N  -0.693174421787262
# The max value of N 0.6643397212028503
# [INFO:] The shape of input data   (1150, 32, 32, 3)
# [INFO:] The shape of decoded  data   (1150, 32, 32, 3)
# [INFO:] The shape of N  data   (1150, 32, 32, 3)
# img shape: (128, 320, 3)
#
# Saving results for best after being encoded and decoded: @
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/gtsrb/RCAE//best/
#
# Saving results for worst after being encoded and decoded: @
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/gtsrb/RCAE//worst/
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# =====================
# AUROC 0.5 0.8863714285714286
# =======================
# ========================================================================
# RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/gtsrb/DCAE/
# INFO: The dataset is  gtsrb
# [INFO:] Loading data...
# The random seed used in the experiment is  81
# [INFO:] Loading adversarial data...
# [INFO:] Negative Y_test labels 100
# [INFO:] Positive Y_test labels 270
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The random seed used in the experiment is  81
# [INFO:] Loading adversarial data...
# [INFO:] Negative Y_test labels 100
# [INFO:] Positive Y_test labels 270
# Data loaded.
# Train Data Shape:  (780, 3, 32, 32)
# Train Label Shape:  (780,)
# Validation Data Shape:  (0, 3, 32, 32)
# Validation Label Shape:  (0,)
# Test Data Shape:  (370, 3, 32, 32)
# Test Label Shape:  (370,)
# ===========TRAINING AND PREDICTING WITH DCAE============================
# [INFO:] X_train.shape (1150, 32, 32, 3)
# [INFO:] y_train.shape (1150,)
# [INFO:] X_test.shape (1150, 32, 32, 3)
# [INFO:] y_test.shape (1150,)
# [INFO] compiling model...
# [INFO:] Shape of U, V (256, 32) (256, 32)
# (lamda,Threshold) 0.5 0.25
# The type of b is ..., its len is  <class 'numpy.ndarray'> (1150, 3072) 3072
# Iteration NUmber is :  0
# NUmber of non zero elements  for N,lamda 67449 0.5
# The shape of N (1150, 3072)
# The minimum value of N  -0.6024645566940308
# The max value of N 0.6325744986534119
# [INFO:] The shape of input data   (1150, 32, 32, 3)
# [INFO:] The shape of decoded  data   (1150, 32, 32, 3)
# [INFO:] The shape of N  data   (1150, 32, 32, 3)
# img shape: (128, 320, 3)
#
# Saving results for best after being encoded and decoded: @
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/gtsrb/RCAE//best/
#
# Saving results for worst after being encoded and decoded: @
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/gtsrb/RCAE//worst/
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# =====================
# AUROC 0.5 0.8938952380952381
# =======================
# ========================================================================
# RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/gtsrb/DCAE/
# INFO: The dataset is  gtsrb
# [INFO:] Loading data...
# The random seed used in the experiment is  67
# [INFO:] Loading adversarial data...
# [INFO:] Negative Y_test labels 100
# [INFO:] Positive Y_test labels 270
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The random seed used in the experiment is  67
# [INFO:] Loading adversarial data...
# [INFO:] Negative Y_test labels 100
# [INFO:] Positive Y_test labels 270
# Data loaded.
# Train Data Shape:  (780, 3, 32, 32)
# Train Label Shape:  (780,)
# Validation Data Shape:  (0, 3, 32, 32)
# Validation Label Shape:  (0,)
# Test Data Shape:  (370, 3, 32, 32)
# Test Label Shape:  (370,)
# ===========TRAINING AND PREDICTING WITH DCAE============================
# [INFO:] X_train.shape (1150, 32, 32, 3)
# [INFO:] y_train.shape (1150,)
# [INFO:] X_test.shape (1150, 32, 32, 3)
# [INFO:] y_test.shape (1150,)
# [INFO] compiling model...
# [INFO:] Shape of U, V (256, 32) (256, 32)
# (lamda,Threshold) 0.5 0.25
# The type of b is ..., its len is  <class 'numpy.ndarray'> (1150, 3072) 3072
# Iteration NUmber is :  0
# NUmber of non zero elements  for N,lamda 54779 0.5
# The shape of N (1150, 3072)
# The minimum value of N  -0.6386791467666626
# The max value of N 0.5893135070800781
# [INFO:] The shape of input data   (1150, 32, 32, 3)
# [INFO:] The shape of decoded  data   (1150, 32, 32, 3)
# [INFO:] The shape of N  data   (1150, 32, 32, 3)
# img shape: (128, 320, 3)
#
# Saving results for best after being encoded and decoded: @
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/gtsrb/RCAE//best/
#
# Saving results for worst after being encoded and decoded: @
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/gtsrb/RCAE//worst/
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# =====================
# AUROC 0.5 0.9041523809523808
# =======================
# ========================================================================
# RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/gtsrb/DCAE/
# INFO: The dataset is  gtsrb
# [INFO:] Loading data...
# The random seed used in the experiment is  33
# [INFO:] Loading adversarial data...
# [INFO:] Negative Y_test labels 100
# [INFO:] Positive Y_test labels 270
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The random seed used in the experiment is  33
# [INFO:] Loading adversarial data...
# [INFO:] Negative Y_test labels 100
# [INFO:] Positive Y_test labels 270
# Data loaded.
# Train Data Shape:  (780, 3, 32, 32)
# Train Label Shape:  (780,)
# Validation Data Shape:  (0, 3, 32, 32)
# Validation Label Shape:  (0,)
# Test Data Shape:  (370, 3, 32, 32)
# Test Label Shape:  (370,)
# ===========TRAINING AND PREDICTING WITH DCAE============================
# [INFO:] X_train.shape (1150, 32, 32, 3)
# [INFO:] y_train.shape (1150,)
# [INFO:] X_test.shape (1150, 32, 32, 3)
# [INFO:] y_test.shape (1150,)
# [INFO] compiling model...
# [INFO:] Shape of U, V (256, 32) (256, 32)
# (lamda,Threshold) 0.5 0.25
# The type of b is ..., its len is  <class 'numpy.ndarray'> (1150, 3072) 3072
# Iteration NUmber is :  0
# NUmber of non zero elements  for N,lamda 51060 0.5
# The shape of N (1150, 3072)
# The minimum value of N  -0.6652103662490845
# The max value of N 0.6527183055877686
# [INFO:] The shape of input data   (1150, 32, 32, 3)
# [INFO:] The shape of decoded  data   (1150, 32, 32, 3)
# [INFO:] The shape of N  data   (1150, 32, 32, 3)
# img shape: (128, 320, 3)
#
# Saving results for best after being encoded and decoded: @
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/gtsrb/RCAE//best/
#
# Saving results for worst after being encoded and decoded: @
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/gtsrb/RCAE//worst/
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# =====================
# AUROC 0.5 0.8827142857142858
# =======================
# ========================================================================
# RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/gtsrb/DCAE/
# INFO: The dataset is  gtsrb
# [INFO:] Loading data...
# The random seed used in the experiment is  25
# [INFO:] Loading adversarial data...
# [INFO:] Negative Y_test labels 100
# [INFO:] Positive Y_test labels 270
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The random seed used in the experiment is  25
# [INFO:] Loading adversarial data...
# [INFO:] Negative Y_test labels 100
# [INFO:] Positive Y_test labels 270
# Data loaded.
# Train Data Shape:  (780, 3, 32, 32)
# Train Label Shape:  (780,)
# Validation Data Shape:  (0, 3, 32, 32)
# Validation Label Shape:  (0,)
# Test Data Shape:  (370, 3, 32, 32)
# Test Label Shape:  (370,)
# ===========TRAINING AND PREDICTING WITH DCAE============================
# [INFO:] X_train.shape (1150, 32, 32, 3)
# [INFO:] y_train.shape (1150,)
# [INFO:] X_test.shape (1150, 32, 32, 3)
# [INFO:] y_test.shape (1150,)
# [INFO] compiling model...
# [INFO:] Shape of U, V (256, 32) (256, 32)
# (lamda,Threshold) 0.5 0.25
# The type of b is ..., its len is  <class 'numpy.ndarray'> (1150, 3072) 3072
# Iteration NUmber is :  0
# NUmber of non zero elements  for N,lamda 52518 0.5
# The shape of N (1150, 3072)
# The minimum value of N  -0.662563681602478
# The max value of N 0.606228768825531
# [INFO:] The shape of input data   (1150, 32, 32, 3)
# [INFO:] The shape of decoded  data   (1150, 32, 32, 3)
# [INFO:] The shape of N  data   (1150, 32, 32, 3)
# img shape: (128, 320, 3)
#
# Saving results for best after being encoded and decoded: @
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/gtsrb/RCAE//best/
#
# Saving results for worst after being encoded and decoded: @
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/gtsrb/RCAE//worst/
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# =====================
# AUROC 0.5 0.8134095238095238
# =======================
# ========================================================================
# RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/gtsrb/DCAE/
# INFO: The dataset is  gtsrb
# [INFO:] Loading data...
# The random seed used in the experiment is  90
# [INFO:] Loading adversarial data...
# [INFO:] Negative Y_test labels 100
# [INFO:] Positive Y_test labels 270
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The random seed used in the experiment is  90
# [INFO:] Loading adversarial data...
# [INFO:] Negative Y_test labels 100
# [INFO:] Positive Y_test labels 270
# Data loaded.
# Train Data Shape:  (780, 3, 32, 32)
# Train Label Shape:  (780,)
# Validation Data Shape:  (0, 3, 32, 32)
# Validation Label Shape:  (0,)
# Test Data Shape:  (370, 3, 32, 32)
# Test Label Shape:  (370,)
# ===========TRAINING AND PREDICTING WITH DCAE============================
# [INFO:] X_train.shape (1150, 32, 32, 3)
# [INFO:] y_train.shape (1150,)
# [INFO:] X_test.shape (1150, 32, 32, 3)
# [INFO:] y_test.shape (1150,)
# [INFO] compiling model...
# [INFO:] Shape of U, V (256, 32) (256, 32)
# (lamda,Threshold) 0.5 0.25
# The type of b is ..., its len is  <class 'numpy.ndarray'> (1150, 3072) 3072
# Iteration NUmber is :  0
# NUmber of non zero elements  for N,lamda 63462 0.5
# The shape of N (1150, 3072)
# The minimum value of N  -0.6470732688903809
# The max value of N 0.6858018040657043
# [INFO:] The shape of input data   (1150, 32, 32, 3)
# [INFO:] The shape of decoded  data   (1150, 32, 32, 3)
# [INFO:] The shape of N  data   (1150, 32, 32, 3)
# img shape: (128, 320, 3)
#
# Saving results for best after being encoded and decoded: @
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/gtsrb/RCAE//best/
#
# Saving results for worst after being encoded and decoded: @
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/gtsrb/RCAE//worst/
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# =====================
# AUROC 0.5 0.8972
# =======================
# ========================================================================
# RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/gtsrb/DCAE/
# INFO: The dataset is  gtsrb
# [INFO:] Loading data...
# The random seed used in the experiment is  77
# [INFO:] Loading adversarial data...
# [INFO:] Negative Y_test labels 100
# [INFO:] Positive Y_test labels 270
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The random seed used in the experiment is  77
# [INFO:] Loading adversarial data...
# [INFO:] Negative Y_test labels 100
# [INFO:] Positive Y_test labels 270
# Data loaded.
# Train Data Shape:  (780, 3, 32, 32)
# Train Label Shape:  (780,)
# Validation Data Shape:  (0, 3, 32, 32)
# Validation Label Shape:  (0,)
# Test Data Shape:  (370, 3, 32, 32)
# Test Label Shape:  (370,)
# ===========TRAINING AND PREDICTING WITH DCAE============================
# [INFO:] X_train.shape (1150, 32, 32, 3)
# [INFO:] y_train.shape (1150,)
# [INFO:] X_test.shape (1150, 32, 32, 3)
# [INFO:] y_test.shape (1150,)
# [INFO] compiling model...
# [INFO:] Shape of U, V (256, 32) (256, 32)
# (lamda,Threshold) 0.5 0.25
# The type of b is ..., its len is  <class 'numpy.ndarray'> (1150, 3072) 3072
# Iteration NUmber is :  0
# NUmber of non zero elements  for N,lamda 101168 0.5
# The shape of N (1150, 3072)
# The minimum value of N  -0.6540188789367676
# The max value of N 0.6577067971229553
# [INFO:] The shape of input data   (1150, 32, 32, 3)
# [INFO:] The shape of decoded  data   (1150, 32, 32, 3)
# [INFO:] The shape of N  data   (1150, 32, 32, 3)
# img shape: (128, 320, 3)
#
# Saving results for best after being encoded and decoded: @
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/gtsrb/RCAE//best/
#
# Saving results for worst after being encoded and decoded: @
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/gtsrb/RCAE//worst/
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# =====================
# AUROC 0.5 0.8897428571428572
# =======================
# ========================================================================
# RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/gtsrb/DCAE/
# INFO: The dataset is  gtsrb
# [INFO:] Loading data...
# The random seed used in the experiment is  15
# [INFO:] Loading adversarial data...
# [INFO:] Negative Y_test labels 100
# [INFO:] Positive Y_test labels 270
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The random seed used in the experiment is  15
# [INFO:] Loading adversarial data...
# [INFO:] Negative Y_test labels 100
# [INFO:] Positive Y_test labels 270
# Data loaded.
# Train Data Shape:  (780, 3, 32, 32)
# Train Label Shape:  (780,)
# Validation Data Shape:  (0, 3, 32, 32)
# Validation Label Shape:  (0,)
# Test Data Shape:  (370, 3, 32, 32)
# Test Label Shape:  (370,)
# ===========TRAINING AND PREDICTING WITH DCAE============================
# [INFO:] X_train.shape (1150, 32, 32, 3)
# [INFO:] y_train.shape (1150,)
# [INFO:] X_test.shape (1150, 32, 32, 3)
# [INFO:] y_test.shape (1150,)
# [INFO] compiling model...
# [INFO:] Shape of U, V (256, 32) (256, 32)
# (lamda,Threshold) 0.5 0.25
# The type of b is ..., its len is  <class 'numpy.ndarray'> (1150, 3072) 3072
# Iteration NUmber is :  0
# NUmber of non zero elements  for N,lamda 114424 0.5
# The shape of N (1150, 3072)
# The minimum value of N  -0.7130616903305054
# The max value of N 0.7188460230827332
# [INFO:] The shape of input data   (1150, 32, 32, 3)
# [INFO:] The shape of decoded  data   (1150, 32, 32, 3)
# [INFO:] The shape of N  data   (1150, 32, 32, 3)
# img shape: (128, 320, 3)
#
# Saving results for best after being encoded and decoded: @
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/gtsrb/RCAE//best/
#
# Saving results for worst after being encoded and decoded: @
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/gtsrb/RCAE//worst/
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# =====================
# AUROC 0.5 0.845152380952381
# =======================
# ========================================================================
# RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/gtsrb/DCAE/
# INFO: The dataset is  gtsrb
# [INFO:] Loading data...
# The random seed used in the experiment is  11
# [INFO:] Loading adversarial data...
# [INFO:] Negative Y_test labels 100
# [INFO:] Positive Y_test labels 270
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The random seed used in the experiment is  11
# [INFO:] Loading adversarial data...
# [INFO:] Negative Y_test labels 100
# [INFO:] Positive Y_test labels 270
# Data loaded.
# Train Data Shape:  (780, 3, 32, 32)
# Train Label Shape:  (780,)
# Validation Data Shape:  (0, 3, 32, 32)
# Validation Label Shape:  (0,)
# Test Data Shape:  (370, 3, 32, 32)
# Test Label Shape:  (370,)
# ===========TRAINING AND PREDICTING WITH DCAE============================
# [INFO:] X_train.shape (1150, 32, 32, 3)
# [INFO:] y_train.shape (1150,)
# [INFO:] X_test.shape (1150, 32, 32, 3)
# [INFO:] y_test.shape (1150,)
# [INFO] compiling model...
# [INFO:] Shape of U, V (256, 32) (256, 32)
# (lamda,Threshold) 0.5 0.25
# The type of b is ..., its len is  <class 'numpy.ndarray'> (1150, 3072) 3072
# Iteration NUmber is :  0
# NUmber of non zero elements  for N,lamda 60624 0.5
# The shape of N (1150, 3072)
# The minimum value of N  -0.5966957807540894
# The max value of N 0.6182328462600708
# [INFO:] The shape of input data   (1150, 32, 32, 3)
# [INFO:] The shape of decoded  data   (1150, 32, 32, 3)
# [INFO:] The shape of N  data   (1150, 32, 32, 3)
# img shape: (128, 320, 3)
#
# Saving results for best after being encoded and decoded: @
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/gtsrb/RCAE//best/
#
# Saving results for worst after being encoded and decoded: @
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/gtsrb/RCAE//worst/
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# =====================
# AUROC 0.5 0.8818571428571429
# =======================
# ========================================================================
# ===========TRAINING AND PREDICTING WITH DCAE============================
# AUROC computed  [0.8446666666666667, 0.8863714285714286, 0.8938952380952381, 0.9041523809523808, 0.8827142857142858, 0.8134095238095238, 0.8972, 0.8897428571428572, 0.845152380952381, 0.8818571428571429]
# AUROC ===== 0.8739161904761905 +/- 0.027830837168609717
# ========================================================================

# %% [markdown]
# ##** End of GTSRB experiments **##

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2
from src.models.RCAE import RCAE_AD
import numpy as np 
from src.config import Configuration as Cfg

DATASET = "gtsrb"
IMG_DIM= 3072
IMG_HGT =32
IMG_WDT=32
IMG_CHANNEL=3
HIDDEN_LAYER_SIZE= 32
MODEL_SAVE_PATH = PROJECT_DIR + "/models/gtsrb/DCAE/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/gtsrb/DCAE/"

PRETRAINED_WT_PATH = ""
# RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
RANDOM_SEED = [42]
AUC = []

for seed in RANDOM_SEED:  
  Cfg.seed = seed
  rcae = RCAE_AD(DATASET,IMG_DIM, HIDDEN_LAYER_SIZE, IMG_HGT, IMG_WDT,IMG_CHANNEL, MODEL_SAVE_PATH, REPORT_SAVE_PATH,PRETRAINED_WT_PATH,seed)
  print("Train Data Shape: ",rcae.data._X_train.shape)
  print("Train Label Shape: ",rcae.data._y_train.shape)
  print("Validation Data Shape: ",rcae.data._X_val.shape)
  print("Validation Label Shape: ",rcae.data._y_val.shape)
  print("Test Data Shape: ",rcae.data._X_test.shape)
  print("Test Label Shape: ",rcae.data._y_test.shape)
  print("===========TRAINING AND PREDICTING WITH DCAE============================")
  auc_roc = rcae.fit_and_predict()
  print("========================================================================")
  AUC.append(auc_roc)
  
print("===========TRAINING AND PREDICTING WITH DCAE============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# Using TensorFlow backend.
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/utils/visualization/mosaic_plot.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-49aa195c7a4f>", line 3, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')  # or 'PS', 'PDF', 'SVG'
# RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/gtsrb/DCAE/
# INFO: The dataset is  gtsrb
# [INFO:] Loading data...
# The random seed used in the experiment is  42
# [INFO:] Loading adversarial data...
# [INFO:] Negative Y_test labels 100
# [INFO:] Positive Y_test labels 270
# Data loaded.
# [INFO:] Assertions of memory muted
# [INFO:] Loading data...
# The random seed used in the experiment is  42
# [INFO:] Loading adversarial data...
# [INFO:] Negative Y_test labels 100
# [INFO:] Positive Y_test labels 270
# Data loaded.
# Train Data Shape:  (1150, 3, 32, 32)
# Train Label Shape:  (1150,)
# Validation Data Shape:  (0, 3, 32, 32)
# Validation Label Shape:  (0,)
# Test Data Shape:  (370, 3, 32, 32)
# Test Label Shape:  (370,)
# ===========TRAINING AND PREDICTING WITH DCAE============================
# [INFO:] X_train.shape (1520, 32, 32, 3)
# [INFO:] y_train.shape (1520,)
# [INFO:] X_test.shape (1520, 32, 32, 3)
# [INFO:] y_test.shape (1520,)
# [INFO] compiling model...
# [INFO:] Shape of U, V (256, 32) (256, 32)
# (lamda,Threshold) 0.5 0.25
# The type of b is ..., its len is  <class 'numpy.ndarray'> (1520, 3072) 3072
# Iteration NUmber is :  0
# NUmber of non zero elements  for N,lamda 54452 0.5
# The shape of N (1520, 3072)
# The minimum value of N  -0.6731674671173096
# The max value of N 0.6196399927139282
# [INFO:] The shape of input data   (1520, 32, 32, 3)
# [INFO:] The shape of decoded  data   (1520, 32, 32, 3)
# [INFO:] The shape of N  data   (1520, 32, 32, 3)
# img shape: (128, 320, 3)
#
# Saving results for best after being encoded and decoded: @
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/gtsrb/RCAE//best/
#
# Saving results for worst after being encoded and decoded: @
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/gtsrb/RCAE//worst/
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_anomalousmost anomalous digit: @
# [INFO:] The  top_100_anomalies (100, 32, 32, 3)
# img shape: (320, 320, 3)
# Saving Top-200most_normalmost anomalous digit: @
# =====================
# AUROC 0.5 0.8326212121212121
# =======================
# ========================================================================
# ===========TRAINING AND PREDICTING WITH DCAE============================
# AUROC computed  [0.8326212121212121]
# AUROC ===== 0.8326212121212121 +/- 0.0
# ========================================================================
