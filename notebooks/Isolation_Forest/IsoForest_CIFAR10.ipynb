# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install picklable_itertools

# !pip install fuel
# !pip install foolbox

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
import numpy as np
PROJECT_DIR = "/content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/"
import sys,os
import numpy as np
sys.path.append(PROJECT_DIR)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: picklable_itertools in /usr/local/lib/python3.6/dist-packages (0.1.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from picklable_itertools) (1.11.0)
# Requirement already satisfied: fuel in /usr/local/lib/python3.6/dist-packages (0.2.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from fuel) (2.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from fuel) (2.18.4)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.6/dist-packages (from fuel) (17.0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from fuel) (1.1.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from fuel) (3.13)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from fuel) (4.0.0)
# Requirement already satisfied: tables in /usr/local/lib/python3.6/dist-packages (from fuel) (3.4.4)
# Requirement already satisfied: progressbar2 in /usr/local/lib/python3.6/dist-packages (from fuel) (3.38.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from fuel) (1.11.0)
# Requirement already satisfied: picklable-itertools in /usr/local/lib/python3.6/dist-packages (from fuel) (0.1.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from fuel) (1.14.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->fuel) (2018.10.15)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->fuel) (1.22)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->fuel) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->fuel) (2.6)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from pillow->fuel) (0.46)
# Requirement already satisfied: numexpr>=2.5.2 in /usr/local/lib/python3.6/dist-packages (from tables->fuel) (2.6.8)
# Requirement already satisfied: python-utils>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from progressbar2->fuel) (2.3.0)
# Requirement already satisfied: foolbox in /usr/local/lib/python3.6/dist-packages (1.8.0)
# Requirement already satisfied: GitPython in /usr/local/lib/python3.6/dist-packages (from foolbox) (2.1.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from foolbox) (2.18.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from foolbox) (1.14.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from foolbox) (40.6.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from foolbox) (1.1.0)
# Requirement already satisfied: gitdb2>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from GitPython->foolbox) (2.0.5)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->foolbox) (1.22)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->foolbox) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->foolbox) (2018.10.15)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->foolbox) (2.6)
# Requirement already satisfied: smmap2>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from gitdb2>=2.0.0->GitPython->foolbox) (2.0.5)

# %% [markdown]
# ##** Aeroplane Vs All **##

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2
from src.models.isoForest import IsoForest
import numpy as np 
from src.config import Configuration as Cfg
from src.config import Configuration as Cfg
from src.models.isoForest import IsoForest
# from src.utils.log import log_exp_config, log_isoForest, log_AD_results
# from src.utils.visualization.images_plot import plot_outliers_and_most_normal



DATASET = "cifar10"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/cifar10/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/cifar10/ISO_FOREST/"
PRETRAINED_WT_PATH = ""

RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.cifar10_val_frac = 0.1
Cfg.cifar10_normal = 0
Cfg.cifar10_outlier = -1



for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    # initialize Isolation Forest
    model = IsoForest(dataset=DATASET, n_estimators=ESTIMATORS, max_samples=MAX_SAMPLES,
                      contamination=CONTAMINATION)
    # train IF model
    model.fit()
    print("===========PREDICTING WITH ISO_FOREST============================")
    # predict
    # model.predict(which_set='train')
    auc_roc = model.predict(which_set='test')
    print("========================================================================")
    print("AUROC",auc_roc)
    print("========================================================================")
    AUC.append(auc_roc)
  
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# Using TensorFlow backend.
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/utils/visualization/mosaic_plot.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-6569f4f7c1be>", line 10, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')  # or 'PS', 'PDF', 'SVG'
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 46.031
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.6389
# ========================================================================
# AUROC 0.6371993333333333
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 46.4309
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.22553
# ========================================================================
# AUROC 0.6204176666666666
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 46.1892
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.54491
# ========================================================================
# AUROC 0.6285666666666666
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 45.9077
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.74332
# ========================================================================
# AUROC 0.6625536666666666
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 46.2208
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.6874
# ========================================================================
# AUROC 0.630567
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 45.8544
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.97982
# ========================================================================
# AUROC 0.6489879999999999
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 46.1041
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.72845
# ========================================================================
# AUROC 0.6457943333333334
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 46.9923
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.76537
# ========================================================================
# AUROC 0.6444056666666667
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 45.9974
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.93607
# ========================================================================
# AUROC 0.6465639999999999
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 0
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 45.753
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.14107
# ========================================================================
# AUROC 0.6347316666666667
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.6371993333333333, 0.6204176666666666, 0.6285666666666666, 0.6625536666666666, 0.630567, 0.6489879999999999, 0.6457943333333334, 0.6444056666666667, 0.6465639999999999, 0.6347316666666667]
# AUROC ===== 0.6399788 +/- 0.011507768124377727
# ========================================================================

# %% [markdown]
# ##** Automobile Vs All **##

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2
from src.models.isoForest import IsoForest
import numpy as np 
from src.config import Configuration as Cfg
from src.config import Configuration as Cfg
from src.models.isoForest import IsoForest
# from src.utils.log import log_exp_config, log_isoForest, log_AD_results
# from src.utils.visualization.images_plot import plot_outliers_and_most_normal



DATASET = "cifar10"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/cifar10/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/cifar10/ISO_FOREST/"
PRETRAINED_WT_PATH = ""

RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.cifar10_val_frac = 0.1
Cfg.cifar10_normal = 1
Cfg.cifar10_outlier = -1



for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    # initialize Isolation Forest
    model = IsoForest(dataset=DATASET, n_estimators=ESTIMATORS, max_samples=MAX_SAMPLES,
                      contamination=CONTAMINATION)
    # train IF model
    model.fit()
    print("===========PREDICTING WITH ISO_FOREST============================")
    # predict
    # model.predict(which_set='train')
    auc_roc = model.predict(which_set='test')
    print("========================================================================")
    print("AUROC",auc_roc)
    print("========================================================================")
    AUC.append(auc_roc)
  
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 46.0025
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.66444
# ========================================================================
# AUROC 0.6300456666666667
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 46.7592
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.38047
# ========================================================================
# AUROC 0.5874016666666667
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 46.4417
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.36603
# ========================================================================
# AUROC 0.6210993333333333
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 46.2145
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.83242
# ========================================================================
# AUROC 0.6282153333333333
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 46.1664
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.66773
# ========================================================================
# AUROC 0.622736
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 46.1926
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.94922
# ========================================================================
# AUROC 0.6302443333333334
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 46.0601
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.73411
# ========================================================================
# AUROC 0.5856870000000001
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 46.6674
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.06781
# ========================================================================
# AUROC 0.5846323333333333
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.3538
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.47467
# ========================================================================
# AUROC 0.5824513333333333
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 1
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 46.5969
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.08124
# ========================================================================
# AUROC 0.5843843333333334
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.6300456666666667, 0.5874016666666667, 0.6210993333333333, 0.6282153333333333, 0.622736, 0.6302443333333334, 0.5856870000000001, 0.5846323333333333, 0.5824513333333333, 0.5843843333333334]
# AUROC ===== 0.6056897333333333 +/- 0.020984502915670358
# ========================================================================

# %% [markdown]
# ##** Bird Vs All **##

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2
from src.models.isoForest import IsoForest
import numpy as np 
from src.config import Configuration as Cfg
from src.config import Configuration as Cfg
from src.models.isoForest import IsoForest
# from src.utils.log import log_exp_config, log_isoForest, log_AD_results
# from src.utils.visualization.images_plot import plot_outliers_and_most_normal



DATASET = "cifar10"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/cifar10/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/cifar10/ISO_FOREST/"
PRETRAINED_WT_PATH = ""

RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.cifar10_val_frac = 0.1
Cfg.cifar10_normal = 2
Cfg.cifar10_outlier = -1



for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    # initialize Isolation Forest
    model = IsoForest(dataset=DATASET, n_estimators=ESTIMATORS, max_samples=MAX_SAMPLES,
                      contamination=CONTAMINATION)
    # train IF model
    model.fit()
    print("===========PREDICTING WITH ISO_FOREST============================")
    # predict
    # model.predict(which_set='train')
    auc_roc = model.predict(which_set='test')
    print("========================================================================")
    print("AUROC",auc_roc)
    print("========================================================================")
    AUC.append(auc_roc)
  
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.0321
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.06789
# ========================================================================
# AUROC 0.6631863333333333
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.4165
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.06835
# ========================================================================
# AUROC 0.648444
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 46.9154
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.72028
# ========================================================================
# AUROC 0.6306343333333333
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.086
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.04442
# ========================================================================
# AUROC 0.6270483333333333
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.2091
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.3746
# ========================================================================
# AUROC 0.648322
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 46.9079
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.76647
# ========================================================================
# AUROC 0.6520726666666667
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.1761
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.93324
# ========================================================================
# AUROC 0.6491103333333333
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.389
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.05339
# ========================================================================
# AUROC 0.6366923333333333
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 46.9281
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.72926
# ========================================================================
# AUROC 0.6611423333333334
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 2
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.4436
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.99907
# ========================================================================
# AUROC 0.6347026666666666
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.6631863333333333, 0.648444, 0.6306343333333333, 0.6270483333333333, 0.648322, 0.6520726666666667, 0.6491103333333333, 0.6366923333333333, 0.6611423333333334, 0.6347026666666666]
# AUROC ===== 0.6451355333333334 +/- 0.011767052905086797
# ========================================================================

# %% [markdown]
# ##** Cat Vs All **##

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2
from src.models.isoForest import IsoForest
import numpy as np 
from src.config import Configuration as Cfg
from src.config import Configuration as Cfg
from src.models.isoForest import IsoForest
# from src.utils.log import log_exp_config, log_isoForest, log_AD_results
# from src.utils.visualization.images_plot import plot_outliers_and_most_normal



DATASET = "cifar10"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/cifar10/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/cifar10/ISO_FOREST/"
PRETRAINED_WT_PATH = ""

RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.cifar10_val_frac = 0.1
Cfg.cifar10_normal = 3
Cfg.cifar10_outlier = -1



for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    # initialize Isolation Forest
    model = IsoForest(dataset=DATASET, n_estimators=ESTIMATORS, max_samples=MAX_SAMPLES,
                      contamination=CONTAMINATION)
    # train IF model
    model.fit()
    print("===========PREDICTING WITH ISO_FOREST============================")
    # predict
    # model.predict(which_set='train')
    auc_roc = model.predict(which_set='test')
    print("========================================================================")
    print("AUROC",auc_roc)
    print("========================================================================")
    AUC.append(auc_roc)
  
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.5289
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.04752
# ========================================================================
# AUROC 0.6055276666666667
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.512
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.09542
# ========================================================================
# AUROC 0.5234886666666666
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.3663
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.74852
# ========================================================================
# AUROC 0.5933596666666667
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.9235
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.13348
# ========================================================================
# AUROC 0.577915
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.6768
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.1245
# ========================================================================
# AUROC 0.5504943333333333
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.4672
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.09697
# ========================================================================
# AUROC 0.5596193333333334
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.9158
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.37839
# ========================================================================
# AUROC 0.5597746666666668
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 48.0487
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.05978
# ========================================================================
# AUROC 0.5435006666666666
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 46.8513
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.03791
# ========================================================================
# AUROC 0.535569
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 3
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.5175
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.96637
# ========================================================================
# AUROC 0.566935
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.6055276666666667, 0.5234886666666666, 0.5933596666666667, 0.577915, 0.5504943333333333, 0.5596193333333334, 0.5597746666666668, 0.5435006666666666, 0.535569, 0.566935]
# AUROC ===== 0.5616184000000001 +/- 0.024127199714936785
# ========================================================================

# %% [markdown]
# ##** Deer Vs All **##

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2
from src.models.isoForest import IsoForest
import numpy as np 
from src.config import Configuration as Cfg
from src.config import Configuration as Cfg
from src.models.isoForest import IsoForest
# from src.utils.log import log_exp_config, log_isoForest, log_AD_results
# from src.utils.visualization.images_plot import plot_outliers_and_most_normal



DATASET = "cifar10"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/cifar10/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/cifar10/ISO_FOREST/"
PRETRAINED_WT_PATH = ""

RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.cifar10_val_frac = 0.1
Cfg.cifar10_normal = 4
Cfg.cifar10_outlier = -1



for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    # initialize Isolation Forest
    model = IsoForest(dataset=DATASET, n_estimators=ESTIMATORS, max_samples=MAX_SAMPLES,
                      contamination=CONTAMINATION)
    # train IF model
    model.fit()
    print("===========PREDICTING WITH ISO_FOREST============================")
    # predict
    # model.predict(which_set='train')
    auc_roc = model.predict(which_set='test')
    print("========================================================================")
    print("AUROC",auc_roc)
    print("========================================================================")
    AUC.append(auc_roc)
  
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 48.2444
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.083
# ========================================================================
# AUROC 0.7240446666666667
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.5533
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.07165
# ========================================================================
# AUROC 0.734851
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 48.7409
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.04851
# ========================================================================
# AUROC 0.7335393333333333
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.2091
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.72313
# ========================================================================
# AUROC 0.7281283333333333
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.9302
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.68786
# ========================================================================
# AUROC 0.7230686666666666
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.1223
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.99871
# ========================================================================
# AUROC 0.7434673333333333
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.8732
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.66819
# ========================================================================
# AUROC 0.7263456666666666
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.877
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.73369
# ========================================================================
# AUROC 0.6979683333333333
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 48.4755
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.70363
# ========================================================================
# AUROC 0.7308263333333334
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 4
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 46.9821
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.6235
# ========================================================================
# AUROC 0.724747
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.7240446666666667, 0.734851, 0.7335393333333333, 0.7281283333333333, 0.7230686666666666, 0.7434673333333333, 0.7263456666666666, 0.6979683333333333, 0.7308263333333334, 0.724747]
# AUROC ===== 0.7266986666666665 +/- 0.011238822452157127
# ========================================================================

# %% [markdown]
# ##** Dog Vs All **##

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2
from src.models.isoForest import IsoForest
import numpy as np 
from src.config import Configuration as Cfg
from src.config import Configuration as Cfg
from src.models.isoForest import IsoForest
# from src.utils.log import log_exp_config, log_isoForest, log_AD_results
# from src.utils.visualization.images_plot import plot_outliers_and_most_normal



DATASET = "cifar10"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/cifar10/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/cifar10/ISO_FOREST/"
PRETRAINED_WT_PATH = ""

RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.cifar10_val_frac = 0.1
Cfg.cifar10_normal = 5
Cfg.cifar10_outlier = -1



for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    # initialize Isolation Forest
    model = IsoForest(dataset=DATASET, n_estimators=ESTIMATORS, max_samples=MAX_SAMPLES,
                      contamination=CONTAMINATION)
    # train IF model
    model.fit()
    print("===========PREDICTING WITH ISO_FOREST============================")
    # predict
    # model.predict(which_set='train')
    auc_roc = model.predict(which_set='test')
    print("========================================================================")
    print("AUROC",auc_roc)
    print("========================================================================")
    AUC.append(auc_roc)
  
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.318
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.61566
# ========================================================================
# AUROC 0.6154390000000001
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.0734
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.01579
# ========================================================================
# AUROC 0.6217030000000001
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.3745
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.07293
# ========================================================================
# AUROC 0.6245896666666667
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.3709
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.68753
# ========================================================================
# AUROC 0.5519666666666667
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.6441
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.05098
# ========================================================================
# AUROC 0.6541156666666665
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.558
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.02541
# ========================================================================
# AUROC 0.5925996666666666
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.5151
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.98278
# ========================================================================
# AUROC 0.6449159999999999
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.9576
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.80807
# ========================================================================
# AUROC 0.6180399999999999
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.8453
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.98695
# ========================================================================
# AUROC 0.5951900000000001
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 5
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.782
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.04801
# ========================================================================
# AUROC 0.6277013333333333
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.6154390000000001, 0.6217030000000001, 0.6245896666666667, 0.5519666666666667, 0.6541156666666665, 0.5925996666666666, 0.6449159999999999, 0.6180399999999999, 0.5951900000000001, 0.6277013333333333]
# AUROC ===== 0.6146261 +/- 0.027565679154440463
# ========================================================================

# %% [markdown]
# ##** Frog Vs All **##

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2
from src.models.isoForest import IsoForest
import numpy as np 
from src.config import Configuration as Cfg
from src.config import Configuration as Cfg
from src.models.isoForest import IsoForest
# from src.utils.log import log_exp_config, log_isoForest, log_AD_results
# from src.utils.visualization.images_plot import plot_outliers_and_most_normal



DATASET = "cifar10"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/cifar10/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/cifar10/ISO_FOREST/"
PRETRAINED_WT_PATH = ""

RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.cifar10_val_frac = 0.1
Cfg.cifar10_normal = 6
Cfg.cifar10_outlier = -1



for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    # initialize Isolation Forest
    model = IsoForest(dataset=DATASET, n_estimators=ESTIMATORS, max_samples=MAX_SAMPLES,
                      contamination=CONTAMINATION)
    # train IF model
    model.fit()
    print("===========PREDICTING WITH ISO_FOREST============================")
    # predict
    # model.predict(which_set='train')
    auc_roc = model.predict(which_set='test')
    print("========================================================================")
    print("AUROC",auc_roc)
    print("========================================================================")
    AUC.append(auc_roc)
  
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.3901
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.02143
# ========================================================================
# AUROC 0.6781573333333334
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.914
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.062
# ========================================================================
# AUROC 0.6674456666666666
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.4905
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.01772
# ========================================================================
# AUROC 0.645255
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 48.3158
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.01259
# ========================================================================
# AUROC 0.6978086666666665
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.6969
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.94126
# ========================================================================
# AUROC 0.6840390000000001
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.8932
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.01783
# ========================================================================
# AUROC 0.7045276666666667
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.5938
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.02361
# ========================================================================
# AUROC 0.6784476666666666
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.976
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.0516
# ========================================================================
# AUROC 0.671152
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 48.0671
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.70447
# ========================================================================
# AUROC 0.6589566666666666
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 6
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.4551
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.04835
# ========================================================================
# AUROC 0.720527
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.6781573333333334, 0.6674456666666666, 0.645255, 0.6978086666666665, 0.6840390000000001, 0.7045276666666667, 0.6784476666666666, 0.671152, 0.6589566666666666, 0.720527]
# AUROC ===== 0.6806316666666666 +/- 0.021131154048518556
# ========================================================================

# %% [markdown]
# ##** Horse Vs All **##

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2
from src.models.isoForest import IsoForest
import numpy as np 
from src.config import Configuration as Cfg
from src.config import Configuration as Cfg
from src.models.isoForest import IsoForest
# from src.utils.log import log_exp_config, log_isoForest, log_AD_results
# from src.utils.visualization.images_plot import plot_outliers_and_most_normal



DATASET = "cifar10"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/cifar10/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/cifar10/ISO_FOREST/"
PRETRAINED_WT_PATH = ""

RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.cifar10_val_frac = 0.1
Cfg.cifar10_normal = 7
Cfg.cifar10_outlier = -1



for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    # initialize Isolation Forest
    model = IsoForest(dataset=DATASET, n_estimators=ESTIMATORS, max_samples=MAX_SAMPLES,
                      contamination=CONTAMINATION)
    # train IF model
    model.fit()
    print("===========PREDICTING WITH ISO_FOREST============================")
    # predict
    # model.predict(which_set='train')
    auc_roc = model.predict(which_set='test')
    print("========================================================================")
    print("AUROC",auc_roc)
    print("========================================================================")
    AUC.append(auc_roc)
  
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 48.0186
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.95601
# ========================================================================
# AUROC 0.5921803333333333
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.7987
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.95985
# ========================================================================
# AUROC 0.623558
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.8084
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.58375
# ========================================================================
# AUROC 0.6443093333333333
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.4758
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.70093
# ========================================================================
# AUROC 0.6438353333333333
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 48.5087
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.55068
# ========================================================================
# AUROC 0.6312506666666667
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 48.3406
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.04038
# ========================================================================
# AUROC 0.633861
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 49.4238
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.2462
# ========================================================================
# AUROC 0.64469
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 48.6987
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.97573
# ========================================================================
# AUROC 0.6390586666666667
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 48.7447
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.32731
# ========================================================================
# AUROC 0.61287
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 7
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 50.2281
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.50823
# ========================================================================
# AUROC 0.6387203333333333
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.5921803333333333, 0.623558, 0.6443093333333333, 0.6438353333333333, 0.6312506666666667, 0.633861, 0.64469, 0.6390586666666667, 0.61287, 0.6387203333333333]
# AUROC ===== 0.6304333666666667 +/- 0.01596850054426596
# ========================================================================

# %% [markdown]
# ##** Ship Vs All **##

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2
from src.models.isoForest import IsoForest
import numpy as np 
from src.config import Configuration as Cfg
from src.config import Configuration as Cfg
from src.models.isoForest import IsoForest
# from src.utils.log import log_exp_config, log_isoForest, log_AD_results
# from src.utils.visualization.images_plot import plot_outliers_and_most_normal



DATASET = "cifar10"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/cifar10/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/cifar10/ISO_FOREST/"
PRETRAINED_WT_PATH = ""

RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.cifar10_val_frac = 0.1
Cfg.cifar10_normal = 8
Cfg.cifar10_outlier = -1



for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    # initialize Isolation Forest
    model = IsoForest(dataset=DATASET, n_estimators=ESTIMATORS, max_samples=MAX_SAMPLES,
                      contamination=CONTAMINATION)
    # train IF model
    model.fit()
    print("===========PREDICTING WITH ISO_FOREST============================")
    # predict
    # model.predict(which_set='train')
    auc_roc = model.predict(which_set='test')
    print("========================================================================")
    print("AUROC",auc_roc)
    print("========================================================================")
    AUC.append(auc_roc)
  
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 49.3822
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.00813
# ========================================================================
# AUROC 0.679376
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 48.4296
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.9831
# ========================================================================
# AUROC 0.6804526666666667
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 49.2521
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.98199
# ========================================================================
# AUROC 0.6864656666666666
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 50.0484
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.99173
# ========================================================================
# AUROC 0.6844793333333333
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 48.5203
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.01105
# ========================================================================
# AUROC 0.689547
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.9569
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.71271
# ========================================================================
# AUROC 0.6631516666666666
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 47.4512
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.05817
# ========================================================================
# AUROC 0.7105246666666667
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 50.4012
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.99623
# ========================================================================
# AUROC 0.6639393333333334
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 48.5514
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 5.77964
# ========================================================================
# AUROC 0.6750480000000001
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 8
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 48.5471
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.3264
# ========================================================================
# AUROC 0.6688753333333334
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.679376, 0.6804526666666667, 0.6864656666666666, 0.6844793333333333, 0.689547, 0.6631516666666666, 0.7105246666666667, 0.6639393333333334, 0.6750480000000001, 0.6688753333333334]
# AUROC ===== 0.6801859666666666 +/- 0.013323325658783544
# ========================================================================

# %% [markdown]
# ##** Truck Vs All **##

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2
from src.models.isoForest import IsoForest
import numpy as np 
from src.config import Configuration as Cfg
from src.config import Configuration as Cfg
from src.models.isoForest import IsoForest
# from src.utils.log import log_exp_config, log_isoForest, log_AD_results
# from src.utils.visualization.images_plot import plot_outliers_and_most_normal



DATASET = "cifar10"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/cifar10/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/cifar10/ISO_FOREST/"
PRETRAINED_WT_PATH = ""

RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.cifar10_val_frac = 0.1
Cfg.cifar10_normal = 9
Cfg.cifar10_outlier = -1



for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    # initialize Isolation Forest
    model = IsoForest(dataset=DATASET, n_estimators=ESTIMATORS, max_samples=MAX_SAMPLES,
                      contamination=CONTAMINATION)
    # train IF model
    model.fit()
    print("===========PREDICTING WITH ISO_FOREST============================")
    # predict
    # model.predict(which_set='train')
    auc_roc = model.predict(which_set='test')
    print("========================================================================")
    print("AUROC",auc_roc)
    print("========================================================================")
    AUC.append(auc_roc)
  
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  42
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 48.8551
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.28157
# ========================================================================
# AUROC 0.7090079999999999
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  56
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 48.5195
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.10208
# ========================================================================
# AUROC 0.7292306666666667
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  81
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 48.0811
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.47523
# ========================================================================
# AUROC 0.7356713333333333
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  67
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 49.6886
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 7.29398
# ========================================================================
# AUROC 0.7283906666666665
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  33
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 50.7893
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 7.25496
# ========================================================================
# AUROC 0.7346506666666667
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  25
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 50.1401
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.05471
# ========================================================================
# AUROC 0.740372
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  90
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 48.2844
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.07532
# ========================================================================
# AUROC 0.743633
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  77
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 48.7739
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.45422
# ========================================================================
# AUROC 0.7341513333333333
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  15
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 49.2259
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.34601
# ========================================================================
# AUROC 0.709094
# ========================================================================
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# Inside the CIFAR10_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/reports/figures/cifar10/RCAE/
# [INFO:] Loading data...
# The normal label used in experiment, 9
# INFO: Random Seed set is  11
# x_outlier shape: (500, 32, 32, 3)
# _X_test_beforegcn, (6500, 32, 32, 3) 1.0 0.0
# Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6500, 32, 32, 3)
# The shape of POS data :  (6000, 32, 32, 3)
# The shape of NEG data :  (500, 32, 32, 3)
# Starting training...
# Total elapsed time: 48.4407
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 6.01878
# ========================================================================
# AUROC 0.7188956666666666
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.7090079999999999, 0.7292306666666667, 0.7356713333333333, 0.7283906666666665, 0.7346506666666667, 0.740372, 0.743633, 0.7341513333333333, 0.709094, 0.7188956666666666]
# AUROC ===== 0.7283097333333333 +/- 0.011576296022284337
# ========================================================================
