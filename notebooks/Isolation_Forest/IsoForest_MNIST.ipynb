# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install picklable_itertools

# !pip install fuel
# !pip install foolbox

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
import numpy as np
PROJECT_DIR = "/content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/"
import sys,os
import numpy as np
sys.path.append(PROJECT_DIR)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: picklable_itertools in /usr/local/lib/python3.6/dist-packages (0.1.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from picklable_itertools) (1.11.0)
# Requirement already satisfied: fuel in /usr/local/lib/python3.6/dist-packages (0.2.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from fuel) (3.13)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from fuel) (4.0.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from fuel) (1.11.0)
# Requirement already satisfied: progressbar2 in /usr/local/lib/python3.6/dist-packages (from fuel) (3.38.0)
# Requirement already satisfied: tables in /usr/local/lib/python3.6/dist-packages (from fuel) (3.4.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from fuel) (2.18.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from fuel) (1.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from fuel) (1.14.6)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.6/dist-packages (from fuel) (17.0.0)
# Requirement already satisfied: picklable-itertools in /usr/local/lib/python3.6/dist-packages (from fuel) (0.1.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from fuel) (2.8.0)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from pillow->fuel) (0.46)
# Requirement already satisfied: python-utils>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from progressbar2->fuel) (2.3.0)
# Requirement already satisfied: numexpr>=2.5.2 in /usr/local/lib/python3.6/dist-packages (from tables->fuel) (2.6.8)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->fuel) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->fuel) (2018.10.15)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->fuel) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->fuel) (3.0.4)
# Requirement already satisfied: foolbox in /usr/local/lib/python3.6/dist-packages (1.8.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from foolbox) (1.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from foolbox) (40.6.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from foolbox) (1.14.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from foolbox) (2.18.4)
# Requirement already satisfied: GitPython in /usr/local/lib/python3.6/dist-packages (from foolbox) (2.1.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->foolbox) (2018.10.15)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->foolbox) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->foolbox) (1.22)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->foolbox) (2.6)
# Requirement already satisfied: gitdb2>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from GitPython->foolbox) (2.0.5)
# Requirement already satisfied: smmap2>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from gitdb2>=2.0.0->GitPython->foolbox) (2.0.5)

# %% [markdown]
# ##** 0 Vs All Experiments **##

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2
from src.models.isoForest import IsoForest
import numpy as np 
from src.config import Configuration as Cfg

DATASET = "mnist"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/mnist/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/mnist/ISO_FOREST/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.mnist_val_frac = 0.1
Cfg.mnist_normal = 0
Cfg.mnist_outlier = -1



for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    # initialize Isolation Forest
    model = IsoForest(dataset=DATASET, n_estimators=ESTIMATORS, max_samples=MAX_SAMPLES,
                      contamination=CONTAMINATION)
    # train IF model
    model.fit()
    print("===========PREDICTING WITH ISO_FOREST============================")
    # predict
    # model.predict(which_set='train')
    auc_roc = model.predict(which_set='test')
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    AUC.append(auc_roc)
  
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# Using TensorFlow backend.
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/utils/visualization/mosaic_plot.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-6569f4f7c1be>", line 10, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')  # or 'PS', 'PDF', 'SVG'
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6374, 28, 28, 1)
# The shape of POS data :  (6311, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.3576
# ===========PREDICTING WITH ISO_FOREST============================
# The shape of Testing data :  (6374, 28, 28, 1) (6374,)
# The shape of POS data :  (6311, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting prediction...
# Total elapsed time: 1.61414
# ========================================================================
# AUROC:  0.9679446066706405
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   56
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6374, 28, 28, 1)
# The shape of POS data :  (6311, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.14479
# ===========PREDICTING WITH ISO_FOREST============================
# The shape of Testing data :  (6374, 28, 28, 1) (6374,)
# The shape of POS data :  (6311, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting prediction...
# Total elapsed time: 1.65438
# ========================================================================
# AUROC:  0.9741771107640225
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   81
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6374, 28, 28, 1)
# The shape of POS data :  (6311, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.32076
# ===========PREDICTING WITH ISO_FOREST============================
# The shape of Testing data :  (6374, 28, 28, 1) (6374,)
# The shape of POS data :  (6311, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting prediction...
# Total elapsed time: 1.65651
# ========================================================================
# AUROC:  0.9542320916112708
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   67
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6374, 28, 28, 1)
# The shape of POS data :  (6311, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.44313
# ===========PREDICTING WITH ISO_FOREST============================
# The shape of Testing data :  (6374, 28, 28, 1) (6374,)
# The shape of POS data :  (6311, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting prediction...
# Total elapsed time: 1.68256
# ========================================================================
# AUROC:  0.951583654641807
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   33
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6374, 28, 28, 1)
# The shape of POS data :  (6311, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.31619
# ===========PREDICTING WITH ISO_FOREST============================
# The shape of Testing data :  (6374, 28, 28, 1) (6374,)
# The shape of POS data :  (6311, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting prediction...
# Total elapsed time: 1.58259
# ========================================================================
# AUROC:  0.9434245572733928
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   25
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6374, 28, 28, 1)
# The shape of POS data :  (6311, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.47491
# ===========PREDICTING WITH ISO_FOREST============================
# The shape of Testing data :  (6374, 28, 28, 1) (6374,)
# The shape of POS data :  (6311, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting prediction...
# Total elapsed time: 1.69897
# ========================================================================
# AUROC:  0.9445010349779801
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   90
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6374, 28, 28, 1)
# The shape of POS data :  (6311, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.45952
# ===========PREDICTING WITH ISO_FOREST============================
# The shape of Testing data :  (6374, 28, 28, 1) (6374,)
# The shape of POS data :  (6311, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting prediction...
# Total elapsed time: 1.59775
# ========================================================================
# AUROC:  0.9346920091651512
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   77
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6374, 28, 28, 1)
# The shape of POS data :  (6311, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.56216
# ===========PREDICTING WITH ISO_FOREST============================
# The shape of Testing data :  (6374, 28, 28, 1) (6374,)
# The shape of POS data :  (6311, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting prediction...
# Total elapsed time: 1.73228
# ========================================================================
# AUROC:  0.9524010734595428
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   15
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6374, 28, 28, 1)
# The shape of POS data :  (6311, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.50887
# ===========PREDICTING WITH ISO_FOREST============================
# The shape of Testing data :  (6374, 28, 28, 1) (6374,)
# The shape of POS data :  (6311, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting prediction...
# Total elapsed time: 1.56504
# ========================================================================
# AUROC:  0.9583292462392445
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  0
# [INFO:] Random Seed used is   11
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6374, 28, 28, 1)
# The shape of POS data :  (6311, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.25075
# ===========PREDICTING WITH ISO_FOREST============================
# The shape of Testing data :  (6374, 28, 28, 1) (6374,)
# The shape of POS data :  (6311, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting prediction...
# Total elapsed time: 1.53092
# ========================================================================
# AUROC:  0.9512793233281269
# ===========AURO Computed============================
# AUROC computed  [0.9679446066706405, 0.9741771107640225, 0.9542320916112708, 0.951583654641807, 0.9434245572733928, 0.9445010349779801, 0.9346920091651512, 0.9524010734595428, 0.9583292462392445, 0.9512793233281269]
# AUROC ===== 0.9532564708131179 +/- 0.010979535258551294
# ========================================================================

# %% [markdown]
# ## ** MNIST 1 Vs All

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2
from src.models.isoForest import IsoForest
import numpy as np 
from src.config import Configuration as Cfg

DATASET = "mnist"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/mnist/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/mnist/ISO_FOREST/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.mnist_val_frac = 0.1
Cfg.mnist_normal = 1
Cfg.mnist_outlier = -1



for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    # initialize Isolation Forest
    model = IsoForest(dataset=DATASET, n_estimators=ESTIMATORS, max_samples=MAX_SAMPLES,
                      contamination=CONTAMINATION)
    # train IF model
    model.fit()
    print("===========PREDICTING WITH ISO_FOREST============================")
    # predict
    # model.predict(which_set='train')
    auc_roc = model.predict(which_set='test')
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    AUC.append(auc_roc)
  
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# Using TensorFlow backend.
# /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/src/utils/visualization/mosaic_plot.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-6569f4f7c1be>", line 10, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-105>", line 2, in matplotlib
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2950, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py", line 309, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/usr/local/lib/python3.6/dist-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')  # or 'PS', 'PDF', 'SVG'
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (7275, 28, 28, 1)
# The shape of POS data :  (7203, 28, 28, 1)
# The shape of NEG data :  (72, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.60395
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.90514
# ========================================================================
# AUROC:  0.9915756552053928
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   56
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (7275, 28, 28, 1)
# The shape of POS data :  (7203, 28, 28, 1)
# The shape of NEG data :  (72, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.65291
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.91151
# ========================================================================
# AUROC:  0.993870223826492
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   81
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (7275, 28, 28, 1)
# The shape of POS data :  (7203, 28, 28, 1)
# The shape of NEG data :  (72, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.52561
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.92085
# ========================================================================
# AUROC:  0.9884326746571643
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   67
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (7275, 28, 28, 1)
# The shape of POS data :  (7203, 28, 28, 1)
# The shape of NEG data :  (72, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.65602
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.95596
# ========================================================================
# AUROC:  0.9943503478488901
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   33
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (7275, 28, 28, 1)
# The shape of POS data :  (7203, 28, 28, 1)
# The shape of NEG data :  (72, 28, 28, 1)
# Starting training...
# Total elapsed time: 10.0684
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.92857
# ========================================================================
# AUROC:  0.9959179817051537
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   25
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (7275, 28, 28, 1)
# The shape of POS data :  (7203, 28, 28, 1)
# The shape of NEG data :  (72, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.88263
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.90006
# ========================================================================
# AUROC:  0.9955014885772904
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   90
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (7275, 28, 28, 1)
# The shape of POS data :  (7203, 28, 28, 1)
# The shape of NEG data :  (72, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.98896
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 2.03377
# ========================================================================
# AUROC:  0.9896551591158005
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   77
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (7275, 28, 28, 1)
# The shape of POS data :  (7203, 28, 28, 1)
# The shape of NEG data :  (72, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.91338
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.96106
# ========================================================================
# AUROC:  0.9950175081370417
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   15
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (7275, 28, 28, 1)
# The shape of POS data :  (7203, 28, 28, 1)
# The shape of NEG data :  (72, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.95593
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.85039
# ========================================================================
# AUROC:  0.9973448563098709
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  1
# [INFO:] Random Seed used is   11
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (7275, 28, 28, 1)
# The shape of POS data :  (7203, 28, 28, 1)
# The shape of NEG data :  (72, 28, 28, 1)
# Starting training...
# Total elapsed time: 10.1219
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.93588
# ========================================================================
# AUROC:  0.9934807256235828
# ===========AURO Computed============================
# AUROC computed  [0.9915756552053928, 0.993870223826492, 0.9884326746571643, 0.9943503478488901, 0.9959179817051537, 0.9955014885772904, 0.9896551591158005, 0.9950175081370417, 0.9973448563098709, 0.9934807256235828]
# AUROC ===== 0.9935146621006679 +/- 0.0026825437994551513
# ========================================================================

# %% [markdown]
# ## ** MNIST 2 Vs All

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2
from src.models.isoForest import IsoForest
import numpy as np 
from src.config import Configuration as Cfg

DATASET = "mnist"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/mnist/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/mnist/ISO_FOREST/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.mnist_val_frac = 0.1
Cfg.mnist_normal = 2
Cfg.mnist_outlier = -1



for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    # initialize Isolation Forest
    model = IsoForest(dataset=DATASET, n_estimators=ESTIMATORS, max_samples=MAX_SAMPLES,
                      contamination=CONTAMINATION)
    # train IF model
    model.fit()
    print("===========PREDICTING WITH ISO_FOREST============================")
    # predict
    # model.predict(which_set='train')
    auc_roc = model.predict(which_set='test')
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    AUC.append(auc_roc)
  
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  2
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6458, 28, 28, 1)
# The shape of POS data :  (6395, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.75765
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.69519
# ========================================================================
# AUROC:  0.6839619246186877
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  2
# [INFO:] Random Seed used is   56
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6458, 28, 28, 1)
# The shape of POS data :  (6395, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.79001
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.7333
# ========================================================================
# AUROC:  0.7096417091725927
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  2
# [INFO:] Random Seed used is   81
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6458, 28, 28, 1)
# The shape of POS data :  (6395, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.03729
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.66925
# ========================================================================
# AUROC:  0.8442011988532708
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  2
# [INFO:] Random Seed used is   67
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6458, 28, 28, 1)
# The shape of POS data :  (6395, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.82739
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.75345
# ========================================================================
# AUROC:  0.7003586631420876
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  2
# [INFO:] Random Seed used is   33
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6458, 28, 28, 1)
# The shape of POS data :  (6395, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.8099
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.63555
# ========================================================================
# AUROC:  0.7310795884681734
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  2
# [INFO:] Random Seed used is   25
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6458, 28, 28, 1)
# The shape of POS data :  (6395, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.93722
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.71126
# ========================================================================
# AUROC:  0.7509487819104708
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  2
# [INFO:] Random Seed used is   90
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6458, 28, 28, 1)
# The shape of POS data :  (6395, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.86621
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.74355
# ========================================================================
# AUROC:  0.7311763902850689
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  2
# [INFO:] Random Seed used is   77
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6458, 28, 28, 1)
# The shape of POS data :  (6395, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.76332
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.66247
# ========================================================================
# AUROC:  0.7718952058279658
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  2
# [INFO:] Random Seed used is   15
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6458, 28, 28, 1)
# The shape of POS data :  (6395, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.92752
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.74884
# ========================================================================
# AUROC:  0.705561140275761
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  2
# [INFO:] Random Seed used is   11
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6458, 28, 28, 1)
# The shape of POS data :  (6395, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.94684
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.75426
# ========================================================================
# AUROC:  0.6862231157774551
# ===========AURO Computed============================
# AUROC computed  [0.6839619246186877, 0.7096417091725927, 0.8442011988532708, 0.7003586631420876, 0.7310795884681734, 0.7509487819104708, 0.7311763902850689, 0.7718952058279658, 0.705561140275761, 0.6862231157774551]
# AUROC ===== 0.7315047718331533 +/- 0.04598056793352748
# ========================================================================

# %% [markdown]
# ## ** MNIST 3 Vs All

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2
from src.models.isoForest import IsoForest
import numpy as np 
from src.config import Configuration as Cfg

DATASET = "mnist"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/mnist/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/mnist/ISO_FOREST/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.mnist_val_frac = 0.1
Cfg.mnist_normal = 3
Cfg.mnist_outlier = -1



for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    # initialize Isolation Forest
    model = IsoForest(dataset=DATASET, n_estimators=ESTIMATORS, max_samples=MAX_SAMPLES,
                      contamination=CONTAMINATION)
    # train IF model
    model.fit()
    print("===========PREDICTING WITH ISO_FOREST============================")
    # predict
    # model.predict(which_set='train')
    auc_roc = model.predict(which_set='test')
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    AUC.append(auc_roc)
  
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (6528, 28, 28, 1)
# The shape of NEG data :  (65, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.91604
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.66104
# ========================================================================
# AUROC:  0.8231264140271493
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO:] Random Seed used is   56
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (6528, 28, 28, 1)
# The shape of NEG data :  (65, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.1488
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.75693
# ========================================================================
# AUROC:  0.7378205128205129
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO:] Random Seed used is   81
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (6528, 28, 28, 1)
# The shape of NEG data :  (65, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.07298
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.71191
# ========================================================================
# AUROC:  0.8137231334841629
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO:] Random Seed used is   67
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (6528, 28, 28, 1)
# The shape of NEG data :  (65, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.11553
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.74639
# ========================================================================
# AUROC:  0.8197492458521871
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO:] Random Seed used is   33
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (6528, 28, 28, 1)
# The shape of NEG data :  (65, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.96987
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.68187
# ========================================================================
# AUROC:  0.8207508484162895
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO:] Random Seed used is   25
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (6528, 28, 28, 1)
# The shape of NEG data :  (65, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.05707
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.80523
# ========================================================================
# AUROC:  0.8316930618401207
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO:] Random Seed used is   90
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (6528, 28, 28, 1)
# The shape of NEG data :  (65, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.26538
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.76224
# ========================================================================
# AUROC:  0.8004713423831071
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO:] Random Seed used is   77
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (6528, 28, 28, 1)
# The shape of NEG data :  (65, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.15202
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.75574
# ========================================================================
# AUROC:  0.8056066176470589
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO:] Random Seed used is   15
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (6528, 28, 28, 1)
# The shape of NEG data :  (65, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.22534
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.79624
# ========================================================================
# AUROC:  0.8298807503770738
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO:] Random Seed used is   11
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (6528, 28, 28, 1)
# The shape of NEG data :  (65, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.20553
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.76554
# ========================================================================
# AUROC:  0.85118778280543
# ===========AURO Computed============================
# AUROC computed  [0.8231264140271493, 0.7378205128205129, 0.8137231334841629, 0.8197492458521871, 0.8207508484162895, 0.8316930618401207, 0.8004713423831071, 0.8056066176470589, 0.8298807503770738, 0.85118778280543]
# AUROC ===== 0.8134009709653093 +/- 0.02857161018107947
# ========================================================================

# %% [markdown]
# ## ** MNIST 4 Vs All

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2
from src.models.isoForest import IsoForest
import numpy as np 
from src.config import Configuration as Cfg

DATASET = "mnist"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/mnist/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/mnist/ISO_FOREST/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.mnist_val_frac = 0.1
Cfg.mnist_normal = 4
Cfg.mnist_outlier = -1



for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    # initialize Isolation Forest
    model = IsoForest(dataset=DATASET, n_estimators=ESTIMATORS, max_samples=MAX_SAMPLES,
                      contamination=CONTAMINATION)
    # train IF model
    model.fit()
    print("===========PREDICTING WITH ISO_FOREST============================")
    # predict
    # model.predict(which_set='train')
    auc_roc = model.predict(which_set='test')
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    AUC.append(auc_roc)
  
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  4
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (6240, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.97614
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.69935
# ========================================================================
# AUROC:  0.8485292597187759
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  4
# [INFO:] Random Seed used is   56
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (6240, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.19785
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.80008
# ========================================================================
# AUROC:  0.8468491521918942
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  4
# [INFO:] Random Seed used is   81
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (6240, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.1217
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.65218
# ========================================================================
# AUROC:  0.8941713192721257
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  4
# [INFO:] Random Seed used is   67
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (6240, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.22401
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.68722
# ========================================================================
# AUROC:  0.8885494210090985
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  4
# [INFO:] Random Seed used is   33
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (6240, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.86557
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.67938
# ========================================================================
# AUROC:  0.8312396608767576
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  4
# [INFO:] Random Seed used is   25
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (6240, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.38217
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.7394
# ========================================================================
# AUROC:  0.8901519851116626
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  4
# [INFO:] Random Seed used is   90
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (6240, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.98862
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.66996
# ========================================================================
# AUROC:  0.8616832092638544
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  4
# [INFO:] Random Seed used is   77
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (6240, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.81376
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.671
# ========================================================================
# AUROC:  0.8800739247311827
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  4
# [INFO:] Random Seed used is   15
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (6240, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.98872
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.705
# ========================================================================
# AUROC:  0.9242504135649298
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  4
# [INFO:] Random Seed used is   11
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (6240, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.9558
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.68194
# ========================================================================
# AUROC:  0.8750129239040529
# ===========AURO Computed============================
# AUROC computed  [0.8485292597187759, 0.8468491521918942, 0.8941713192721257, 0.8885494210090985, 0.8312396608767576, 0.8901519851116626, 0.8616832092638544, 0.8800739247311827, 0.9242504135649298, 0.8750129239040529]
# AUROC ===== 0.8740511269644333 +/- 0.02609315615123555
# ========================================================================

# %% [markdown]
# ## ** MNIST 5 Vs All

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2
from src.models.isoForest import IsoForest
import numpy as np 
from src.config import Configuration as Cfg

DATASET = "mnist"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/mnist/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/mnist/ISO_FOREST/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.mnist_val_frac = 0.1
Cfg.mnist_normal = 5
Cfg.mnist_outlier = -1



for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    # initialize Isolation Forest
    model = IsoForest(dataset=DATASET, n_estimators=ESTIMATORS, max_samples=MAX_SAMPLES,
                      contamination=CONTAMINATION)
    # train IF model
    model.fit()
    print("===========PREDICTING WITH ISO_FOREST============================")
    # predict
    # model.predict(which_set='train')
    auc_roc = model.predict(which_set='test')
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    AUC.append(auc_roc)
  
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  5
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (5828, 28, 28, 1)
# The shape of POS data :  (5771, 28, 28, 1)
# The shape of NEG data :  (57, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.4031
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.54558
# ========================================================================
# AUROC:  0.7438797131452787
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  5
# [INFO:] Random Seed used is   56
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (5828, 28, 28, 1)
# The shape of POS data :  (5771, 28, 28, 1)
# The shape of NEG data :  (57, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.64214
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.54116
# ========================================================================
# AUROC:  0.6971457408032297
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  5
# [INFO:] Random Seed used is   81
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (5828, 28, 28, 1)
# The shape of POS data :  (5771, 28, 28, 1)
# The shape of NEG data :  (57, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.5054
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.52334
# ========================================================================
# AUROC:  0.7203926468397646
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  5
# [INFO:] Random Seed used is   67
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (5828, 28, 28, 1)
# The shape of POS data :  (5771, 28, 28, 1)
# The shape of NEG data :  (57, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.45389
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.56081
# ========================================================================
# AUROC:  0.7119809574186723
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  5
# [INFO:] Random Seed used is   33
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (5828, 28, 28, 1)
# The shape of POS data :  (5771, 28, 28, 1)
# The shape of NEG data :  (57, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.42555
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.54747
# ========================================================================
# AUROC:  0.7590037300841777
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  5
# [INFO:] Random Seed used is   25
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (5828, 28, 28, 1)
# The shape of POS data :  (5771, 28, 28, 1)
# The shape of NEG data :  (57, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.48596
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.55582
# ========================================================================
# AUROC:  0.8008706569751358
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  5
# [INFO:] Random Seed used is   90
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (5828, 28, 28, 1)
# The shape of POS data :  (5771, 28, 28, 1)
# The shape of NEG data :  (57, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.47585
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.53067
# ========================================================================
# AUROC:  0.7087798338334139
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  5
# [INFO:] Random Seed used is   77
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (5828, 28, 28, 1)
# The shape of POS data :  (5771, 28, 28, 1)
# The shape of NEG data :  (57, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.48559
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.54569
# ========================================================================
# AUROC:  0.7587118897573165
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  5
# [INFO:] Random Seed used is   15
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (5828, 28, 28, 1)
# The shape of POS data :  (5771, 28, 28, 1)
# The shape of NEG data :  (57, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.41871
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.59567
# ========================================================================
# AUROC:  0.7539299644015601
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  5
# [INFO:] Random Seed used is   11
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (5828, 28, 28, 1)
# The shape of POS data :  (5771, 28, 28, 1)
# The shape of NEG data :  (57, 28, 28, 1)
# Starting training...
# Total elapsed time: 8.66162
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.56163
# ========================================================================
# AUROC:  0.7413473903090771
# ===========AURO Computed============================
# AUROC computed  [0.7438797131452787, 0.6971457408032297, 0.7203926468397646, 0.7119809574186723, 0.7590037300841777, 0.8008706569751358, 0.7087798338334139, 0.7587118897573165, 0.7539299644015601, 0.7413473903090771]
# AUROC ===== 0.7396042523567625 +/- 0.02933693949422241
# ========================================================================

# %% [markdown]
# ## ** MNIST 6 Vs All

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2
from src.models.isoForest import IsoForest
import numpy as np 
from src.config import Configuration as Cfg

DATASET = "mnist"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/mnist/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/mnist/ISO_FOREST/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.mnist_val_frac = 0.1
Cfg.mnist_normal = 6
Cfg.mnist_outlier = -1



for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    # initialize Isolation Forest
    model = IsoForest(dataset=DATASET, n_estimators=ESTIMATORS, max_samples=MAX_SAMPLES,
                      contamination=CONTAMINATION)
    # train IF model
    model.fit()
    print("===========PREDICTING WITH ISO_FOREST============================")
    # predict
    # model.predict(which_set='train')
    auc_roc = model.predict(which_set='test')
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    AUC.append(auc_roc)
  
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  6
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6347, 28, 28, 1)
# The shape of POS data :  (6285, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.24091
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.70472
# ========================================================================
# AUROC:  0.8701491005209536
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  6
# [INFO:] Random Seed used is   56
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6347, 28, 28, 1)
# The shape of POS data :  (6285, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.2718
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.71061
# ========================================================================
# AUROC:  0.8944953422126416
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  6
# [INFO:] Random Seed used is   81
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6347, 28, 28, 1)
# The shape of POS data :  (6285, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.16261
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.68707
# ========================================================================
# AUROC:  0.8893063361305721
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  6
# [INFO:] Random Seed used is   67
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6347, 28, 28, 1)
# The shape of POS data :  (6285, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.25209
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.64026
# ========================================================================
# AUROC:  0.8801088100187338
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  6
# [INFO:] Random Seed used is   33
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6347, 28, 28, 1)
# The shape of POS data :  (6285, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.32539
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.69771
# ========================================================================
# AUROC:  0.893294325968127
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  6
# [INFO:] Random Seed used is   25
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6347, 28, 28, 1)
# The shape of POS data :  (6285, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.46517
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.73759
# ========================================================================
# AUROC:  0.8901532065593963
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  6
# [INFO:] Random Seed used is   90
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6347, 28, 28, 1)
# The shape of POS data :  (6285, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.42449
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.61994
# ========================================================================
# AUROC:  0.8930223009212923
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  6
# [INFO:] Random Seed used is   77
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6347, 28, 28, 1)
# The shape of POS data :  (6285, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.32427
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.72329
# ========================================================================
# AUROC:  0.8678702491852079
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  6
# [INFO:] Random Seed used is   15
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6347, 28, 28, 1)
# The shape of POS data :  (6285, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.49133
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.69541
# ========================================================================
# AUROC:  0.8983550183488593
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  6
# [INFO:] Random Seed used is   11
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6347, 28, 28, 1)
# The shape of POS data :  (6285, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.47398
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.63507
# ========================================================================
# AUROC:  0.8883414170965176
# ===========AURO Computed============================
# AUROC computed  [0.8701491005209536, 0.8944953422126416, 0.8893063361305721, 0.8801088100187338, 0.893294325968127, 0.8901532065593963, 0.8930223009212923, 0.8678702491852079, 0.8983550183488593, 0.8883414170965176]
# AUROC ===== 0.8865096106962301 +/- 0.009864321589961245
# ========================================================================

# %% [markdown]
# ## ** MNIST 7 Vs All

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2
from src.models.isoForest import IsoForest
import numpy as np 
from src.config import Configuration as Cfg

DATASET = "mnist"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/mnist/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/mnist/ISO_FOREST/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.mnist_val_frac = 0.1
Cfg.mnist_normal = 7
Cfg.mnist_outlier = -1



for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    # initialize Isolation Forest
    model = IsoForest(dataset=DATASET, n_estimators=ESTIMATORS, max_samples=MAX_SAMPLES,
                      contamination=CONTAMINATION)
    # train IF model
    model.fit()
    print("===========PREDICTING WITH ISO_FOREST============================")
    # predict
    # model.predict(which_set='train')
    auc_roc = model.predict(which_set='test')
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    AUC.append(auc_roc)
  
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  7
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6733, 28, 28, 1)
# The shape of POS data :  (6667, 28, 28, 1)
# The shape of NEG data :  (66, 28, 28, 1)
# Starting training...
# Total elapsed time: 10.1914
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.81961
# ========================================================================
# AUROC:  0.9133747858061643
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  7
# [INFO:] Random Seed used is   56
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6733, 28, 28, 1)
# The shape of POS data :  (6667, 28, 28, 1)
# The shape of NEG data :  (66, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.97028
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.74352
# ========================================================================
# AUROC:  0.912156664894028
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  7
# [INFO:] Random Seed used is   81
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6733, 28, 28, 1)
# The shape of POS data :  (6667, 28, 28, 1)
# The shape of NEG data :  (66, 28, 28, 1)
# Starting training...
# Total elapsed time: 10.1112
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.73703
# ========================================================================
# AUROC:  0.8880192354018661
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  7
# [INFO:] Random Seed used is   67
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6733, 28, 28, 1)
# The shape of POS data :  (6667, 28, 28, 1)
# The shape of NEG data :  (66, 28, 28, 1)
# Starting training...
# Total elapsed time: 10.0012
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.81223
# ========================================================================
# AUROC:  0.9478185181650008
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  7
# [INFO:] Random Seed used is   33
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6733, 28, 28, 1)
# The shape of POS data :  (6667, 28, 28, 1)
# The shape of NEG data :  (66, 28, 28, 1)
# Starting training...
# Total elapsed time: 10.037
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.79129
# ========================================================================
# AUROC:  0.9409052274658996
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  7
# [INFO:] Random Seed used is   25
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6733, 28, 28, 1)
# The shape of POS data :  (6667, 28, 28, 1)
# The shape of NEG data :  (66, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.87304
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.65408
# ========================================================================
# AUROC:  0.9147315361504652
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  7
# [INFO:] Random Seed used is   90
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6733, 28, 28, 1)
# The shape of POS data :  (6667, 28, 28, 1)
# The shape of NEG data :  (66, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.87129
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.69108
# ========================================================================
# AUROC:  0.9131997945557269
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  7
# [INFO:] Random Seed used is   77
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6733, 28, 28, 1)
# The shape of POS data :  (6667, 28, 28, 1)
# The shape of NEG data :  (66, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.90288
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.68953
# ========================================================================
# AUROC:  0.9229629427619527
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  7
# [INFO:] Random Seed used is   15
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6733, 28, 28, 1)
# The shape of POS data :  (6667, 28, 28, 1)
# The shape of NEG data :  (66, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.90127
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.6839
# ========================================================================
# AUROC:  0.8953415965565358
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  7
# [INFO:] Random Seed used is   11
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6733, 28, 28, 1)
# The shape of POS data :  (6667, 28, 28, 1)
# The shape of NEG data :  (66, 28, 28, 1)
# Starting training...
# Total elapsed time: 10.0707
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.7497
# ========================================================================
# AUROC:  0.8961188304221154
# ===========AURO Computed============================
# AUROC computed  [0.9133747858061643, 0.912156664894028, 0.8880192354018661, 0.9478185181650008, 0.9409052274658996, 0.9147315361504652, 0.9131997945557269, 0.9229629427619527, 0.8953415965565358, 0.8961188304221154]
# AUROC ===== 0.9144629132179753 +/- 0.01814830988543539
# ========================================================================

# %% [markdown]
# ## ** MNIST 8 Vs All

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2
from src.models.isoForest import IsoForest
import numpy as np 
from src.config import Configuration as Cfg

DATASET = "mnist"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/mnist/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/mnist/ISO_FOREST/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.mnist_val_frac = 0.1
Cfg.mnist_normal = 8
Cfg.mnist_outlier = -1



for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    # initialize Isolation Forest
    model = IsoForest(dataset=DATASET, n_estimators=ESTIMATORS, max_samples=MAX_SAMPLES,
                      contamination=CONTAMINATION)
    # train IF model
    model.fit()
    print("===========PREDICTING WITH ISO_FOREST============================")
    # predict
    # model.predict(which_set='train')
    auc_roc = model.predict(which_set='test')
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    AUC.append(auc_roc)
  
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (6240, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.66302
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.69715
# ========================================================================
# AUROC:  0.6996536393713811
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   56
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (6240, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.53748
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.59497
# ========================================================================
# AUROC:  0.7261915839536808
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   81
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (6240, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.52529
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.60676
# ========================================================================
# AUROC:  0.772996794871795
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   67
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (6240, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.53931
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.58223
# ========================================================================
# AUROC:  0.7531405086848636
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   33
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (6240, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.32597
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.58733
# ========================================================================
# AUROC:  0.7500930521091811
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   25
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (6240, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.64699
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.65436
# ========================================================================
# AUROC:  0.8089149090157155
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   90
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (6240, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.63533
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.59225
# ========================================================================
# AUROC:  0.7666873449131514
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   77
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (6240, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.53333
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.63049
# ========================================================================
# AUROC:  0.8089330024813896
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   15
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (6240, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.40836
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.59901
# ========================================================================
# AUROC:  0.7194608147229116
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  8
# [INFO:] Random Seed used is   11
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6302, 28, 28, 1)
# The shape of POS data :  (6240, 28, 28, 1)
# The shape of NEG data :  (62, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.70543
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.70959
# ========================================================================
# AUROC:  0.7043243382961125
# ===========AURO Computed============================
# AUROC computed  [0.6996536393713811, 0.7261915839536808, 0.772996794871795, 0.7531405086848636, 0.7500930521091811, 0.8089149090157155, 0.7666873449131514, 0.8089330024813896, 0.7194608147229116, 0.7043243382961125]
# AUROC ===== 0.7510395988420182 +/- 0.03724372933670412
# ========================================================================

# %% [markdown]
# ## ** MNIST 9 Vs All

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2
from src.models.isoForest import IsoForest
import numpy as np 
from src.config import Configuration as Cfg

DATASET = "mnist"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "/models/mnist/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/mnist/ISO_FOREST/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.mnist_val_frac = 0.1
Cfg.mnist_normal = 9
Cfg.mnist_outlier = -1



for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    # initialize Isolation Forest
    model = IsoForest(dataset=DATASET, n_estimators=ESTIMATORS, max_samples=MAX_SAMPLES,
                      contamination=CONTAMINATION)
    # train IF model
    model.fit()
    print("===========PREDICTING WITH ISO_FOREST============================")
    # predict
    # model.predict(which_set='train')
    auc_roc = model.predict(which_set='test')
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    AUC.append(auc_roc)
  
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean ,"+/-",auc_roc_std)
print("========================================================================")
# Out:
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  9
# [INFO:] Random Seed used is   42
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6427, 28, 28, 1)
# The shape of POS data :  (6364, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.71849
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.68903
# ========================================================================
# AUROC:  0.8769741502299641
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  9
# [INFO:] Random Seed used is   56
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6427, 28, 28, 1)
# The shape of POS data :  (6364, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.86797
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.7128
# ========================================================================
# AUROC:  0.8838456396595932
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  9
# [INFO:] Random Seed used is   81
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6427, 28, 28, 1)
# The shape of POS data :  (6364, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.80426
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.76985
# ========================================================================
# AUROC:  0.8526907305977074
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  9
# [INFO:] Random Seed used is   67
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6427, 28, 28, 1)
# The shape of POS data :  (6364, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.70882
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.62566
# ========================================================================
# AUROC:  0.8462856544251893
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  9
# [INFO:] Random Seed used is   33
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6427, 28, 28, 1)
# The shape of POS data :  (6364, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.74476
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.62291
# ========================================================================
# AUROC:  0.8867438867438867
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  9
# [INFO:] Random Seed used is   25
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6427, 28, 28, 1)
# The shape of POS data :  (6364, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.85448
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.60682
# ========================================================================
# AUROC:  0.8799447287819381
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  9
# [INFO:] Random Seed used is   90
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6427, 28, 28, 1)
# The shape of POS data :  (6364, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.67869
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.69696
# ========================================================================
# AUROC:  0.8653911386469527
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  9
# [INFO:] Random Seed used is   77
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6427, 28, 28, 1)
# The shape of POS data :  (6364, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.95922
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.71338
# ========================================================================
# AUROC:  0.8954910059561222
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  9
# [INFO:] Random Seed used is   15
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6427, 28, 28, 1)
# The shape of POS data :  (6364, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.93615
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.61236
# ========================================================================
# AUROC:  0.8788223439386229
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks//reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  9
# [INFO:] Random Seed used is   11
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6427, 28, 28, 1)
# The shape of POS data :  (6364, 28, 28, 1)
# The shape of NEG data :  (63, 28, 28, 1)
# Starting training...
# Total elapsed time: 9.81186
# ===========PREDICTING WITH ISO_FOREST============================
# Starting prediction...
# Total elapsed time: 1.61597
# ========================================================================
# AUROC:  0.8933285444913351
# ===========AURO Computed============================
# AUROC computed  [0.8769741502299641, 0.8838456396595932, 0.8526907305977074, 0.8462856544251893, 0.8867438867438867, 0.8799447287819381, 0.8653911386469527, 0.8954910059561222, 0.8788223439386229, 0.8933285444913351]
# AUROC ===== 0.8759517823471313 +/- 0.015557723076788946
# ========================================================================
